# %%
import os
import numpy as np
import pandas as pd

# Sklearn
from sklearn.metrics import accuracy_score, recall_score, f1_score
import joblib

# PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F

# AIF360
from aif360.datasets import BinaryLabelDataset
from aif360.metrics import ClassificationMetric

import seaborn as sns
import matplotlib.pyplot as plt

# %%
test_data = pd.read_csv('dataset/train_test_extracted_base/test_all_demographics.csv')

race_map = {0: "Other", 1: "AfricanAmerican", 2: "Asian", 3: "Caucasian", 4: "Hispanic"}
gender_map = {0: "Female", 1: "Male"}

test_data['race_str'] = test_data['race'].map(race_map)
test_data['gender_str'] = test_data['gender'].map(gender_map)
test_data['race_gender'] = test_data['race_str'] + "_" + test_data['gender_str']


drop_cols = ['readmitted','race','gender','race_str','gender_str','race_gender',
             'race_AfricanAmerican','race_Asian','race_Caucasian','race_Hispanic','race_Other']
X_test = test_data.drop(columns=drop_cols)
y_test = test_data['readmitted']

print("X_test shape:", X_test.shape, "y_test shape:", y_test.shape)

model_paths = {
    'LogReg': 'models/base_all_demographics/LogReg.joblib',
    'XGB':    'models/base_all_demographics/XGB.joblib',
    'MLP':    'models/base_all_demographics/MLP.pth'  # PyTorch model
}
# Out:
# X_test shape: (14924, 28) y_test shape: (14924,)

# %%
class SimpleNet(nn.Module):
    def __init__(self, input_dim, hidden_dim=64, num_classes=2):
        super(SimpleNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, num_classes)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        logits = self.fc2(x)
        return logits


for model_name, path in model_paths.items():
    print(f"\n=== Loading {model_name} ===")

    if model_name in ['LogReg','XGB']:
        # scikit-learn model
        model = joblib.load(path)

        if model_name == 'LogReg':
            scaler_path = "models/base_all_demographics/scaler_LogReg.joblib"
            scaler = joblib.load(scaler_path)
            X_test_scaled = scaler.transform(X_test)
            y_pred = model.predict(X_test_scaled)
        elif model_name == 'XGB':
            y_pred = model.predict(X_test)

    else:

        input_dim = X_test.shape[1]
        mlp_model = SimpleNet(input_dim=input_dim, hidden_dim=64, num_classes=2)
        mlp_model.load_state_dict(torch.load(path))  # Load weights


        mlp_model.eval()
        X_test_t = torch.tensor(X_test.values, dtype=torch.float32)
        with torch.no_grad():
            logits = mlp_model(X_test_t)
            probs = F.softmax(logits, dim=1)
            y_pred = torch.argmax(probs, dim=1).numpy()

    acc = accuracy_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred, zero_division=0)
    f1 = f1_score(y_test, y_pred, zero_division=0)

    print(f"[{model_name}] Accuracy: {acc:.4f}, Recall: {rec:.4f}, F1: {f1:.4f}")

    # Store predictions for bias analysis
    pred_col = f"pred_{model_name}"
    test_data[pred_col] = y_pred
# Out:
# === Loading LogReg ===
# [LogReg] Accuracy: 0.6627, Recall: 0.4997, F1: 0.2542
#
# === Loading XGB ===
# [XGB] Accuracy: 0.6200, Recall: 0.6069, F1: 0.2687
#
# === Loading MLP ===
# [MLP] Accuracy: 0.6201, Recall: 0.5562, F1: 0.2520

# %%
def build_aif360_subset(df, label_col, pred_col, unpriv_group_val, priv_group_val):
    """
    Filters 'df' so it only contains rows where race_gender is either unpriv_group_val or priv_group_val.
    Then encodes 'race_gender' as 1 => unpriv, 0 => priv.
    Returns two BinaryLabelDatasets (one ground truth, one predicted).
    Also prints debug info on how many times label=1 vs 0 in truth & predictions.
    """

    # Filter DataFrame
    df_filtered = df[df['race_gender'].isin([unpriv_group_val, priv_group_val])].copy()
    if df_filtered.empty:
        return None, None

    # Binarize race_gender => 1 if unpriv, else 0
    df_filtered['race_gender'] = df_filtered['race_gender'].apply(
        lambda x: 1 if x == unpriv_group_val else 0
    )

    unpriv_count = (df_filtered['race_gender'] == 1).sum()
    priv_count   = (df_filtered['race_gender'] == 0).sum()

    # Build dataset_true
    df_true = df_filtered[['race_gender', label_col]].copy()
    df_true.rename(columns={label_col: 'label'}, inplace=True)

    # Count how many label=1 vs. 0 in ground truth
    true_ones  = (df_true['label'] == 1).sum()
    true_zeros = (df_true['label'] == 0).sum()

    dataset_true = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_true,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    # Build dataset_pred
    df_pred = df_filtered[['race_gender', pred_col]].copy()
    df_pred.rename(columns={pred_col: 'label'}, inplace=True)

    # Count how many label=1 vs. 0 in predictions
    pred_ones  = (df_pred['label'] == 1).sum()
    pred_zeros = (df_pred['label'] == 0).sum()

    dataset_pred = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_pred,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    # Debug prints
    print(f"\n[DEBUG] build_aif360_subset => unpriv='{unpriv_group_val}'(=1), "
          f"priv='{priv_group_val}'(=0)")
    print(f"   => #rows in subset: {len(df_filtered)} (unpriv_count={unpriv_count}, priv_count={priv_count})")
    print(f"   => GroundTruth: label=1 => {true_ones}, label=0 => {true_zeros}")
    print(f"   => Predictions: label=1 => {pred_ones}, label=0 => {pred_zeros}")

    return dataset_true, dataset_pred


def compute_bias_metrics(dataset_true, dataset_pred):
    metric = ClassificationMetric(
        dataset_true,
        dataset_pred,
        unprivileged_groups=[{'race_gender': 1}],
        privileged_groups=[{'race_gender': 0}]
    )
    spd = metric.statistical_parity_difference()
    di = metric.disparate_impact()
    eod = metric.equal_opportunity_difference()   
    aod = metric.average_odds_difference()        
    t_index = metric.theil_index()                
    return spd, di, eod, aod, t_index


def plot_fairness_bar(df, x_col, y_col, hue_col, title,
                      width=8, height=6, ref_line=None,
                      label_fontsize=8):

    plt.figure(figsize=(width, height))
    ax = sns.barplot(data=df, x=x_col, y=y_col, hue=hue_col)

    if ref_line is not None:
        plt.axhline(ref_line, color='black', linewidth=1)

    for container in ax.containers:
        ax.bar_label(container, fmt="%.2f", label_type='edge', 
                     padding=3, fontsize=label_fontsize)

    plt.title(title)
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()



def build_aif360_subset_lumped(df, label_col, pred_col, privileged_grp="Asian_Female"):
    """
    Instead of splitting each unpriv group individually,
    we lump "everything that is not privileged_grp" into unpriv (1).
    """
    # Copy entire df (no filter for specific groups)
    df_temp = df.copy()

    # Binarize: 1 if not privileged_grp, else 0
    df_temp['race_gender'] = df_temp['race_gender'].apply(
        lambda x: 0 if x == privileged_grp else 1
    )

    # Build dataset_true
    df_true = df_temp[['race_gender', label_col]].copy()
    df_true.rename(columns={label_col: 'label'}, inplace=True)
    dataset_true = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_true,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    # Build dataset_pred
    df_pred = df_temp[['race_gender', pred_col]].copy()
    df_pred.rename(columns={pred_col: 'label'}, inplace=True)
    dataset_pred = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_pred,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    return dataset_true, dataset_pred



def build_aif360_subset_lumped_OF(df, label_col, pred_col):
    """
    Lump: 'Other_Female' => 1 (unpriv), everything else => 0 (priv).
    """
    df_temp = df.copy()
    df_temp['race_gender'] = df_temp['race_gender'].apply(
        lambda x: 1 if x == "Other_Female" else 0
    )
    # Build dataset_true
    df_true = df_temp[[ 'race_gender', label_col]].copy()
    df_true.rename(columns={label_col: 'label'}, inplace=True)
    dataset_true = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_true,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )
    # Build dataset_pred
    df_pred = df_temp[['race_gender', pred_col]].copy()
    df_pred.rename(columns={pred_col: 'label'}, inplace=True)
    dataset_pred = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_pred,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )
    return dataset_true, dataset_pred

# %%
print("\n=== (A) Bias Analysis per Subgroup vs. 'Other_Female' ===")

UNPRIV_GROUP_OF = "Other_Female"
all_race_genders = test_data['race_gender'].unique()
privileged_groups = [g for g in all_race_genders if g != UNPRIV_GROUP_OF]

results_sep_OF = []
model_predictions = ['pred_LogReg','pred_XGB','pred_MLP']

for model_col in model_predictions:
    print(f"\n--- Model: {model_col}, Unprivileged: {UNPRIV_GROUP_OF} ---")
    for priv_grp in privileged_groups:
        ds_true, ds_pred = build_aif360_subset(
            df=test_data,
            label_col='readmitted',
            pred_col=model_col,
            unpriv_group_val=UNPRIV_GROUP_OF, 
            priv_group_val=priv_grp           
        )
        if ds_true is None or ds_pred is None:
            print(f"   WARNING: No data for group={priv_grp}; skipping.")
            continue

        spd, di, eod, aod, t_index = compute_bias_metrics(ds_true, ds_pred)
        print(f"   Compare {UNPRIV_GROUP_OF} vs {priv_grp}: SPD={spd:.4f}, DI={di:.4f}")

        results_sep_OF.append({
            'Model': model_col,
            'UnprivGroup': UNPRIV_GROUP_OF,
            'PrivGroup': priv_grp,
            'SPD': spd,
            'DI': di,
            'EOD': eod,
            'AOD': aod,
            'T_Index': t_index
        })

df_results_sep_OF = pd.DataFrame(results_sep_OF)
print("\n=== Aggregated Bias Results (Individual Groups) ===\n", df_results_sep_OF)

print("\n=== Plot SPD/DI for each Subgroup vs. Other_Female ===")
plot_fairness_bar(
    df=df_results_sep_OF,
    x_col='PrivGroup',
    y_col='SPD',
    hue_col='Model',
    title=f"Statistical Parity Difference vs. {UNPRIV_GROUP_OF} (Unpriv)",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_sep_OF,
    x_col='PrivGroup',
    y_col='DI',
    hue_col='Model',
    title=f"Disparate Impact vs. {UNPRIV_GROUP_OF} (Unpriv)",
    ref_line=1
)


print("\n=== (B) Lumps => 'Other_Female' unpriv, All Others => priv ===")
results_lumped_OF = []

for model_col in model_predictions:
    ds_true_lumped, ds_pred_lumped = build_aif360_subset_lumped_OF(
        df=test_data,
        label_col='readmitted',
        pred_col=model_col
    )
    spd, di, eod, aod, t_index = compute_bias_metrics(ds_true_lumped, ds_pred_lumped)
    print(f"[{model_col}] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD={spd:.4f}, DI={di:.4f}")
    results_lumped_OF.append({
        'Model': model_col,
        'UnprivGroup': "Other_Female",
        'PrivGroup': "ALL_OTHERS",
        'SPD': spd,
        'DI': di,
        'EOD': eod,
        'AOD': aod,
        'T_Index': t_index
    })

df_results_lumped_OF = pd.DataFrame(results_lumped_OF)
print("\n=== Aggregated Bias Results (Lumped) ===\n", df_results_lumped_OF)

print("\n=== Plot SPD/DI => 'Other_Female'(unpriv) vs ALL_OTHERS ===")
plot_fairness_bar(
    df=df_results_lumped_OF,
    x_col='UnprivGroup',
    y_col='SPD',
    hue_col='Model',
    title="Statistical Parity Difference (Other_Female vs. ALL_OTHERS)",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_lumped_OF,
    x_col='UnprivGroup',
    y_col='DI',
    hue_col='Model',
    title="Disparate Impact (Other_Female vs. ALL_OTHERS)",
    ref_line=1
)
# Out:
# === (A) Bias Analysis per Subgroup vs. 'Other_Female' ===
#
# --- Model: pred_LogReg, Unprivileged: Other_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Female'(=0)
#    => #rows in subset: 6077 (unpriv_count=136, priv_count=5941)
#    => GroundTruth: label=1 => 700, label=0 => 5377
#    => Predictions: label=1 => 2118, label=0 => 3959
#    Compare Other_Female vs Caucasian_Female: SPD=0.0331, DI=1.0509
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Male'(=0)
#    => #rows in subset: 5527 (unpriv_count=136, priv_count=5391)
#    => GroundTruth: label=1 => 637, label=0 => 4890
#    => Predictions: label=1 => 1808, label=0 => 3719
#    Compare Other_Female vs Caucasian_Male: SPD=0.0112, DI=1.0167
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Female'(=0)
#    => #rows in subset: 1931 (unpriv_count=136, priv_count=1795)
#    => GroundTruth: label=1 => 223, label=0 => 1708
#    => Predictions: label=1 => 655, label=0 => 1276
#    Compare Other_Female vs AfricanAmerican_Female: SPD=0.0248, DI=1.0376
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Male'(=0)
#    => #rows in subset: 293 (unpriv_count=136, priv_count=157)
#    => GroundTruth: label=1 => 32, label=0 => 261
#    => Predictions: label=1 => 85, label=0 => 208
#    Compare Other_Female vs Hispanic_Male: SPD=-0.0487, DI=0.9336
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Male'(=0)
#    => #rows in subset: 1256 (unpriv_count=136, priv_count=1120)
#    => GroundTruth: label=1 => 161, label=0 => 1095
#    => Predictions: label=1 => 433, label=0 => 823
#    Compare Other_Female vs AfricanAmerican_Male: SPD=0.0320, DI=1.0492
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Female'(=0)
#    => #rows in subset: 302 (unpriv_count=136, priv_count=166)
#    => GroundTruth: label=1 => 35, label=0 => 267
#    => Predictions: label=1 => 92, label=0 => 210
#    Compare Other_Female vs Hispanic_Female: SPD=-0.0210, DI=0.9702
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Other_Male'(=0)
#    => #rows in subset: 250 (unpriv_count=136, priv_count=114)
#    => GroundTruth: label=1 => 26, label=0 => 224
#    => Predictions: label=1 => 81, label=0 => 169
#    Compare Other_Female vs Other_Male: SPD=0.0172, DI=1.0257
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 53, label=0 => 137
#    Compare Other_Female vs Asian_Female: SPD=-0.1310, DI=0.8392
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Male'(=0)
#    => #rows in subset: 186 (unpriv_count=136, priv_count=50)
#    => GroundTruth: label=1 => 23, label=0 => 163
#    => Predictions: label=1 => 52, label=0 => 134
#    Compare Other_Female vs Asian_Male: SPD=-0.1362, DI=0.8339
#
# --- Model: pred_XGB, Unprivileged: Other_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Female'(=0)
#    => #rows in subset: 6077 (unpriv_count=136, priv_count=5941)
#    => GroundTruth: label=1 => 700, label=0 => 5377
#    => Predictions: label=1 => 2690, label=0 => 3387
#    Compare Other_Female vs Caucasian_Female: SPD=0.0542, DI=1.0974
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Male'(=0)
#    => #rows in subset: 5527 (unpriv_count=136, priv_count=5391)
#    => GroundTruth: label=1 => 637, label=0 => 4890
#    => Predictions: label=1 => 2104, label=0 => 3423
#    Compare Other_Female vs Caucasian_Male: SPD=-0.0093, DI=0.9851
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Female'(=0)
#    => #rows in subset: 1931 (unpriv_count=136, priv_count=1795)
#    => GroundTruth: label=1 => 223, label=0 => 1708
#    => Predictions: label=1 => 751, label=0 => 1180
#    Compare Other_Female vs AfricanAmerican_Female: SPD=-0.0008, DI=0.9986
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Male'(=0)
#    => #rows in subset: 293 (unpriv_count=136, priv_count=157)
#    => GroundTruth: label=1 => 32, label=0 => 261
#    => Predictions: label=1 => 110, label=0 => 183
#    Compare Other_Female vs Hispanic_Male: SPD=-0.0266, DI=0.9582
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Male'(=0)
#    => #rows in subset: 1256 (unpriv_count=136, priv_count=1120)
#    => GroundTruth: label=1 => 161, label=0 => 1095
#    => Predictions: label=1 => 484, label=0 => 772
#    Compare Other_Female vs AfricanAmerican_Male: SPD=-0.0049, DI=0.9921
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Female'(=0)
#    => #rows in subset: 302 (unpriv_count=136, priv_count=166)
#    => GroundTruth: label=1 => 35, label=0 => 267
#    => Predictions: label=1 => 105, label=0 => 197
#    Compare Other_Female vs Hispanic_Female: SPD=-0.0765, DI=0.8887
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Other_Male'(=0)
#    => #rows in subset: 250 (unpriv_count=136, priv_count=114)
#    => GroundTruth: label=1 => 26, label=0 => 224
#    => Predictions: label=1 => 90, label=0 => 160
#    Compare Other_Female vs Other_Male: SPD=-0.0651, DI=0.9036
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 69, label=0 => 121
#    Compare Other_Female vs Asian_Female: SPD=-0.0934, DI=0.8673
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Male'(=0)
#    => #rows in subset: 186 (unpriv_count=136, priv_count=50)
#    => GroundTruth: label=1 => 23, label=0 => 163
#    => Predictions: label=1 => 59, label=0 => 127
#    Compare Other_Female vs Asian_Male: SPD=-0.2697, DI=0.6935
#
# --- Model: pred_MLP, Unprivileged: Other_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Female'(=0)
#    => #rows in subset: 6077 (unpriv_count=136, priv_count=5941)
#    => GroundTruth: label=1 => 700, label=0 => 5377
#    => Predictions: label=1 => 2479, label=0 => 3598
#    Compare Other_Female vs Caucasian_Female: SPD=-0.0039, DI=0.9934
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Male'(=0)
#    => #rows in subset: 5527 (unpriv_count=136, priv_count=5391)
#    => GroundTruth: label=1 => 637, label=0 => 4890
#    => Predictions: label=1 => 2103, label=0 => 3424
#    Compare Other_Female vs Caucasian_Male: SPD=-0.0321, DI=0.9483
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Female'(=0)
#    => #rows in subset: 1931 (unpriv_count=136, priv_count=1795)
#    => GroundTruth: label=1 => 223, label=0 => 1708
#    => Predictions: label=1 => 766, label=0 => 1165
#    Compare Other_Female vs AfricanAmerican_Female: SPD=-0.0162, DI=0.9732
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Male'(=0)
#    => #rows in subset: 293 (unpriv_count=136, priv_count=157)
#    => GroundTruth: label=1 => 32, label=0 => 261
#    => Predictions: label=1 => 108, label=0 => 185
#    Compare Other_Female vs Hispanic_Male: SPD=-0.0806, DI=0.8796
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Male'(=0)
#    => #rows in subset: 1256 (unpriv_count=136, priv_count=1120)
#    => GroundTruth: label=1 => 161, label=0 => 1095
#    => Predictions: label=1 => 507, label=0 => 749
#    Compare Other_Female vs AfricanAmerican_Male: SPD=-0.0091, DI=0.9848
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Female'(=0)
#    => #rows in subset: 302 (unpriv_count=136, priv_count=166)
#    => GroundTruth: label=1 => 35, label=0 => 267
#    => Predictions: label=1 => 116, label=0 => 186
#    Compare Other_Female vs Hispanic_Female: SPD=-0.0503, DI=0.9212
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Other_Male'(=0)
#    => #rows in subset: 250 (unpriv_count=136, priv_count=114)
#    => GroundTruth: label=1 => 26, label=0 => 224
#    => Predictions: label=1 => 93, label=0 => 157
#    Compare Other_Female vs Other_Male: SPD=-0.0872, DI=0.8709
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 71, label=0 => 119
#    Compare Other_Female vs Asian_Female: SPD=-0.1340, DI=0.8145
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Male'(=0)
#    => #rows in subset: 186 (unpriv_count=136, priv_count=50)
#    => GroundTruth: label=1 => 23, label=0 => 163
#    => Predictions: label=1 => 67, label=0 => 119
#    Compare Other_Female vs Asian_Male: SPD=-0.1918, DI=0.7541
#
# === Aggregated Bias Results (Individual Groups) ===
#            Model   UnprivGroup               PrivGroup       SPD        DI  \
# 0   pred_LogReg  Other_Female        Caucasian_Female  0.033091  1.050852
# 1   pred_LogReg  Other_Female          Caucasian_Male  0.011221  1.016683
# 2   pred_LogReg  Other_Female  AfricanAmerican_Female  0.024771  1.037585
# 3   pred_LogReg  Other_Female           Hispanic_Male -0.048661  0.933568
# 4   pred_LogReg  Other_Female    AfricanAmerican_Male  0.032038  1.049154
# 5   pred_LogReg  Other_Female         Hispanic_Female -0.020996  0.970211
# 6   pred_LogReg  Other_Female              Other_Male  0.017157  1.025735
# 7   pred_LogReg  Other_Female            Asian_Female -0.130991  0.839238
# 8   pred_LogReg  Other_Female              Asian_Male -0.136176  0.833931
# 9      pred_XGB  Other_Female        Caucasian_Female  0.054159  1.097384
# 10     pred_XGB  Other_Female          Caucasian_Male -0.009257  0.985059
# 11     pred_XGB  Other_Female  AfricanAmerican_Female -0.000848  0.998613
# 12     pred_XGB  Other_Female           Hispanic_Male -0.026649  0.958162
# 13     pred_XGB  Other_Female    AfricanAmerican_Male -0.004884  0.992060
# 14     pred_XGB  Other_Female         Hispanic_Female -0.076453  0.888674
# 15     pred_XGB  Other_Female              Other_Male -0.065144  0.903552
# 16     pred_XGB  Other_Female            Asian_Female -0.093410  0.867260
# 17     pred_XGB  Other_Female              Asian_Male -0.269706  0.693516
# 18     pred_MLP  Other_Female        Caucasian_Female -0.003921  0.993379
# 19     pred_MLP  Other_Female          Caucasian_Male -0.032058  0.948318
# 20     pred_MLP  Other_Female  AfricanAmerican_Female -0.016222  0.973163
# 21     pred_MLP  Other_Female           Hispanic_Male -0.080555  0.879552
# 22     pred_MLP  Other_Female    AfricanAmerican_Male -0.009086  0.984789
# 23     pred_MLP  Other_Female         Hispanic_Female -0.050319  0.921199
# 24     pred_MLP  Other_Female              Other_Male -0.087203  0.870894
# 25     pred_MLP  Other_Female            Asian_Female -0.133987  0.814480
# 26     pred_MLP  Other_Female              Asian_Male -0.191765  0.754148
#
#          EOD       AOD   T_Index
# 0   0.057203 -0.021822  0.367176
# 1   0.036232 -0.046729  0.342477
# 2   0.047053 -0.023493  0.351270
# 3  -0.033424 -0.036553  0.274625
# 4   0.054300 -0.026657  0.353951
# 5  -0.002730 -0.042215  0.294044
# 6   0.040134  0.027012  0.319553
# 7  -0.062853 -0.336982  0.277557
# 8  -0.093409 -0.252260  0.266630
# 9   0.087632 -0.023959  0.480821
# 10  0.024269 -0.087578  0.398947
# 11  0.031756 -0.075450  0.405389
# 12 -0.008830 -0.000447  0.354670
# 13  0.028755 -0.094791  0.396834
# 14 -0.062052 -0.066974  0.317468
# 15 -0.019188 -0.148483  0.355340
# 16 -0.018008 -0.314560  0.356336
# 17 -0.241620 -0.309699  0.279805
# 18  0.021978 -0.063465  0.441834
# 19 -0.003971 -0.098961  0.409602
# 20  0.007291 -0.067222  0.421062
# 21 -0.056714 -0.103754  0.370548
# 22  0.015327 -0.073727  0.425834
# 23 -0.028836 -0.081412  0.387538
# 24 -0.071954 -0.022088  0.365002
# 25 -0.051907 -0.387065  0.390817
# 26 -0.142185 -0.332203  0.357783
#
# === Plot SPD/DI for each Subgroup vs. Other_Female ===
# === (B) Lumps => 'Other_Female' unpriv, All Others => priv ===
# [pred_LogReg] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD=0.0213, DI=1.0321
# [pred_XGB] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD=0.0150, DI=1.0252
# [pred_MLP] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD=-0.0191, DI=0.9685
#
# === Aggregated Bias Results (Lumped) ===
#           Model   UnprivGroup   PrivGroup       SPD        DI       EOD  \
# 0  pred_LogReg  Other_Female  ALL_OTHERS  0.021259  1.032086  0.045339
# 1     pred_XGB  Other_Female  ALL_OTHERS  0.015014  1.025222  0.048206
# 2     pred_MLP  Other_Female  ALL_OTHERS -0.019149  0.968473  0.007203
#
#         AOD   T_Index
# 0 -0.033622  0.353863
# 1 -0.062255  0.430087
# 2 -0.080288  0.423372
#
# === Plot SPD/DI => 'Other_Female'(unpriv) vs ALL_OTHERS ===

# %%
print("\n=== (A) Bias Analysis: Subgroup vs. 'Asian_Female' (Privileged) ===")

PRIV_GROUP_AF = "Asian_Female"
# all subgroups that are NOT 'Asian_Female' are tested as unprivileged, one by one
all_race_genders = test_data['race_gender'].unique()
unprivileged_groups = [g for g in all_race_genders if g != PRIV_GROUP_AF]

results_sep_AF = []
model_predictions = ['pred_LogReg','pred_XGB','pred_MLP']

for model_col in model_predictions:
    print(f"\n--- Model: {model_col}, Privileged: {PRIV_GROUP_AF} ---")
    for unpriv_grp in unprivileged_groups:
        ds_true, ds_pred = build_aif360_subset(
            df=test_data,
            label_col='readmitted',
            pred_col=model_col,
            unpriv_group_val=unpriv_grp,      # => 1
            priv_group_val=PRIV_GROUP_AF      # => 0
        )
        if ds_true is None or ds_pred is None:
            # If no rows match unpriv_grp or PRIV_GROUP_AF in test_data['race_gender']
            continue

        spd, di, eod, aod, t_index = compute_bias_metrics(ds_true, ds_pred)
        print(f"   Compare unpriv={unpriv_grp} vs priv={PRIV_GROUP_AF}: SPD={spd:.4f}, DI={di:.4f}")

        results_sep_AF.append({
            'Model': model_col,
            'UnprivGroup': unpriv_grp,
            'PrivGroup': PRIV_GROUP_AF,
            'SPD': spd,
            'DI': di,
            'EOD': eod,
            'AOD': aod,
            'T_Index': t_index
        })

df_results_sep_AF = pd.DataFrame(results_sep_AF)
print("\n=== Aggregated Bias Results (Individual Subgroups) ===\n", df_results_sep_AF)

# Plot SPD & DI
print("\n=== Plot SPD/DI for each Unpriv Subgroup vs. 'Asian_Female' ===")
plot_fairness_bar(
    df=df_results_sep_AF,
    x_col='UnprivGroup',
    y_col='SPD',
    hue_col='Model',
    title=f"Statistical Parity Difference vs. {PRIV_GROUP_AF}",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_sep_AF,
    x_col='UnprivGroup',
    y_col='DI',
    hue_col='Model',
    title=f"Disparate Impact vs. {PRIV_GROUP_AF}",
    ref_line=1
)


print("\n=== (B) Lumped Bias => 'Asian_Female' privileged vs. ALL_OTHERS unpriv ===")

results_lumped_AF = []

for model_col in model_predictions:
    ds_true_lumped, ds_pred_lumped = build_aif360_subset_lumped(
        df=test_data,
        label_col='readmitted',
        pred_col=model_col,
        privileged_grp=PRIV_GROUP_AF
    )

    spd, di, eod, aod, t_index = compute_bias_metrics(ds_true_lumped, ds_pred_lumped)
    print(f"[{model_col}] Non-Asian_Female vs {PRIV_GROUP_AF}: SPD={spd:.4f}, DI={di:.4f}")

    results_lumped_AF.append({
        'Model': model_col,
        'UnprivGroup': "ALL_OTHERS",
        'PrivGroup': PRIV_GROUP_AF,
        'SPD': spd,
        'DI': di,
        'EOD': eod,
        'AOD': aod,
        'T_Index': t_index
    })

df_results_lumped_AF = pd.DataFrame(results_lumped_AF)
print("\n=== Aggregated Bias Results (Lumped) ===\n", df_results_lumped_AF)

print("\n=== Plot SPD/DI => Non-Asian_Female vs 'Asian_Female' ===")
plot_fairness_bar(
    df=df_results_lumped_AF,
    x_col='UnprivGroup',
    y_col='SPD',
    hue_col='Model',
    title=f"Statistical Parity Difference (All Non-Asian_Female vs. {PRIV_GROUP_AF})",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_lumped_AF,
    x_col='UnprivGroup',
    y_col='DI',
    hue_col='Model',
    title=f"Disparate Impact (All Non-Asian_Female vs. {PRIV_GROUP_AF})",
    ref_line=1
)
# Out:
# === (A) Bias Analysis: Subgroup vs. 'Asian_Female' (Privileged) ===
#
# --- Model: pred_LogReg, Privileged: Asian_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5995 (unpriv_count=5941, priv_count=54)
#    => GroundTruth: label=1 => 688, label=0 => 5307
#    => Predictions: label=1 => 2085, label=0 => 3910
#    Compare unpriv=Caucasian_Female vs priv=Asian_Female: SPD=-0.1641, DI=0.7986
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5445 (unpriv_count=5391, priv_count=54)
#    => GroundTruth: label=1 => 625, label=0 => 4820
#    => Predictions: label=1 => 1775, label=0 => 3670
#    Compare unpriv=Caucasian_Male vs priv=Asian_Female: SPD=-0.1422, DI=0.8255
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1849 (unpriv_count=1795, priv_count=54)
#    => GroundTruth: label=1 => 211, label=0 => 1638
#    => Predictions: label=1 => 622, label=0 => 1227
#    Compare unpriv=AfricanAmerican_Female vs priv=Asian_Female: SPD=-0.1558, DI=0.8088
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 211 (unpriv_count=157, priv_count=54)
#    => GroundTruth: label=1 => 20, label=0 => 191
#    => Predictions: label=1 => 52, label=0 => 159
#    Compare unpriv=Hispanic_Male vs priv=Asian_Female: SPD=-0.0823, DI=0.8990
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1174 (unpriv_count=1120, priv_count=54)
#    => GroundTruth: label=1 => 149, label=0 => 1025
#    => Predictions: label=1 => 400, label=0 => 774
#    Compare unpriv=AfricanAmerican_Male vs priv=Asian_Female: SPD=-0.1630, DI=0.7999
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 220 (unpriv_count=166, priv_count=54)
#    => GroundTruth: label=1 => 23, label=0 => 197
#    => Predictions: label=1 => 59, label=0 => 161
#    Compare unpriv=Hispanic_Female vs priv=Asian_Female: SPD=-0.1100, DI=0.8650
#
# [DEBUG] build_aif360_subset => unpriv='Other_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 168 (unpriv_count=114, priv_count=54)
#    => GroundTruth: label=1 => 14, label=0 => 154
#    => Predictions: label=1 => 48, label=0 => 120
#    Compare unpriv=Other_Male vs priv=Asian_Female: SPD=-0.1481, DI=0.8182
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 53, label=0 => 137
#    Compare unpriv=Other_Female vs priv=Asian_Female: SPD=-0.1310, DI=0.8392
#
# [DEBUG] build_aif360_subset => unpriv='Asian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 104 (unpriv_count=50, priv_count=54)
#    => GroundTruth: label=1 => 11, label=0 => 93
#    => Predictions: label=1 => 19, label=0 => 85
#    Compare unpriv=Asian_Male vs priv=Asian_Female: SPD=0.0052, DI=1.0064
#
# --- Model: pred_XGB, Privileged: Asian_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5995 (unpriv_count=5941, priv_count=54)
#    => GroundTruth: label=1 => 688, label=0 => 5307
#    => Predictions: label=1 => 2653, label=0 => 3342
#    Compare unpriv=Caucasian_Female vs priv=Asian_Female: SPD=-0.1476, DI=0.7903
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5445 (unpriv_count=5391, priv_count=54)
#    => GroundTruth: label=1 => 625, label=0 => 4820
#    => Predictions: label=1 => 2067, label=0 => 3378
#    Compare unpriv=Caucasian_Male vs priv=Asian_Female: SPD=-0.0842, DI=0.8804
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1849 (unpriv_count=1795, priv_count=54)
#    => GroundTruth: label=1 => 211, label=0 => 1638
#    => Predictions: label=1 => 714, label=0 => 1135
#    Compare unpriv=AfricanAmerican_Female vs priv=Asian_Female: SPD=-0.0926, DI=0.8685
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 211 (unpriv_count=157, priv_count=54)
#    => GroundTruth: label=1 => 20, label=0 => 191
#    => Predictions: label=1 => 73, label=0 => 138
#    Compare unpriv=Hispanic_Male vs priv=Asian_Female: SPD=-0.0668, DI=0.9051
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1174 (unpriv_count=1120, priv_count=54)
#    => GroundTruth: label=1 => 149, label=0 => 1025
#    => Predictions: label=1 => 447, label=0 => 727
#    Compare unpriv=AfricanAmerican_Male vs priv=Asian_Female: SPD=-0.0885, DI=0.8742
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 220 (unpriv_count=166, priv_count=54)
#    => GroundTruth: label=1 => 23, label=0 => 197
#    => Predictions: label=1 => 68, label=0 => 152
#    Compare unpriv=Hispanic_Female vs priv=Asian_Female: SPD=-0.0170, DI=0.9759
#
# [DEBUG] build_aif360_subset => unpriv='Other_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 168 (unpriv_count=114, priv_count=54)
#    => GroundTruth: label=1 => 14, label=0 => 154
#    => Predictions: label=1 => 53, label=0 => 115
#    Compare unpriv=Other_Male vs priv=Asian_Female: SPD=-0.0283, DI=0.9598
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 69, label=0 => 121
#    Compare unpriv=Other_Female vs priv=Asian_Female: SPD=-0.0934, DI=0.8673
#
# [DEBUG] build_aif360_subset => unpriv='Asian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 104 (unpriv_count=50, priv_count=54)
#    => GroundTruth: label=1 => 11, label=0 => 93
#    => Predictions: label=1 => 22, label=0 => 82
#    Compare unpriv=Asian_Male vs priv=Asian_Female: SPD=0.1763, DI=1.2505
#
# --- Model: pred_MLP, Privileged: Asian_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5995 (unpriv_count=5941, priv_count=54)
#    => GroundTruth: label=1 => 688, label=0 => 5307
#    => Predictions: label=1 => 2438, label=0 => 3557
#    Compare unpriv=Caucasian_Female vs priv=Asian_Female: SPD=-0.1301, DI=0.8199
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5445 (unpriv_count=5391, priv_count=54)
#    => GroundTruth: label=1 => 625, label=0 => 4820
#    => Predictions: label=1 => 2062, label=0 => 3383
#    Compare unpriv=Caucasian_Male vs priv=Asian_Female: SPD=-0.1019, DI=0.8589
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1849 (unpriv_count=1795, priv_count=54)
#    => GroundTruth: label=1 => 211, label=0 => 1638
#    => Predictions: label=1 => 725, label=0 => 1124
#    Compare unpriv=AfricanAmerican_Female vs priv=Asian_Female: SPD=-0.1178, DI=0.8369
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 211 (unpriv_count=157, priv_count=54)
#    => GroundTruth: label=1 => 20, label=0 => 191
#    => Predictions: label=1 => 67, label=0 => 144
#    Compare unpriv=Hispanic_Male vs priv=Asian_Female: SPD=-0.0534, DI=0.9260
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1174 (unpriv_count=1120, priv_count=54)
#    => GroundTruth: label=1 => 149, label=0 => 1025
#    => Predictions: label=1 => 466, label=0 => 708
#    Compare unpriv=AfricanAmerican_Male vs priv=Asian_Female: SPD=-0.1249, DI=0.8271
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 220 (unpriv_count=166, priv_count=54)
#    => GroundTruth: label=1 => 23, label=0 => 197
#    => Predictions: label=1 => 75, label=0 => 145
#    Compare unpriv=Hispanic_Female vs priv=Asian_Female: SPD=-0.0837, DI=0.8842
#
# [DEBUG] build_aif360_subset => unpriv='Other_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 168 (unpriv_count=114, priv_count=54)
#    => GroundTruth: label=1 => 14, label=0 => 154
#    => Predictions: label=1 => 52, label=0 => 116
#    Compare unpriv=Other_Male vs priv=Asian_Female: SPD=-0.0468, DI=0.9352
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 71, label=0 => 119
#    Compare unpriv=Other_Female vs priv=Asian_Female: SPD=-0.1340, DI=0.8145
#
# [DEBUG] build_aif360_subset => unpriv='Asian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 104 (unpriv_count=50, priv_count=54)
#    => GroundTruth: label=1 => 11, label=0 => 93
#    => Predictions: label=1 => 26, label=0 => 78
#    Compare unpriv=Asian_Male vs priv=Asian_Female: SPD=0.0578, DI=1.0800
#
# === Aggregated Bias Results (Individual Subgroups) ===
#            Model             UnprivGroup     PrivGroup       SPD        DI  \
# 0   pred_LogReg        Caucasian_Female  Asian_Female -0.164083  0.798626
# 1   pred_LogReg          Caucasian_Male  Asian_Female -0.142212  0.825467
# 2   pred_LogReg  AfricanAmerican_Female  Asian_Female -0.155762  0.808838
# 3   pred_LogReg           Hispanic_Male  Asian_Female -0.082331  0.898958
# 4   pred_LogReg    AfricanAmerican_Male  Asian_Female -0.163029  0.799919
# 5   pred_LogReg         Hispanic_Female  Asian_Female -0.109996  0.865005
# 6   pred_LogReg              Other_Male  Asian_Female -0.148148  0.818182
# 7   pred_LogReg            Other_Female  Asian_Female -0.130991  0.839238
# 8   pred_LogReg              Asian_Male  Asian_Female  0.005185  1.006364
# 9      pred_XGB        Caucasian_Female  Asian_Female -0.147568  0.790298
# 10     pred_XGB          Caucasian_Male  Asian_Female -0.084153  0.880415
# 11     pred_XGB  AfricanAmerican_Female  Asian_Female -0.092562  0.868465
# 12     pred_XGB           Hispanic_Male  Asian_Female -0.066761  0.905129
# 13     pred_XGB    AfricanAmerican_Male  Asian_Female -0.088525  0.874201
# 14     pred_XGB         Hispanic_Female  Asian_Female -0.016957  0.975904
# 15     pred_XGB              Other_Male  Asian_Female -0.028265  0.959834
# 16     pred_XGB            Other_Female  Asian_Female -0.093410  0.867260
# 17     pred_XGB              Asian_Male  Asian_Female  0.176296  1.250526
# 18     pred_MLP        Caucasian_Female  Asian_Female -0.130066  0.819909
# 19     pred_MLP          Caucasian_Male  Asian_Female -0.101929  0.858867
# 20     pred_MLP  AfricanAmerican_Female  Asian_Female -0.117765  0.836940
# 21     pred_MLP           Hispanic_Male  Asian_Female -0.053432  0.926017
# 22     pred_MLP    AfricanAmerican_Male  Asian_Female -0.124901  0.827060
# 23     pred_MLP         Hispanic_Female  Asian_Female -0.083668  0.884152
# 24     pred_MLP              Other_Male  Asian_Female -0.046784  0.935223
# 25     pred_MLP            Other_Female  Asian_Female -0.133987  0.814480
# 26     pred_MLP              Asian_Male  Asian_Female  0.057778  1.080000
#
#          EOD       AOD   T_Index
# 0  -0.120056 -0.315160  0.367814
# 1  -0.099085 -0.290253  0.342792
# 2  -0.109906 -0.313489  0.352616
# 3  -0.029429 -0.300429  0.257408
# 4  -0.117153 -0.310325  0.356192
# 5  -0.060123 -0.294767  0.284171
# 6  -0.102987 -0.363994  0.319234
# 7  -0.062853 -0.336982  0.277557
# 8   0.030556 -0.084722  0.224448
# 9  -0.105640 -0.290601  0.482814
# 10 -0.042278 -0.226982  0.399773
# 11 -0.049764 -0.239110  0.408142
# 12 -0.009178 -0.314113  0.359455
# 13 -0.046763 -0.219768  0.400418
# 14  0.044044 -0.247586  0.308058
# 15  0.001179 -0.166077  0.360870
# 16 -0.018008 -0.314560  0.356336
# 17  0.223611 -0.004861  0.231043
# 18 -0.073885 -0.323600  0.442176
# 19 -0.047936 -0.288104  0.409478
# 20 -0.059198 -0.319843  0.421249
# 21  0.004808 -0.283310  0.353428
# 22 -0.067234 -0.313337  0.426349
# 23 -0.023070 -0.305653  0.376936
# 24  0.020047 -0.364976  0.341740
# 25 -0.051907 -0.387065  0.390817
# 26  0.090278 -0.054861  0.311518
#
# === Plot SPD/DI for each Unpriv Subgroup vs. 'Asian_Female' ===
# === (B) Lumped Bias => 'Asian_Female' privileged vs. ALL_OTHERS unpriv ===
# [pred_LogReg] Non-Asian_Female vs Asian_Female: SPD=-0.1526, DI=0.8127
# [pred_XGB] Non-Asian_Female vs Asian_Female: SPD=-0.1087, DI=0.8456
# [pred_MLP] Non-Asian_Female vs Asian_Female: SPD=-0.1154, DI=0.8402
#
# === Aggregated Bias Results (Lumped) ===
#           Model UnprivGroup     PrivGroup       SPD        DI       EOD  \
# 0  pred_LogReg  ALL_OTHERS  Asian_Female -0.152609  0.812707 -0.108180
# 1     pred_XGB  ALL_OTHERS  Asian_Female -0.108680  0.845560 -0.066024
# 2     pred_MLP  ALL_OTHERS  Asian_Female -0.115430  0.840174 -0.059261
#
#         AOD   T_Index
# 0 -0.304821  0.353863
# 1 -0.253887  0.430087
# 2 -0.308707  0.423372
#
# === Plot SPD/DI => Non-Asian_Female vs 'Asian_Female' ===

# %%
results_dir = "dataset/train_test_extracted_base"

df_results_sep_OF.to_csv(os.path.join(results_dir, "bias_results_sep_OF_all_demographics.csv"), index=False)
df_results_lumped_OF.to_csv(os.path.join(results_dir, "bias_results_lumped_OF_all_demographics.csv"), index=False)

df_results_sep_AF.to_csv(os.path.join(results_dir, "bias_results_sep_AF_all_demographics.csv"), index=False)
df_results_lumped_AF.to_csv(os.path.join(results_dir, "bias_results_lumped_AF_all_demographics.csv"), index=False)
