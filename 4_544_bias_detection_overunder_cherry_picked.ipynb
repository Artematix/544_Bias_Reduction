# %%
import os
import numpy as np
import pandas as pd

# Sklearn
from sklearn.metrics import accuracy_score, recall_score, f1_score
import joblib

# PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F

# AIF360
from aif360.datasets import BinaryLabelDataset
from aif360.metrics import ClassificationMetric

import seaborn as sns
import matplotlib.pyplot as plt

# %%
test_data = pd.read_csv('dataset/train_test_extracted_overunder/test_cherry_picked.csv')

race_map = {0: "Other", 1: "AfricanAmerican", 2: "Asian", 3: "Caucasian", 4: "Hispanic"}
gender_map = {0: "Female", 1: "Male"}

test_data['race_str'] = test_data['race'].map(race_map)
test_data['gender_str'] = test_data['gender'].map(gender_map)
test_data['race_gender'] = test_data['race_str'] + "_" + test_data['gender_str']

drop_cols = ['readmitted','race','gender','race_str','gender_str','race_gender',
             'race_AfricanAmerican','race_Asian','race_Caucasian','race_Hispanic','race_Other']
X_test = test_data.drop(columns=drop_cols)
y_test = test_data['readmitted']

print("X_test shape:", X_test.shape, "y_test shape:", y_test.shape)


model_paths = {
    'LogReg': 'models/overunder_cherry_picked/LogReg.joblib',
    'XGB':    'models/overunder_cherry_picked/XGB.joblib',
    'MLP':    'models/overunder_cherry_picked/MLP.pth'  # PyTorch model
}
# Out:
# X_test shape: (14924, 22) y_test shape: (14924,)

# %%
class SimpleNet(nn.Module):
    def __init__(self, input_dim, hidden_dim=64, num_classes=2):
        super(SimpleNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, num_classes)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        logits = self.fc2(x)
        return logits



for model_name, path in model_paths.items():
    print(f"\n=== Loading {model_name} ===")

    if model_name in ['LogReg','XGB']:
        # scikit-learn model
        model = joblib.load(path)


        if model_name == 'LogReg':
            scaler_path = "models/overunder_cherry_picked/scaler_LogReg.joblib"
            scaler = joblib.load(scaler_path)
            X_test_scaled = scaler.transform(X_test)
            y_pred = model.predict(X_test_scaled)
        elif model_name == 'XGB':
            y_pred = model.predict(X_test)

    else:

        input_dim = X_test.shape[1]
        mlp_model = SimpleNet(input_dim=input_dim, hidden_dim=64, num_classes=2)
        mlp_model.load_state_dict(torch.load(path))  # Load weights


        mlp_model.eval()
        X_test_t = torch.tensor(X_test.values, dtype=torch.float32)
        with torch.no_grad():
            logits = mlp_model(X_test_t)
            probs = F.softmax(logits, dim=1)
            y_pred = torch.argmax(probs, dim=1).numpy()

    acc = accuracy_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred, zero_division=0)
    f1 = f1_score(y_test, y_pred, zero_division=0)

    print(f"[{model_name}] Accuracy: {acc:.4f}, Recall: {rec:.4f}, F1: {f1:.4f}")

    # Store predictions for bias analysis
    pred_col = f"pred_{model_name}"
    test_data[pred_col] = y_pred
# Out:
# === Loading LogReg ===
# [LogReg] Accuracy: 0.6575, Recall: 0.4980, F1: 0.2507
#
# === Loading XGB ===
# [XGB] Accuracy: 0.6625, Recall: 0.5201, F1: 0.2618
#
# === Loading MLP ===
# [MLP] Accuracy: 0.5740, Recall: 0.5317, F1: 0.2231

# %%
def build_aif360_subset(df, label_col, pred_col, unpriv_group_val, priv_group_val):
    """
    Filters 'df' so it only contains rows where race_gender is either unpriv_group_val or priv_group_val.
    Then encodes 'race_gender' as 1 => unpriv, 0 => priv.
    Returns two BinaryLabelDatasets (one ground truth, one predicted).
    Also prints debug info on how many times label=1 vs 0 in truth & predictions.
    """

    # Filter DataFrame
    df_filtered = df[df['race_gender'].isin([unpriv_group_val, priv_group_val])].copy()
    if df_filtered.empty:
        return None, None

    # Binarize race_gender => 1 if unpriv, else 0
    df_filtered['race_gender'] = df_filtered['race_gender'].apply(
        lambda x: 1 if x == unpriv_group_val else 0
    )

    unpriv_count = (df_filtered['race_gender'] == 1).sum()
    priv_count   = (df_filtered['race_gender'] == 0).sum()

    # Build dataset_true
    df_true = df_filtered[['race_gender', label_col]].copy()
    df_true.rename(columns={label_col: 'label'}, inplace=True)

    # Count how many label=1 vs. 0 in ground truth
    true_ones  = (df_true['label'] == 1).sum()
    true_zeros = (df_true['label'] == 0).sum()

    dataset_true = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_true,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    # Build dataset_pred
    df_pred = df_filtered[['race_gender', pred_col]].copy()
    df_pred.rename(columns={pred_col: 'label'}, inplace=True)

    # Count how many label=1 vs. 0 in predictions
    pred_ones  = (df_pred['label'] == 1).sum()
    pred_zeros = (df_pred['label'] == 0).sum()

    dataset_pred = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_pred,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    # Debug prints
    print(f"\n[DEBUG] build_aif360_subset => unpriv='{unpriv_group_val}'(=1), "
          f"priv='{priv_group_val}'(=0)")
    print(f"   => #rows in subset: {len(df_filtered)} (unpriv_count={unpriv_count}, priv_count={priv_count})")
    print(f"   => GroundTruth: label=1 => {true_ones}, label=0 => {true_zeros}")
    print(f"   => Predictions: label=1 => {pred_ones}, label=0 => {pred_zeros}")

    return dataset_true, dataset_pred


def compute_bias_metrics(dataset_true, dataset_pred):
    metric = ClassificationMetric(
        dataset_true,
        dataset_pred,
        unprivileged_groups=[{'race_gender': 1}],
        privileged_groups=[{'race_gender': 0}]
    )
    spd = metric.statistical_parity_difference()
    di = metric.disparate_impact()
    eod = metric.equal_opportunity_difference()  
    aod = metric.average_odds_difference()       
    t_index = metric.theil_index()               
    return spd, di, eod, aod, t_index



def plot_fairness_bar(df, x_col, y_col, hue_col, title,
                      width=8, height=6, ref_line=None,
                      label_fontsize=8):

    plt.figure(figsize=(width, height))
    ax = sns.barplot(data=df, x=x_col, y=y_col, hue=hue_col)

    if ref_line is not None:
        plt.axhline(ref_line, color='black', linewidth=1)

    for container in ax.containers:
        ax.bar_label(container, fmt="%.2f", label_type='edge', 
                     padding=3, fontsize=label_fontsize)

    plt.title(title)
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()


def build_aif360_subset_lumped(df, label_col, pred_col, privileged_grp="Asian_Female"):
    """
    Instead of splitting each unpriv group individually,
    we lump "everything that is not privileged_grp" into unpriv (1).
    """
    # Copy entire df (no filter for specific groups)
    df_temp = df.copy()

    # Binarize: 1 if not privileged_grp, else 0
    df_temp['race_gender'] = df_temp['race_gender'].apply(
        lambda x: 0 if x == privileged_grp else 1
    )

    # Build dataset_true
    df_true = df_temp[['race_gender', label_col]].copy()
    df_true.rename(columns={label_col: 'label'}, inplace=True)
    dataset_true = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_true,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    # Build dataset_pred
    df_pred = df_temp[['race_gender', pred_col]].copy()
    df_pred.rename(columns={pred_col: 'label'}, inplace=True)
    dataset_pred = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_pred,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    return dataset_true, dataset_pred

# %%
print("\n=== (A) Bias Analysis per Subgroup vs. 'Other_Female' ===")

UNPRIV_GROUP_OF = "Other_Female"
all_race_genders = test_data['race_gender'].unique()
privileged_groups = [g for g in all_race_genders if g != UNPRIV_GROUP_OF]

results_sep_OF = []
model_predictions = ['pred_LogReg','pred_XGB','pred_MLP']

for model_col in model_predictions:
    print(f"\n--- Model: {model_col}, Unprivileged: {UNPRIV_GROUP_OF} ---")
    for priv_grp in privileged_groups:
        ds_true, ds_pred = build_aif360_subset(
            df=test_data,
            label_col='readmitted',
            pred_col=model_col,
            unpriv_group_val=UNPRIV_GROUP_OF, 
            priv_group_val=priv_grp           
        )
        if ds_true is None or ds_pred is None:
            print(f"   WARNING: No data for group={priv_grp}; skipping.")
            continue

        spd, di, eod, aod, t_index = compute_bias_metrics(ds_true, ds_pred)
        print(f"   Compare {UNPRIV_GROUP_OF} vs {priv_grp}: SPD={spd:.4f}, DI={di:.4f}")

        results_sep_OF.append({
            'Model': model_col,
            'UnprivGroup': UNPRIV_GROUP_OF,
            'PrivGroup': priv_grp,
            'SPD': spd,
            'DI': di,
            'EOD': eod,
            'AOD': aod,
            'T_Index': t_index
        })

df_results_sep_OF = pd.DataFrame(results_sep_OF)
print("\n=== Aggregated Bias Results (Individual Groups) ===\n", df_results_sep_OF)

print("\n=== Plot SPD/DI for each Subgroup vs. Other_Female ===")
plot_fairness_bar(
    df=df_results_sep_OF,
    x_col='PrivGroup',
    y_col='SPD',
    hue_col='Model',
    title=f"Statistical Parity Difference vs. {UNPRIV_GROUP_OF} (Unpriv)",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_sep_OF,
    x_col='PrivGroup',
    y_col='DI',
    hue_col='Model',
    title=f"Disparate Impact vs. {UNPRIV_GROUP_OF} (Unpriv)",
    ref_line=1
)


def build_aif360_subset_lumped_OF(df, label_col, pred_col):
    """
    Lump: 'Other_Female' => 1 (unpriv), everything else => 0 (priv).
    """
    df_temp = df.copy()
    df_temp['race_gender'] = df_temp['race_gender'].apply(
        lambda x: 1 if x == "Other_Female" else 0
    )
    # Build dataset_true
    df_true = df_temp[[ 'race_gender', label_col]].copy()
    df_true.rename(columns={label_col: 'label'}, inplace=True)
    dataset_true = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_true,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )
    # Build dataset_pred
    df_pred = df_temp[['race_gender', pred_col]].copy()
    df_pred.rename(columns={pred_col: 'label'}, inplace=True)
    dataset_pred = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_pred,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )
    return dataset_true, dataset_pred


print("\n=== (B) Lumps => 'Other_Female' unpriv, All Others => priv ===")
results_lumped_OF = []

for model_col in model_predictions:
    ds_true_lumped, ds_pred_lumped = build_aif360_subset_lumped_OF(
        df=test_data,
        label_col='readmitted',
        pred_col=model_col
    )
    spd, di, eod, aod, t_index = compute_bias_metrics(ds_true_lumped, ds_pred_lumped)
    print(f"[{model_col}] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD={spd:.4f}, DI={di:.4f}")
    results_lumped_OF.append({
        'Model': model_col,
        'UnprivGroup': "Other_Female",
        'PrivGroup': "ALL_OTHERS",
        'SPD': spd,
        'DI': di,
        'EOD': eod,
        'AOD': aod,
        'T_Index': t_index
    })

df_results_lumped_OF = pd.DataFrame(results_lumped_OF)
print("\n=== Aggregated Bias Results (Lumped) ===\n", df_results_lumped_OF)

print("\n=== Plot SPD/DI => 'Other_Female'(unpriv) vs ALL_OTHERS ===")
plot_fairness_bar(
    df=df_results_lumped_OF,
    x_col='UnprivGroup',
    y_col='SPD',
    hue_col='Model',
    title="Statistical Parity Difference (Other_Female vs. ALL_OTHERS)",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_lumped_OF,
    x_col='UnprivGroup',
    y_col='DI',
    hue_col='Model',
    title="Disparate Impact (Other_Female vs. ALL_OTHERS)",
    ref_line=1
)
# Out:
# === (A) Bias Analysis per Subgroup vs. 'Other_Female' ===
#
# --- Model: pred_LogReg, Unprivileged: Other_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Female'(=0)
#    => #rows in subset: 6077 (unpriv_count=136, priv_count=5941)
#    => GroundTruth: label=1 => 700, label=0 => 5377
#    => Predictions: label=1 => 2136, label=0 => 3941
#    Compare Other_Female vs Caucasian_Female: SPD=0.0587, DI=1.0907
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Male'(=0)
#    => #rows in subset: 5527 (unpriv_count=136, priv_count=5391)
#    => GroundTruth: label=1 => 637, label=0 => 4890
#    => Predictions: label=1 => 1822, label=0 => 3705
#    Compare Other_Female vs Caucasian_Male: SPD=0.0364, DI=1.0544
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Female'(=0)
#    => #rows in subset: 1931 (unpriv_count=136, priv_count=1795)
#    => GroundTruth: label=1 => 223, label=0 => 1708
#    => Predictions: label=1 => 665, label=0 => 1266
#    Compare Other_Female vs AfricanAmerican_Female: SPD=0.0541, DI=1.0830
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Male'(=0)
#    => #rows in subset: 293 (unpriv_count=136, priv_count=157)
#    => GroundTruth: label=1 => 32, label=0 => 261
#    => Predictions: label=1 => 85, label=0 => 208
#    Compare Other_Female vs Hispanic_Male: SPD=-0.0075, DI=0.9895
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Male'(=0)
#    => #rows in subset: 1256 (unpriv_count=136, priv_count=1120)
#    => GroundTruth: label=1 => 161, label=0 => 1095
#    => Predictions: label=1 => 441, label=0 => 815
#    Compare Other_Female vs AfricanAmerican_Male: SPD=0.0639, DI=1.0996
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Female'(=0)
#    => #rows in subset: 302 (unpriv_count=136, priv_count=166)
#    => GroundTruth: label=1 => 35, label=0 => 267
#    => Predictions: label=1 => 92, label=0 => 210
#    Compare Other_Female vs Hispanic_Female: SPD=0.0191, DI=1.0279
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Other_Male'(=0)
#    => #rows in subset: 250 (unpriv_count=136, priv_count=114)
#    => GroundTruth: label=1 => 26, label=0 => 224
#    => Predictions: label=1 => 82, label=0 => 168
#    Compare Other_Female vs Other_Male: SPD=0.0743, DI=1.1176
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 50, label=0 => 140
#    Compare Other_Female vs Asian_Female: SPD=-0.1089, DI=0.8663
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Male'(=0)
#    => #rows in subset: 186 (unpriv_count=136, priv_count=50)
#    => GroundTruth: label=1 => 23, label=0 => 163
#    => Predictions: label=1 => 51, label=0 => 135
#    Compare Other_Female vs Asian_Male: SPD=-0.0741, DI=0.9050
#
# --- Model: pred_XGB, Unprivileged: Other_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Female'(=0)
#    => #rows in subset: 6077 (unpriv_count=136, priv_count=5941)
#    => GroundTruth: label=1 => 700, label=0 => 5377
#    => Predictions: label=1 => 2238, label=0 => 3839
#    Compare Other_Female vs Caucasian_Female: SPD=0.0006, DI=1.0010
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Male'(=0)
#    => #rows in subset: 5527 (unpriv_count=136, priv_count=5391)
#    => GroundTruth: label=1 => 637, label=0 => 4890
#    => Predictions: label=1 => 1788, label=0 => 3739
#    Compare Other_Female vs Caucasian_Male: SPD=-0.0453, DI=0.9332
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Female'(=0)
#    => #rows in subset: 1931 (unpriv_count=136, priv_count=1795)
#    => GroundTruth: label=1 => 223, label=0 => 1708
#    => Predictions: label=1 => 643, label=0 => 1288
#    Compare Other_Female vs AfricanAmerican_Female: SPD=-0.0373, DI=0.9443
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Male'(=0)
#    => #rows in subset: 293 (unpriv_count=136, priv_count=157)
#    => GroundTruth: label=1 => 32, label=0 => 261
#    => Predictions: label=1 => 99, label=0 => 194
#    Compare Other_Female vs Hispanic_Male: SPD=-0.0555, DI=0.9193
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Male'(=0)
#    => #rows in subset: 1256 (unpriv_count=136, priv_count=1120)
#    => GroundTruth: label=1 => 161, label=0 => 1095
#    => Predictions: label=1 => 425, label=0 => 831
#    Compare Other_Female vs AfricanAmerican_Male: SPD=-0.0328, DI=0.9507
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Female'(=0)
#    => #rows in subset: 302 (unpriv_count=136, priv_count=166)
#    => GroundTruth: label=1 => 35, label=0 => 267
#    => Predictions: label=1 => 99, label=0 => 203
#    Compare Other_Female vs Hispanic_Female: SPD=-0.0725, DI=0.8972
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Other_Male'(=0)
#    => #rows in subset: 250 (unpriv_count=136, priv_count=114)
#    => GroundTruth: label=1 => 26, label=0 => 224
#    => Predictions: label=1 => 88, label=0 => 162
#    Compare Other_Female vs Other_Male: SPD=-0.0343, DI=0.9485
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 67, label=0 => 123
#    Compare Other_Female vs Asian_Female: SPD=-0.0528, DI=0.9229
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Male'(=0)
#    => #rows in subset: 186 (unpriv_count=136, priv_count=50)
#    => GroundTruth: label=1 => 23, label=0 => 163
#    => Predictions: label=1 => 59, label=0 => 127
#    Compare Other_Female vs Asian_Male: SPD=-0.1876, DI=0.7712
#
# --- Model: pred_MLP, Unprivileged: Other_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Female'(=0)
#    => #rows in subset: 6077 (unpriv_count=136, priv_count=5941)
#    => GroundTruth: label=1 => 700, label=0 => 5377
#    => Predictions: label=1 => 2728, label=0 => 3349
#    Compare Other_Female vs Caucasian_Female: SPD=-0.0071, DI=0.9871
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Male'(=0)
#    => #rows in subset: 5527 (unpriv_count=136, priv_count=5391)
#    => GroundTruth: label=1 => 637, label=0 => 4890
#    => Predictions: label=1 => 2317, label=0 => 3210
#    Compare Other_Female vs Caucasian_Male: SPD=-0.0376, DI=0.9354
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Female'(=0)
#    => #rows in subset: 1931 (unpriv_count=136, priv_count=1795)
#    => GroundTruth: label=1 => 223, label=0 => 1708
#    => Predictions: label=1 => 853, label=0 => 1078
#    Compare Other_Female vs AfricanAmerican_Female: SPD=-0.0152, DI=0.9728
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Male'(=0)
#    => #rows in subset: 293 (unpriv_count=136, priv_count=157)
#    => GroundTruth: label=1 => 32, label=0 => 261
#    => Predictions: label=1 => 121, label=0 => 172
#    Compare Other_Female vs Hispanic_Male: SPD=-0.0801, DI=0.8717
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Male'(=0)
#    => #rows in subset: 1256 (unpriv_count=136, priv_count=1120)
#    => GroundTruth: label=1 => 161, label=0 => 1095
#    => Predictions: label=1 => 554, label=0 => 702
#    Compare Other_Female vs AfricanAmerican_Male: SPD=-0.0166, DI=0.9704
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Female'(=0)
#    => #rows in subset: 302 (unpriv_count=136, priv_count=166)
#    => GroundTruth: label=1 => 35, label=0 => 267
#    => Predictions: label=1 => 122, label=0 => 180
#    Compare Other_Female vs Hispanic_Female: SPD=-0.0944, DI=0.8521
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Other_Male'(=0)
#    => #rows in subset: 250 (unpriv_count=136, priv_count=114)
#    => GroundTruth: label=1 => 26, label=0 => 224
#    => Predictions: label=1 => 107, label=0 => 143
#    Compare Other_Female vs Other_Male: SPD=-0.0611, DI=0.8990
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 86, label=0 => 104
#    Compare Other_Female vs Asian_Female: SPD=-0.0114, DI=0.9794
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Male'(=0)
#    => #rows in subset: 186 (unpriv_count=136, priv_count=50)
#    => GroundTruth: label=1 => 23, label=0 => 163
#    => Predictions: label=1 => 75, label=0 => 111
#    Compare Other_Female vs Asian_Male: SPD=-0.1959, DI=0.7353
#
# === Aggregated Bias Results (Individual Groups) ===
#            Model   UnprivGroup               PrivGroup       SPD        DI  \
# 0   pred_LogReg  Other_Female        Caucasian_Female  0.058685  1.090675
# 1   pred_LogReg  Other_Female          Caucasian_Male  0.036433  1.054423
# 2   pred_LogReg  Other_Female  AfricanAmerican_Female  0.054072  1.082956
# 3   pred_LogReg  Other_Female           Hispanic_Male -0.007493  0.989496
# 4   pred_LogReg  Other_Female    AfricanAmerican_Male  0.063918  1.099566
# 5   pred_LogReg  Other_Female         Hispanic_Female  0.019135  1.027864
# 6   pred_LogReg  Other_Female              Other_Male  0.074303  1.117647
# 7   pred_LogReg  Other_Female            Asian_Female -0.108932  0.866310
# 8   pred_LogReg  Other_Female              Asian_Male -0.074118  0.904977
# 9      pred_XGB  Other_Female        Caucasian_Female  0.000641  1.001015
# 10     pred_XGB  Other_Female          Caucasian_Male -0.045258  0.933210
# 11     pred_XGB  Other_Female  AfricanAmerican_Female -0.037285  0.944321
# 12     pred_XGB  Other_Female           Hispanic_Male -0.055545  0.919254
# 13     pred_XGB  Other_Female    AfricanAmerican_Male -0.032826  0.950651
# 14     pred_XGB  Other_Female         Hispanic_Female -0.072466  0.897185
# 15     pred_XGB  Other_Female              Other_Male -0.034314  0.948529
# 16     pred_XGB  Other_Female            Asian_Female -0.052832  0.922893
# 17     pred_XGB  Other_Female              Asian_Male -0.187647  0.771162
# 18     pred_MLP  Other_Female        Caucasian_Female -0.007136  0.987054
# 19     pred_MLP  Other_Female          Caucasian_Male -0.037593  0.935376
# 20     pred_MLP  Other_Female  AfricanAmerican_Female -0.015214  0.972800
# 21     pred_MLP  Other_Female           Hispanic_Male -0.080086  0.871699
# 22     pred_MLP  Other_Female    AfricanAmerican_Male -0.016597  0.970401
# 23     pred_MLP  Other_Female         Hispanic_Female -0.094437  0.852109
# 24     pred_MLP  Other_Female              Other_Male -0.061146  0.898977
# 25     pred_MLP  Other_Female            Asian_Female -0.011438  0.979412
# 26     pred_MLP  Other_Female              Asian_Male -0.195882  0.735294
#
#          EOD       AOD   T_Index
# 0   0.069671  0.039967  0.372037
# 1   0.049317  0.011330  0.348267
# 2   0.063074  0.042513  0.359553
# 3  -0.003971  0.033729  0.286177
# 4   0.074033  0.038765  0.365855
# 5   0.019167  0.053701  0.299702
# 6   0.076911  0.163455  0.332207
# 7  -0.054379 -0.277189  0.273953
# 8  -0.062712 -0.081356  0.268440
# 9   0.024800 -0.054071  0.390760
# 10 -0.020902 -0.100650  0.336152
# 11 -0.019518 -0.069922  0.336096
# 12 -0.028328 -0.097497  0.339380
# 13 -0.017019 -0.072612  0.336582
# 14 -0.067000 -0.043304  0.308054
# 15 -0.010713 -0.026190  0.351384
# 16  0.011299 -0.244350  0.360328
# 17 -0.188701 -0.127684  0.289047
# 18  0.022091 -0.081737  0.515945
# 19 -0.009345 -0.108918  0.472621
# 20  0.009903 -0.075672  0.496133
# 21 -0.044625 -0.169138  0.450395
# 22  0.009515 -0.087123  0.489325
# 23 -0.072972 -0.132891  0.423611
# 24 -0.037896 -0.067559  0.457186
# 25  0.043079 -0.172905  0.492468
# 26 -0.170810 -0.246516  0.410671
#
# === Plot SPD/DI for each Subgroup vs. Other_Female ===
# === (B) Lumps => 'Other_Female' unpriv, All Others => priv ===
# [pred_LogReg] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD=0.0483, DI=1.0735
# [pred_XGB] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD=-0.0257, DI=0.9609
# [pred_MLP] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD=-0.0228, DI=0.9598
#
# === Aggregated Bias Results (Lumped) ===
#           Model   UnprivGroup   PrivGroup       SPD        DI       EOD  \
# 0  pred_LogReg  Other_Female  ALL_OTHERS  0.048322  1.073487  0.059543
# 1     pred_XGB  Other_Female  ALL_OTHERS -0.025748  0.960875 -0.003064
# 2     pred_MLP  Other_Female  ALL_OTHERS -0.022761  0.959849  0.005328
#
#         AOD   T_Index
# 0  0.028742  0.360990
# 1 -0.075595  0.356614
# 2 -0.093585  0.492687
#
# === Plot SPD/DI => 'Other_Female'(unpriv) vs ALL_OTHERS ===

# %%
print("\n=== (A) Bias Analysis: Subgroup vs. 'Asian_Female' (Privileged) ===")

PRIV_GROUP_AF = "Asian_Female"
# all subgroups that are NOT 'Asian_Female' are tested as unprivileged, one by one
all_race_genders = test_data['race_gender'].unique()
unprivileged_groups = [g for g in all_race_genders if g != PRIV_GROUP_AF]

results_sep_AF = []
model_predictions = ['pred_LogReg','pred_XGB','pred_MLP']

for model_col in model_predictions:
    print(f"\n--- Model: {model_col}, Privileged: {PRIV_GROUP_AF} ---")
    for unpriv_grp in unprivileged_groups:
        ds_true, ds_pred = build_aif360_subset(
            df=test_data,
            label_col='readmitted',
            pred_col=model_col,
            unpriv_group_val=unpriv_grp,      # => 1
            priv_group_val=PRIV_GROUP_AF      # => 0
        )
        if ds_true is None or ds_pred is None:
            # If no rows match unpriv_grp or PRIV_GROUP_AF in test_data['race_gender']
            continue

        spd, di, eod, aod, t_index = compute_bias_metrics(ds_true, ds_pred)
        print(f"   Compare unpriv={unpriv_grp} vs priv={PRIV_GROUP_AF}: SPD={spd:.4f}, DI={di:.4f}")

        results_sep_AF.append({
            'Model': model_col,
            'UnprivGroup': unpriv_grp,
            'PrivGroup': PRIV_GROUP_AF,
            'SPD': spd,
            'DI': di,
            'EOD': eod,
            'AOD': aod,
            'T_Index': t_index
        })

df_results_sep_AF = pd.DataFrame(results_sep_AF)
print("\n=== Aggregated Bias Results (Individual Subgroups) ===\n", df_results_sep_AF)

# Plot SPD & DI
print("\n=== Plot SPD/DI for each Unpriv Subgroup vs. 'Asian_Female' ===")
plot_fairness_bar(
    df=df_results_sep_AF,
    x_col='UnprivGroup',
    y_col='SPD',
    hue_col='Model',
    title=f"Statistical Parity Difference vs. {PRIV_GROUP_AF}",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_sep_AF,
    x_col='UnprivGroup',
    y_col='DI',
    hue_col='Model',
    title=f"Disparate Impact vs. {PRIV_GROUP_AF}",
    ref_line=1
)


print("\n=== (B) Lumped Bias => 'Asian_Female' privileged vs. ALL_OTHERS unpriv ===")

results_lumped_AF = []

for model_col in model_predictions:
    ds_true_lumped, ds_pred_lumped = build_aif360_subset_lumped(
        df=test_data,
        label_col='readmitted',
        pred_col=model_col,
        privileged_grp=PRIV_GROUP_AF
    )
    # This lumps everything that is not 'Asian_Female' => 1, 
    # 'Asian_Female' => 0

    spd, di, eod, aod, t_index = compute_bias_metrics(ds_true_lumped, ds_pred_lumped)
    print(f"[{model_col}] Non-Asian_Female vs {PRIV_GROUP_AF}: SPD={spd:.4f}, DI={di:.4f}")

    results_lumped_AF.append({
        'Model': model_col,
        'UnprivGroup': "ALL_OTHERS",
        'PrivGroup': PRIV_GROUP_AF,
        'SPD': spd,
        'DI': di,
        'EOD': eod,
        'AOD': aod,
        'T_Index': t_index
    })

df_results_lumped_AF = pd.DataFrame(results_lumped_AF)
print("\n=== Aggregated Bias Results (Lumped) ===\n", df_results_lumped_AF)

print("\n=== Plot SPD/DI => Non-Asian_Female vs 'Asian_Female' ===")
plot_fairness_bar(
    df=df_results_lumped_AF,
    x_col='UnprivGroup',
    y_col='SPD',
    hue_col='Model',
    title=f"Statistical Parity Difference (All Non-Asian_Female vs. {PRIV_GROUP_AF})",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_lumped_AF,
    x_col='UnprivGroup',
    y_col='DI',
    hue_col='Model',
    title=f"Disparate Impact (All Non-Asian_Female vs. {PRIV_GROUP_AF})",
    ref_line=1
)
# Out:
# === (A) Bias Analysis: Subgroup vs. 'Asian_Female' (Privileged) ===
#
# --- Model: pred_LogReg, Privileged: Asian_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5995 (unpriv_count=5941, priv_count=54)
#    => GroundTruth: label=1 => 688, label=0 => 5307
#    => Predictions: label=1 => 2106, label=0 => 3889
#    Compare unpriv=Caucasian_Female vs priv=Asian_Female: SPD=-0.1676, DI=0.7943
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5445 (unpriv_count=5391, priv_count=54)
#    => GroundTruth: label=1 => 625, label=0 => 4820
#    => Predictions: label=1 => 1792, label=0 => 3653
#    Compare unpriv=Caucasian_Male vs priv=Asian_Female: SPD=-0.1454, DI=0.8216
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1849 (unpriv_count=1795, priv_count=54)
#    => GroundTruth: label=1 => 211, label=0 => 1638
#    => Predictions: label=1 => 635, label=0 => 1214
#    Compare unpriv=AfricanAmerican_Female vs priv=Asian_Female: SPD=-0.1630, DI=0.7999
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 211 (unpriv_count=157, priv_count=54)
#    => GroundTruth: label=1 => 20, label=0 => 191
#    => Predictions: label=1 => 55, label=0 => 156
#    Compare unpriv=Hispanic_Male vs priv=Asian_Female: SPD=-0.1014, DI=0.8755
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1174 (unpriv_count=1120, priv_count=54)
#    => GroundTruth: label=1 => 149, label=0 => 1025
#    => Predictions: label=1 => 411, label=0 => 763
#    Compare unpriv=AfricanAmerican_Male vs priv=Asian_Female: SPD=-0.1729, DI=0.7879
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 220 (unpriv_count=166, priv_count=54)
#    => GroundTruth: label=1 => 23, label=0 => 197
#    => Predictions: label=1 => 62, label=0 => 158
#    Compare unpriv=Hispanic_Female vs priv=Asian_Female: SPD=-0.1281, DI=0.8428
#
# [DEBUG] build_aif360_subset => unpriv='Other_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 168 (unpriv_count=114, priv_count=54)
#    => GroundTruth: label=1 => 14, label=0 => 154
#    => Predictions: label=1 => 52, label=0 => 116
#    Compare unpriv=Other_Male vs priv=Asian_Female: SPD=-0.1832, DI=0.7751
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 50, label=0 => 140
#    Compare unpriv=Other_Female vs priv=Asian_Female: SPD=-0.1089, DI=0.8663
#
# [DEBUG] build_aif360_subset => unpriv='Asian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 104 (unpriv_count=50, priv_count=54)
#    => GroundTruth: label=1 => 11, label=0 => 93
#    => Predictions: label=1 => 21, label=0 => 83
#    Compare unpriv=Asian_Male vs priv=Asian_Female: SPD=-0.0348, DI=0.9573
#
# --- Model: pred_XGB, Privileged: Asian_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5995 (unpriv_count=5941, priv_count=54)
#    => GroundTruth: label=1 => 688, label=0 => 5307
#    => Predictions: label=1 => 2205, label=0 => 3790
#    Compare unpriv=Caucasian_Female vs priv=Asian_Female: SPD=-0.0535, DI=0.9220
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5445 (unpriv_count=5391, priv_count=54)
#    => GroundTruth: label=1 => 625, label=0 => 4820
#    => Predictions: label=1 => 1755, label=0 => 3690
#    Compare unpriv=Caucasian_Male vs priv=Asian_Female: SPD=-0.0076, DI=0.9889
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1849 (unpriv_count=1795, priv_count=54)
#    => GroundTruth: label=1 => 211, label=0 => 1638
#    => Predictions: label=1 => 610, label=0 => 1239
#    Compare unpriv=AfricanAmerican_Female vs priv=Asian_Female: SPD=-0.0155, DI=0.9773
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 211 (unpriv_count=157, priv_count=54)
#    => GroundTruth: label=1 => 20, label=0 => 191
#    => Predictions: label=1 => 66, label=0 => 145
#    Compare unpriv=Hispanic_Male vs priv=Asian_Female: SPD=0.0027, DI=1.0040
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1174 (unpriv_count=1120, priv_count=54)
#    => GroundTruth: label=1 => 149, label=0 => 1025
#    => Predictions: label=1 => 392, label=0 => 782
#    Compare unpriv=AfricanAmerican_Male vs priv=Asian_Female: SPD=-0.0200, DI=0.9708
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 220 (unpriv_count=166, priv_count=54)
#    => GroundTruth: label=1 => 23, label=0 => 197
#    => Predictions: label=1 => 66, label=0 => 154
#    Compare unpriv=Hispanic_Female vs priv=Asian_Female: SPD=0.0196, DI=1.0287
#
# [DEBUG] build_aif360_subset => unpriv='Other_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 168 (unpriv_count=114, priv_count=54)
#    => GroundTruth: label=1 => 14, label=0 => 154
#    => Predictions: label=1 => 55, label=0 => 113
#    Compare unpriv=Other_Male vs priv=Asian_Female: SPD=-0.0185, DI=0.9730
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 67, label=0 => 123
#    Compare unpriv=Other_Female vs priv=Asian_Female: SPD=-0.0528, DI=0.9229
#
# [DEBUG] build_aif360_subset => unpriv='Asian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 104 (unpriv_count=50, priv_count=54)
#    => GroundTruth: label=1 => 11, label=0 => 93
#    => Predictions: label=1 => 26, label=0 => 78
#    Compare unpriv=Asian_Male vs priv=Asian_Female: SPD=0.1348, DI=1.1968
#
# --- Model: pred_MLP, Privileged: Asian_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5995 (unpriv_count=5941, priv_count=54)
#    => GroundTruth: label=1 => 688, label=0 => 5307
#    => Predictions: label=1 => 2690, label=0 => 3305
#    Compare unpriv=Caucasian_Female vs priv=Asian_Female: SPD=-0.0043, DI=0.9923
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5445 (unpriv_count=5391, priv_count=54)
#    => GroundTruth: label=1 => 625, label=0 => 4820
#    => Predictions: label=1 => 2279, label=0 => 3166
#    Compare unpriv=Caucasian_Male vs priv=Asian_Female: SPD=0.0262, DI=1.0471
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1849 (unpriv_count=1795, priv_count=54)
#    => GroundTruth: label=1 => 211, label=0 => 1638
#    => Predictions: label=1 => 815, label=0 => 1034
#    Compare unpriv=AfricanAmerican_Female vs priv=Asian_Female: SPD=0.0038, DI=1.0068
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 211 (unpriv_count=157, priv_count=54)
#    => GroundTruth: label=1 => 20, label=0 => 191
#    => Predictions: label=1 => 83, label=0 => 128
#    Compare unpriv=Hispanic_Male vs priv=Asian_Female: SPD=0.0686, DI=1.1236
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1174 (unpriv_count=1120, priv_count=54)
#    => GroundTruth: label=1 => 149, label=0 => 1025
#    => Predictions: label=1 => 516, label=0 => 658
#    Compare unpriv=AfricanAmerican_Male vs priv=Asian_Female: SPD=0.0052, DI=1.0093
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 220 (unpriv_count=166, priv_count=54)
#    => GroundTruth: label=1 => 23, label=0 => 197
#    => Predictions: label=1 => 84, label=0 => 136
#    Compare unpriv=Hispanic_Female vs priv=Asian_Female: SPD=0.0830, DI=1.1494
#
# [DEBUG] build_aif360_subset => unpriv='Other_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 168 (unpriv_count=114, priv_count=54)
#    => GroundTruth: label=1 => 14, label=0 => 154
#    => Predictions: label=1 => 69, label=0 => 99
#    Compare unpriv=Other_Male vs priv=Asian_Female: SPD=0.0497, DI=1.0895
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 86, label=0 => 104
#    Compare unpriv=Other_Female vs priv=Asian_Female: SPD=-0.0114, DI=0.9794
#
# [DEBUG] build_aif360_subset => unpriv='Asian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 104 (unpriv_count=50, priv_count=54)
#    => GroundTruth: label=1 => 11, label=0 => 93
#    => Predictions: label=1 => 37, label=0 => 67
#    Compare unpriv=Asian_Male vs priv=Asian_Female: SPD=0.1844, DI=1.3320
#
# === Aggregated Bias Results (Individual Subgroups) ===
#            Model             UnprivGroup     PrivGroup       SPD        DI  \
# 0   pred_LogReg        Caucasian_Female  Asian_Female -0.167617  0.794288
# 1   pred_LogReg          Caucasian_Male  Asian_Female -0.145366  0.821597
# 2   pred_LogReg  AfricanAmerican_Female  Asian_Female -0.163004  0.799949
# 3   pred_LogReg           Hispanic_Male  Asian_Female -0.101439  0.875507
# 4   pred_LogReg    AfricanAmerican_Male  Asian_Female -0.172851  0.787865
# 5   pred_LogReg         Hispanic_Female  Asian_Female -0.128068  0.842826
# 6   pred_LogReg              Other_Male  Asian_Female -0.183236  0.775120
# 7   pred_LogReg            Other_Female  Asian_Female -0.108932  0.866310
# 8   pred_LogReg              Asian_Male  Asian_Female -0.034815  0.957273
# 9      pred_XGB        Caucasian_Female  Asian_Female -0.053473  0.921958
# 10     pred_XGB          Caucasian_Male  Asian_Female -0.007574  0.988946
# 11     pred_XGB  AfricanAmerican_Female  Asian_Female -0.015547  0.977309
# 12     pred_XGB           Hispanic_Male  Asian_Female  0.002713  1.003959
# 13     pred_XGB    AfricanAmerican_Male  Asian_Female -0.020007  0.970801
# 14     pred_XGB         Hispanic_Female  Asian_Female  0.019634  1.028655
# 15     pred_XGB              Other_Male  Asian_Female -0.018519  0.972973
# 16     pred_XGB            Other_Female  Asian_Female -0.052832  0.922893
# 17     pred_XGB              Asian_Male  Asian_Female  0.134815  1.196757
# 18     pred_MLP        Caucasian_Female  Asian_Female -0.004302  0.992257
# 19     pred_MLP          Caucasian_Male  Asian_Female  0.026155  1.047078
# 20     pred_MLP  AfricanAmerican_Female  Asian_Female  0.003776  1.006797
# 21     pred_MLP           Hispanic_Male  Asian_Female  0.068648  1.123567
# 22     pred_MLP    AfricanAmerican_Male  Asian_Female  0.005159  1.009286
# 23     pred_MLP         Hispanic_Female  Asian_Female  0.082999  1.149398
# 24     pred_MLP              Other_Male  Asian_Female  0.049708  1.089474
# 25     pred_MLP            Other_Female  Asian_Female -0.011438  0.979412
# 26     pred_MLP              Asian_Male  Asian_Female  0.184444  1.332000
#
#          EOD       AOD   T_Index
# 0  -0.124049 -0.317157  0.372862
# 1  -0.103695 -0.288520  0.348797
# 2  -0.117453 -0.319702  0.361648
# 3  -0.050408 -0.310918  0.275894
# 4  -0.128412 -0.315954  0.369577
# 5  -0.073546 -0.330891  0.294699
# 6  -0.131289 -0.440645  0.341740
# 7  -0.054379 -0.277189  0.273953
# 8   0.008333 -0.195833  0.233826
# 9  -0.013501 -0.190279  0.391743
# 10  0.032202 -0.143700  0.336372
# 11  0.030818 -0.174429  0.336776
# 12  0.039627 -0.146853  0.346734
# 13  0.028318 -0.171738  0.337634
# 14  0.078300 -0.201046  0.303632
# 15  0.022013 -0.218160  0.367103
# 16  0.011299 -0.244350  0.360328
# 17  0.200000 -0.116667  0.264789
# 18  0.020988 -0.091168  0.517481
# 19  0.052424 -0.063987  0.473600
# 20  0.033176 -0.097233  0.500177
# 21  0.087704 -0.003767  0.467048
# 22  0.033564 -0.085782  0.495097
# 23  0.116051 -0.040013  0.429349
# 24  0.080975 -0.105346  0.482453
# 25  0.043079 -0.172905  0.492468
# 26  0.213889  0.073611  0.412093
#
# === Plot SPD/DI for each Unpriv Subgroup vs. 'Asian_Female' ===
# === (B) Lumped Bias => 'Asian_Female' privileged vs. ALL_OTHERS unpriv ===
# [pred_LogReg] Non-Asian_Female vs Asian_Female: SPD=-0.1574, DI=0.8068
# [pred_XGB] Non-Asian_Female vs Asian_Female: SPD=-0.0274, DI=0.9600
# [pred_MLP] Non-Asian_Female vs Asian_Female: SPD=0.0112, DI=1.0201
#
# === Aggregated Bias Results (Lumped) ===
#           Model UnprivGroup     PrivGroup       SPD        DI       EOD  \
# 0  pred_LogReg  ALL_OTHERS  Asian_Female -0.157384  0.806847 -0.113804
# 1     pred_XGB  ALL_OTHERS  Asian_Female -0.027418  0.959985  0.014388
# 2     pred_MLP  ALL_OTHERS  Asian_Female  0.011156  1.020081  0.037937
#
#         AOD   T_Index
# 0 -0.306756  0.360990
# 1 -0.170139  0.356614
# 2 -0.080584  0.492687
#
# === Plot SPD/DI => Non-Asian_Female vs 'Asian_Female' ===

# %%
results_dir = "dataset/train_test_extracted_overunder"

df_results_sep_OF.to_csv(os.path.join(results_dir, "bias_results_sep_OF_cherry_picked.csv"), index=False)
df_results_lumped_OF.to_csv(os.path.join(results_dir, "bias_results_lumped_OF_cherry_picked.csv"), index=False)

df_results_sep_AF.to_csv(os.path.join(results_dir, "bias_results_sep_AF_cherry_picked.csv"), index=False)
df_results_lumped_AF.to_csv(os.path.join(results_dir, "bias_results_lumped_AF_cherry_picked.csv"), index=False)
