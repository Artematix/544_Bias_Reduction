# %%
import os
import numpy as np
import pandas as pd

# Sklearn
from sklearn.metrics import accuracy_score, recall_score, f1_score
import joblib

# PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F

# AIF360
from aif360.datasets import BinaryLabelDataset
from aif360.metrics import ClassificationMetric

import seaborn as sns
import matplotlib.pyplot as plt

# %%
test_data = pd.read_csv('dataset/train_test_extracted_overunder/test_all_demographics.csv')

race_map = {0: "Other", 1: "AfricanAmerican", 2: "Asian", 3: "Caucasian", 4: "Hispanic"}
gender_map = {0: "Female", 1: "Male"}

test_data['race_str'] = test_data['race'].map(race_map)
test_data['gender_str'] = test_data['gender'].map(gender_map)
test_data['race_gender'] = test_data['race_str'] + "_" + test_data['gender_str']

drop_cols = ['readmitted','race','gender','race_str','gender_str','race_gender',
             'race_AfricanAmerican','race_Asian','race_Caucasian','race_Hispanic','race_Other']
X_test = test_data.drop(columns=drop_cols)
y_test = test_data['readmitted']

print("X_test shape:", X_test.shape, "y_test shape:", y_test.shape)


model_paths = {
    'LogReg': 'models/overunder_all_demographics/LogReg.joblib',
    'XGB':    'models/overunder_all_demographics/XGB.joblib',
    'MLP':    'models/overunder_all_demographics/MLP.pth'  # PyTorch model
}
# Out:
# X_test shape: (14924, 25) y_test shape: (14924,)

# %%
class SimpleNet(nn.Module):
    def __init__(self, input_dim, hidden_dim=64, num_classes=2):
        super(SimpleNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, num_classes)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        logits = self.fc2(x)
        return logits



for model_name, path in model_paths.items():
    print(f"\n=== Loading {model_name} ===")

    if model_name in ['LogReg','XGB']:
        # scikit-learn model
        model = joblib.load(path)


        if model_name == 'LogReg':
            scaler_path = "models/overunder_all_demographics/scaler_LogReg.joblib"
            scaler = joblib.load(scaler_path)
            X_test_scaled = scaler.transform(X_test)
            y_pred = model.predict(X_test_scaled)
        elif model_name == 'XGB':    
            y_pred = model.predict(X_test)

    else:
        # PyTorch MLP
        input_dim = X_test.shape[1]
        mlp_model = SimpleNet(input_dim=input_dim, hidden_dim=64, num_classes=2)
        mlp_model.load_state_dict(torch.load(path))  # Load weights


        mlp_model.eval()
        X_test_t = torch.tensor(X_test.values, dtype=torch.float32)
        with torch.no_grad():
            logits = mlp_model(X_test_t)
            probs = F.softmax(logits, dim=1)
            y_pred = torch.argmax(probs, dim=1).numpy()

    acc = accuracy_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred, zero_division=0)
    f1 = f1_score(y_test, y_pred, zero_division=0)

    print(f"[{model_name}] Accuracy: {acc:.4f}, Recall: {rec:.4f}, F1: {f1:.4f}")

    # Store predictions for bias analysis
    pred_col = f"pred_{model_name}"
    test_data[pred_col] = y_pred
# Out:
# === Loading LogReg ===
# [LogReg] Accuracy: 0.6574, Recall: 0.4886, F1: 0.2471
#
# === Loading XGB ===
# [XGB] Accuracy: 0.6469, Recall: 0.5387, F1: 0.2599
#
# === Loading MLP ===
# [MLP] Accuracy: 0.6201, Recall: 0.5079, F1: 0.2353

# %%
def build_aif360_subset(df, label_col, pred_col, unpriv_group_val, priv_group_val):
    """
    Filters 'df' so it only contains rows where race_gender is either unpriv_group_val or priv_group_val.
    Then encodes 'race_gender' as 1 => unpriv, 0 => priv.
    Returns two BinaryLabelDatasets (one ground truth, one predicted).
    Also prints debug info on how many times label=1 vs 0 in truth & predictions.
    """

    # Filter DataFrame
    df_filtered = df[df['race_gender'].isin([unpriv_group_val, priv_group_val])].copy()
    if df_filtered.empty:
        return None, None

    # Binarize race_gender => 1 if unpriv, else 0
    df_filtered['race_gender'] = df_filtered['race_gender'].apply(
        lambda x: 1 if x == unpriv_group_val else 0
    )

    unpriv_count = (df_filtered['race_gender'] == 1).sum()
    priv_count   = (df_filtered['race_gender'] == 0).sum()

    # Build dataset_true
    df_true = df_filtered[['race_gender', label_col]].copy()
    df_true.rename(columns={label_col: 'label'}, inplace=True)

    # Count how many label=1 vs. 0 in ground truth
    true_ones  = (df_true['label'] == 1).sum()
    true_zeros = (df_true['label'] == 0).sum()

    dataset_true = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_true,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    # Build dataset_pred
    df_pred = df_filtered[['race_gender', pred_col]].copy()
    df_pred.rename(columns={pred_col: 'label'}, inplace=True)

    # Count how many label=1 vs. 0 in predictions
    pred_ones  = (df_pred['label'] == 1).sum()
    pred_zeros = (df_pred['label'] == 0).sum()

    dataset_pred = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_pred,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    # Debug prints
    print(f"\n[DEBUG] build_aif360_subset => unpriv='{unpriv_group_val}'(=1), "
          f"priv='{priv_group_val}'(=0)")
    print(f"   => #rows in subset: {len(df_filtered)} (unpriv_count={unpriv_count}, priv_count={priv_count})")
    print(f"   => GroundTruth: label=1 => {true_ones}, label=0 => {true_zeros}")
    print(f"   => Predictions: label=1 => {pred_ones}, label=0 => {pred_zeros}")

    return dataset_true, dataset_pred


def compute_bias_metrics(dataset_true, dataset_pred):
    metric = ClassificationMetric(
        dataset_true,
        dataset_pred,
        unprivileged_groups=[{'race_gender': 1}],
        privileged_groups=[{'race_gender': 0}]
    )
    spd = metric.statistical_parity_difference()
    di = metric.disparate_impact()
    eod = metric.equal_opportunity_difference()  
    aod = metric.average_odds_difference()       
    t_index = metric.theil_index()               
    return spd, di, eod, aod, t_index



def plot_fairness_bar(df, x_col, y_col, hue_col, title,
                      width=8, height=6, ref_line=None,
                      label_fontsize=8):

    plt.figure(figsize=(width, height))
    ax = sns.barplot(data=df, x=x_col, y=y_col, hue=hue_col)

    if ref_line is not None:
        plt.axhline(ref_line, color='black', linewidth=1)

    for container in ax.containers:
        ax.bar_label(container, fmt="%.2f", label_type='edge', 
                     padding=3, fontsize=label_fontsize)

    plt.title(title)
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()


def build_aif360_subset_lumped(df, label_col, pred_col, privileged_grp="Asian_Female"):
    """
    Instead of splitting each unpriv group individually,
    we lump "everything that is not privileged_grp" into unpriv (1).
    """
    # Copy entire df (no filter for specific groups)
    df_temp = df.copy()

    # Binarize: 1 if not privileged_grp, else 0
    df_temp['race_gender'] = df_temp['race_gender'].apply(
        lambda x: 0 if x == privileged_grp else 1
    )

    # Build dataset_true
    df_true = df_temp[['race_gender', label_col]].copy()
    df_true.rename(columns={label_col: 'label'}, inplace=True)
    dataset_true = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_true,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    # Build dataset_pred
    df_pred = df_temp[['race_gender', pred_col]].copy()
    df_pred.rename(columns={pred_col: 'label'}, inplace=True)
    dataset_pred = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_pred,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    return dataset_true, dataset_pred

# %%
print("\n=== (A) Bias Analysis per Subgroup vs. 'Other_Female' ===")

UNPRIV_GROUP_OF = "Other_Female"
all_race_genders = test_data['race_gender'].unique()
privileged_groups = [g for g in all_race_genders if g != UNPRIV_GROUP_OF]

results_sep_OF = []
model_predictions = ['pred_LogReg','pred_XGB','pred_MLP']

for model_col in model_predictions:
    print(f"\n--- Model: {model_col}, Unprivileged: {UNPRIV_GROUP_OF} ---")
    for priv_grp in privileged_groups:
        ds_true, ds_pred = build_aif360_subset(
            df=test_data,
            label_col='readmitted',
            pred_col=model_col,
            unpriv_group_val=UNPRIV_GROUP_OF, 
            priv_group_val=priv_grp           
        )
        if ds_true is None or ds_pred is None:
            print(f"   WARNING: No data for group={priv_grp}; skipping.")
            continue

        spd, di, eod, aod, t_index = compute_bias_metrics(ds_true, ds_pred)
        print(f"   Compare {UNPRIV_GROUP_OF} vs {priv_grp}: SPD={spd:.4f}, DI={di:.4f}")

        results_sep_OF.append({
            'Model': model_col,
            'UnprivGroup': UNPRIV_GROUP_OF,
            'PrivGroup': priv_grp,
            'SPD': spd,
            'DI': di,
            'EOD': eod,
            'AOD': aod,
            'T_Index': t_index
        })

df_results_sep_OF = pd.DataFrame(results_sep_OF)
print("\n=== Aggregated Bias Results (Individual Groups) ===\n", df_results_sep_OF)

print("\n=== Plot SPD/DI for each Subgroup vs. Other_Female ===")
plot_fairness_bar(
    df=df_results_sep_OF,
    x_col='PrivGroup',
    y_col='SPD',
    hue_col='Model',
    title=f"Statistical Parity Difference vs. {UNPRIV_GROUP_OF} (Unpriv)",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_sep_OF,
    x_col='PrivGroup',
    y_col='DI',
    hue_col='Model',
    title=f"Disparate Impact vs. {UNPRIV_GROUP_OF} (Unpriv)",
    ref_line=1
)


def build_aif360_subset_lumped_OF(df, label_col, pred_col):
    """
    Lump: 'Other_Female' => 1 (unpriv), everything else => 0 (priv).
    """
    df_temp = df.copy()
    df_temp['race_gender'] = df_temp['race_gender'].apply(
        lambda x: 1 if x == "Other_Female" else 0
    )
    # Build dataset_true
    df_true = df_temp[[ 'race_gender', label_col]].copy()
    df_true.rename(columns={label_col: 'label'}, inplace=True)
    dataset_true = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_true,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )
    # Build dataset_pred
    df_pred = df_temp[['race_gender', pred_col]].copy()
    df_pred.rename(columns={pred_col: 'label'}, inplace=True)
    dataset_pred = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_pred,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )
    return dataset_true, dataset_pred


print("\n=== (B) Lumps => 'Other_Female' unpriv, All Others => priv ===")
results_lumped_OF = []

for model_col in model_predictions:
    ds_true_lumped, ds_pred_lumped = build_aif360_subset_lumped_OF(
        df=test_data,
        label_col='readmitted',
        pred_col=model_col
    )
    spd, di, eod, aod, t_index = compute_bias_metrics(ds_true_lumped, ds_pred_lumped)
    print(f"[{model_col}] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD={spd:.4f}, DI={di:.4f}")
    results_lumped_OF.append({
        'Model': model_col,
        'UnprivGroup': "Other_Female",
        'PrivGroup': "ALL_OTHERS",
        'SPD': spd,
        'DI': di,
        'EOD': eod,
        'AOD': aod,
        'T_Index': t_index
    })

df_results_lumped_OF = pd.DataFrame(results_lumped_OF)
print("\n=== Aggregated Bias Results (Lumped) ===\n", df_results_lumped_OF)

print("\n=== Plot SPD/DI => 'Other_Female'(unpriv) vs ALL_OTHERS ===")
plot_fairness_bar(
    df=df_results_lumped_OF,
    x_col='UnprivGroup',
    y_col='SPD',
    hue_col='Model',
    title="Statistical Parity Difference (Other_Female vs. ALL_OTHERS)",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_lumped_OF,
    x_col='UnprivGroup',
    y_col='DI',
    hue_col='Model',
    title="Disparate Impact (Other_Female vs. ALL_OTHERS)",
    ref_line=1
)
# Out:
# === (A) Bias Analysis per Subgroup vs. 'Other_Female' ===
#
# --- Model: pred_LogReg, Unprivileged: Other_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Female'(=0)
#    => #rows in subset: 6077 (unpriv_count=136, priv_count=5941)
#    => GroundTruth: label=1 => 700, label=0 => 5377
#    => Predictions: label=1 => 2139, label=0 => 3938
#    Compare Other_Female vs Caucasian_Female: SPD=0.0441, DI=1.0682
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Male'(=0)
#    => #rows in subset: 5527 (unpriv_count=136, priv_count=5391)
#    => GroundTruth: label=1 => 637, label=0 => 4890
#    => Predictions: label=1 => 1833, label=0 => 3694
#    Compare Other_Female vs Caucasian_Male: SPD=0.0234, DI=1.0350
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Female'(=0)
#    => #rows in subset: 1931 (unpriv_count=136, priv_count=1795)
#    => GroundTruth: label=1 => 223, label=0 => 1708
#    => Predictions: label=1 => 641, label=0 => 1290
#    Compare Other_Female vs AfricanAmerican_Female: SPD=0.0249, DI=1.0373
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Male'(=0)
#    => #rows in subset: 293 (unpriv_count=136, priv_count=157)
#    => GroundTruth: label=1 => 32, label=0 => 261
#    => Predictions: label=1 => 89, label=0 => 204
#    Compare Other_Female vs Hispanic_Male: SPD=-0.0095, DI=0.9865
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Male'(=0)
#    => #rows in subset: 1256 (unpriv_count=136, priv_count=1120)
#    => GroundTruth: label=1 => 161, label=0 => 1095
#    => Predictions: label=1 => 425, label=0 => 831
#    Compare Other_Female vs AfricanAmerican_Male: SPD=0.0331, DI=1.0504
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Female'(=0)
#    => #rows in subset: 302 (unpriv_count=136, priv_count=166)
#    => GroundTruth: label=1 => 35, label=0 => 267
#    => Predictions: label=1 => 90, label=0 => 212
#    Compare Other_Female vs Hispanic_Female: SPD=-0.0197, DI=0.9723
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Other_Male'(=0)
#    => #rows in subset: 250 (unpriv_count=136, priv_count=114)
#    => GroundTruth: label=1 => 26, label=0 => 224
#    => Predictions: label=1 => 87, label=0 => 163
#    Compare Other_Female vs Other_Male: SPD=0.0859, DI=1.1419
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 53, label=0 => 137
#    Compare Other_Female vs Asian_Female: SPD=-0.1051, DI=0.8680
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Male'(=0)
#    => #rows in subset: 186 (unpriv_count=136, priv_count=50)
#    => GroundTruth: label=1 => 23, label=0 => 163
#    => Predictions: label=1 => 53, label=0 => 133
#    Compare Other_Female vs Asian_Male: SPD=-0.0888, DI=0.8861
#
# --- Model: pred_XGB, Unprivileged: Other_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Female'(=0)
#    => #rows in subset: 6077 (unpriv_count=136, priv_count=5941)
#    => GroundTruth: label=1 => 700, label=0 => 5377
#    => Predictions: label=1 => 2423, label=0 => 3654
#    Compare Other_Female vs Caucasian_Female: SPD=0.0017, DI=1.0028
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Male'(=0)
#    => #rows in subset: 5527 (unpriv_count=136, priv_count=5391)
#    => GroundTruth: label=1 => 637, label=0 => 4890
#    => Predictions: label=1 => 1859, label=0 => 3668
#    Compare Other_Female vs Caucasian_Male: SPD=-0.0622, DI=0.9064
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Female'(=0)
#    => #rows in subset: 1931 (unpriv_count=136, priv_count=1795)
#    => GroundTruth: label=1 => 223, label=0 => 1708
#    => Predictions: label=1 => 675, label=0 => 1256
#    Compare Other_Female vs AfricanAmerican_Female: SPD=-0.0511, DI=0.9219
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Male'(=0)
#    => #rows in subset: 293 (unpriv_count=136, priv_count=157)
#    => GroundTruth: label=1 => 32, label=0 => 261
#    => Predictions: label=1 => 102, label=0 => 191
#    Compare Other_Female vs Hispanic_Male: SPD=-0.0913, DI=0.8685
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Male'(=0)
#    => #rows in subset: 1256 (unpriv_count=136, priv_count=1120)
#    => GroundTruth: label=1 => 161, label=0 => 1095
#    => Predictions: label=1 => 442, label=0 => 814
#    Compare Other_Female vs AfricanAmerican_Male: SPD=-0.0506, DI=0.9225
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Female'(=0)
#    => #rows in subset: 302 (unpriv_count=136, priv_count=166)
#    => GroundTruth: label=1 => 35, label=0 => 267
#    => Predictions: label=1 => 104, label=0 => 198
#    Compare Other_Female vs Hispanic_Female: SPD=-0.0959, DI=0.8628
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Other_Male'(=0)
#    => #rows in subset: 250 (unpriv_count=136, priv_count=114)
#    => GroundTruth: label=1 => 26, label=0 => 224
#    => Predictions: label=1 => 97, label=0 => 153
#    Compare Other_Female vs Other_Male: SPD=-0.0199, DI=0.9681
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 71, label=0 => 119
#    Compare Other_Female vs Asian_Female: SPD=-0.0822, DI=0.8800
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Male'(=0)
#    => #rows in subset: 186 (unpriv_count=136, priv_count=50)
#    => GroundTruth: label=1 => 23, label=0 => 163
#    => Predictions: label=1 => 61, label=0 => 125
#    Compare Other_Female vs Asian_Male: SPD=-0.2571, DI=0.7011
#
# --- Model: pred_MLP, Unprivileged: Other_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Female'(=0)
#    => #rows in subset: 6077 (unpriv_count=136, priv_count=5941)
#    => GroundTruth: label=1 => 700, label=0 => 5377
#    => Predictions: label=1 => 2392, label=0 => 3685
#    Compare Other_Female vs Caucasian_Female: SPD=0.0115, DI=1.0190
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Male'(=0)
#    => #rows in subset: 5527 (unpriv_count=136, priv_count=5391)
#    => GroundTruth: label=1 => 637, label=0 => 4890
#    => Predictions: label=1 => 2061, label=0 => 3466
#    Compare Other_Female vs Caucasian_Male: SPD=-0.0097, DI=0.9845
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Female'(=0)
#    => #rows in subset: 1931 (unpriv_count=136, priv_count=1795)
#    => GroundTruth: label=1 => 223, label=0 => 1708
#    => Predictions: label=1 => 731, label=0 => 1200
#    Compare Other_Female vs AfricanAmerican_Female: SPD=-0.0041, DI=0.9934
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Male'(=0)
#    => #rows in subset: 293 (unpriv_count=136, priv_count=157)
#    => GroundTruth: label=1 => 32, label=0 => 261
#    => Predictions: label=1 => 105, label=0 => 188
#    Compare Other_Female vs Hispanic_Male: SPD=-0.0448, DI=0.9324
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Male'(=0)
#    => #rows in subset: 1256 (unpriv_count=136, priv_count=1120)
#    => GroundTruth: label=1 => 161, label=0 => 1095
#    => Predictions: label=1 => 502, label=0 => 754
#    Compare Other_Female vs AfricanAmerican_Male: SPD=0.0194, DI=1.0325
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Female'(=0)
#    => #rows in subset: 302 (unpriv_count=136, priv_count=166)
#    => GroundTruth: label=1 => 35, label=0 => 267
#    => Predictions: label=1 => 102, label=0 => 200
#    Compare Other_Female vs Hispanic_Female: SPD=-0.0811, DI=0.8839
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Other_Male'(=0)
#    => #rows in subset: 250 (unpriv_count=136, priv_count=114)
#    => GroundTruth: label=1 => 26, label=0 => 224
#    => Predictions: label=1 => 90, label=0 => 160
#    Compare Other_Female vs Other_Male: SPD=-0.0490, DI=0.9265
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 69, label=0 => 121
#    Compare Other_Female vs Asian_Female: SPD=-0.0675, DI=0.9014
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Male'(=0)
#    => #rows in subset: 186 (unpriv_count=136, priv_count=50)
#    => GroundTruth: label=1 => 23, label=0 => 163
#    => Predictions: label=1 => 60, label=0 => 126
#    Compare Other_Female vs Asian_Male: SPD=-0.2224, DI=0.7353
#
# === Aggregated Bias Results (Individual Groups) ===
#            Model   UnprivGroup               PrivGroup       SPD        DI  \
# 0   pred_LogReg  Other_Female        Caucasian_Female  0.044147  1.068231
# 1   pred_LogReg  Other_Female          Caucasian_Male  0.023397  1.035037
# 2   pred_LogReg  Other_Female  AfricanAmerican_Female  0.024881  1.037343
# 3   pred_LogReg  Other_Female           Hispanic_Male -0.009460  0.986497
# 4   pred_LogReg  Other_Female    AfricanAmerican_Male  0.033141  1.050363
# 5   pred_LogReg  Other_Female         Hispanic_Female -0.019667  0.972333
# 6   pred_LogReg  Other_Female              Other_Male  0.085913  1.141944
# 7   pred_LogReg  Other_Female            Asian_Female -0.105120  0.867989
# 8   pred_LogReg  Other_Female              Asian_Male -0.088824  0.886124
# 9      pred_XGB  Other_Female        Caucasian_Female  0.001696  1.002820
# 10     pred_XGB  Other_Female          Caucasian_Male -0.062242  0.906429
# 11     pred_XGB  Other_Female  AfricanAmerican_Female -0.051098  0.921873
# 12     pred_XGB  Other_Female           Hispanic_Male -0.091326  0.868457
# 13     pred_XGB  Other_Female    AfricanAmerican_Male -0.050630  0.922533
# 14     pred_XGB  Other_Female         Hispanic_Female -0.095854  0.862830
# 15     pred_XGB  Other_Female              Other_Male -0.019866  0.968103
# 16     pred_XGB  Other_Female            Asian_Female -0.082244  0.879968
# 17     pred_XGB  Other_Female              Asian_Male -0.257059  0.701094
# 18     pred_MLP  Other_Female        Caucasian_Female  0.011520  1.019006
# 19     pred_MLP  Other_Female          Caucasian_Male -0.009695  0.984546
# 20     pred_MLP  Other_Female  AfricanAmerican_Female -0.004080  0.993438
# 21     pred_MLP  Other_Female           Hispanic_Male -0.044773  0.932410
# 22     pred_MLP  Other_Female    AfricanAmerican_Male  0.019433  1.032485
# 23     pred_MLP  Other_Female         Hispanic_Female -0.081148  0.883874
# 24     pred_MLP  Other_Female              Other_Male -0.049020  0.926471
# 25     pred_MLP  Other_Female            Asian_Female -0.067538  0.901431
# 26     pred_MLP  Other_Female              Asian_Male -0.222353  0.735294
#
#          EOD       AOD   T_Index
# 0   0.055764  0.022017  0.377234
# 1   0.032367  0.010126  0.348195
# 2   0.032918  0.015239  0.346564
# 3   0.000059  0.000030  0.310327
# 4   0.039684  0.018094  0.349160
# 5  -0.004493 -0.046364  0.307677
# 6   0.088264  0.169132  0.360398
# 7  -0.050494 -0.275247  0.294778
# 8  -0.079661 -0.089831  0.282529
# 9   0.012851 -0.016872  0.430208
# 10 -0.052588 -0.075791  0.349372
# 11 -0.042394 -0.060899  0.363216
# 12 -0.084686 -0.062185  0.353816
# 13 -0.044038 -0.065337  0.359888
# 14 -0.102662 -0.033357  0.336735
# 15 -0.005916  0.003986  0.411522
# 16 -0.031073 -0.237759  0.400512
# 17 -0.275518 -0.143315  0.312836
# 18  0.021136 -0.005480  0.431598
# 19  0.002199 -0.034352  0.408411
# 20  0.001301 -0.006396  0.404640
# 21 -0.034254 -0.044905  0.381065
# 22  0.029943 -0.007562  0.434939
# 23 -0.080764 -0.053454  0.345228
# 24 -0.035177 -0.045367  0.385153
# 25 -0.001766 -0.278661  0.404139
# 26 -0.200377 -0.277966  0.333448
#
# === Plot SPD/DI for each Subgroup vs. Other_Female ===
# === (B) Lumps => 'Other_Female' unpriv, All Others => priv ===
# [pred_LogReg] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD=0.0315, DI=1.0477
# [pred_XGB] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD=-0.0354, DI=0.9445
# [pred_MLP] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD=-0.0007, DI=0.9989
#
# === Aggregated Bias Results (Lumped) ===
#           Model   UnprivGroup   PrivGroup       SPD        DI       EOD  \
# 0  pred_LogReg  Other_Female  ALL_OTHERS  0.031452  1.047675  0.041372
# 1     pred_XGB  Other_Female  ALL_OTHERS -0.035414  0.944523 -0.025649
# 2     pred_MLP  Other_Female  ALL_OTHERS -0.000692  0.998881  0.009413
#
#         AOD   T_Index
# 0  0.014947  0.360042
# 1 -0.049398  0.381271
# 2 -0.019393  0.417116
#
# === Plot SPD/DI => 'Other_Female'(unpriv) vs ALL_OTHERS ===

# %%
print("\n=== (A) Bias Analysis: Subgroup vs. 'Asian_Female' (Privileged) ===")

PRIV_GROUP_AF = "Asian_Female"
# all subgroups that are NOT 'Asian_Female' are tested as unprivileged, one by one
all_race_genders = test_data['race_gender'].unique()
unprivileged_groups = [g for g in all_race_genders if g != PRIV_GROUP_AF]

results_sep_AF = []
model_predictions = ['pred_LogReg','pred_XGB','pred_MLP']

for model_col in model_predictions:
    print(f"\n--- Model: {model_col}, Privileged: {PRIV_GROUP_AF} ---")
    for unpriv_grp in unprivileged_groups:
        ds_true, ds_pred = build_aif360_subset(
            df=test_data,
            label_col='readmitted',
            pred_col=model_col,
            unpriv_group_val=unpriv_grp,      # => 1
            priv_group_val=PRIV_GROUP_AF      # => 0
        )
        if ds_true is None or ds_pred is None:
            # If no rows match unpriv_grp or PRIV_GROUP_AF in test_data['race_gender']
            continue

        spd, di, eod, aod, t_index = compute_bias_metrics(ds_true, ds_pred)
        print(f"   Compare unpriv={unpriv_grp} vs priv={PRIV_GROUP_AF}: SPD={spd:.4f}, DI={di:.4f}")

        results_sep_AF.append({
            'Model': model_col,
            'UnprivGroup': unpriv_grp,
            'PrivGroup': PRIV_GROUP_AF,
            'SPD': spd,
            'DI': di,
            'EOD': eod,
            'AOD': aod,
            'T_Index': t_index
        })

df_results_sep_AF = pd.DataFrame(results_sep_AF)
print("\n=== Aggregated Bias Results (Individual Subgroups) ===\n", df_results_sep_AF)

# Plot SPD & DI
print("\n=== Plot SPD/DI for each Unpriv Subgroup vs. 'Asian_Female' ===")
plot_fairness_bar(
    df=df_results_sep_AF,
    x_col='UnprivGroup',
    y_col='SPD',
    hue_col='Model',
    title=f"Statistical Parity Difference vs. {PRIV_GROUP_AF}",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_sep_AF,
    x_col='UnprivGroup',
    y_col='DI',
    hue_col='Model',
    title=f"Disparate Impact vs. {PRIV_GROUP_AF}",
    ref_line=1
)


print("\n=== (B) Lumped Bias => 'Asian_Female' privileged vs. ALL_OTHERS unpriv ===")

results_lumped_AF = []

for model_col in model_predictions:
    ds_true_lumped, ds_pred_lumped = build_aif360_subset_lumped(
        df=test_data,
        label_col='readmitted',
        pred_col=model_col,
        privileged_grp=PRIV_GROUP_AF
    )
    # This lumps everything that is not 'Asian_Female' => 1, 
    # 'Asian_Female' => 0

    spd, di, eod, aod, t_index = compute_bias_metrics(ds_true_lumped, ds_pred_lumped)
    print(f"[{model_col}] Non-Asian_Female vs {PRIV_GROUP_AF}: SPD={spd:.4f}, DI={di:.4f}")

    results_lumped_AF.append({
        'Model': model_col,
        'UnprivGroup': "ALL_OTHERS",
        'PrivGroup': PRIV_GROUP_AF,
        'SPD': spd,
        'DI': di,
        'EOD': eod,
        'AOD': aod,
        'T_Index': t_index
    })

df_results_lumped_AF = pd.DataFrame(results_lumped_AF)
print("\n=== Aggregated Bias Results (Lumped) ===\n", df_results_lumped_AF)

print("\n=== Plot SPD/DI => Non-Asian_Female vs 'Asian_Female' ===")
plot_fairness_bar(
    df=df_results_lumped_AF,
    x_col='UnprivGroup',
    y_col='SPD',
    hue_col='Model',
    title=f"Statistical Parity Difference (All Non-Asian_Female vs. {PRIV_GROUP_AF})",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_lumped_AF,
    x_col='UnprivGroup',
    y_col='DI',
    hue_col='Model',
    title=f"Disparate Impact (All Non-Asian_Female vs. {PRIV_GROUP_AF})",
    ref_line=1
)
# Out:
# === (A) Bias Analysis: Subgroup vs. 'Asian_Female' (Privileged) ===
#
# --- Model: pred_LogReg, Privileged: Asian_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5995 (unpriv_count=5941, priv_count=54)
#    => GroundTruth: label=1 => 688, label=0 => 5307
#    => Predictions: label=1 => 2108, label=0 => 3887
#    Compare unpriv=Caucasian_Female vs priv=Asian_Female: SPD=-0.1493, DI=0.8125
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5445 (unpriv_count=5391, priv_count=54)
#    => GroundTruth: label=1 => 625, label=0 => 4820
#    => Predictions: label=1 => 1802, label=0 => 3643
#    Compare unpriv=Caucasian_Male vs priv=Asian_Female: SPD=-0.1285, DI=0.8386
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1849 (unpriv_count=1795, priv_count=54)
#    => GroundTruth: label=1 => 211, label=0 => 1638
#    => Predictions: label=1 => 610, label=0 => 1239
#    Compare unpriv=AfricanAmerican_Female vs priv=Asian_Female: SPD=-0.1300, DI=0.8367
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 211 (unpriv_count=157, priv_count=54)
#    => GroundTruth: label=1 => 20, label=0 => 191
#    => Predictions: label=1 => 58, label=0 => 153
#    Compare unpriv=Hispanic_Male vs priv=Asian_Female: SPD=-0.0957, DI=0.8799
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1174 (unpriv_count=1120, priv_count=54)
#    => GroundTruth: label=1 => 149, label=0 => 1025
#    => Predictions: label=1 => 394, label=0 => 780
#    Compare unpriv=AfricanAmerican_Male vs priv=Asian_Female: SPD=-0.1383, DI=0.8264
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 220 (unpriv_count=166, priv_count=54)
#    => GroundTruth: label=1 => 23, label=0 => 197
#    => Predictions: label=1 => 59, label=0 => 161
#    Compare unpriv=Hispanic_Female vs priv=Asian_Female: SPD=-0.0855, DI=0.8927
#
# [DEBUG] build_aif360_subset => unpriv='Other_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 168 (unpriv_count=114, priv_count=54)
#    => GroundTruth: label=1 => 14, label=0 => 154
#    => Predictions: label=1 => 56, label=0 => 112
#    Compare unpriv=Other_Male vs priv=Asian_Female: SPD=-0.1910, DI=0.7601
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 53, label=0 => 137
#    Compare unpriv=Other_Female vs priv=Asian_Female: SPD=-0.1051, DI=0.8680
#
# [DEBUG] build_aif360_subset => unpriv='Asian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 104 (unpriv_count=50, priv_count=54)
#    => GroundTruth: label=1 => 11, label=0 => 93
#    => Predictions: label=1 => 22, label=0 => 82
#    Compare unpriv=Asian_Male vs priv=Asian_Female: SPD=-0.0163, DI=0.9795
#
# --- Model: pred_XGB, Privileged: Asian_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5995 (unpriv_count=5941, priv_count=54)
#    => GroundTruth: label=1 => 688, label=0 => 5307
#    => Predictions: label=1 => 2386, label=0 => 3609
#    Compare unpriv=Caucasian_Female vs priv=Asian_Female: SPD=-0.0839, DI=0.8775
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5445 (unpriv_count=5391, priv_count=54)
#    => GroundTruth: label=1 => 625, label=0 => 4820
#    => Predictions: label=1 => 1822, label=0 => 3623
#    Compare unpriv=Caucasian_Male vs priv=Asian_Female: SPD=-0.0200, DI=0.9708
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1849 (unpriv_count=1795, priv_count=54)
#    => GroundTruth: label=1 => 211, label=0 => 1638
#    => Predictions: label=1 => 638, label=0 => 1211
#    Compare unpriv=AfricanAmerican_Female vs priv=Asian_Female: SPD=-0.0311, DI=0.9545
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 211 (unpriv_count=157, priv_count=54)
#    => GroundTruth: label=1 => 20, label=0 => 191
#    => Predictions: label=1 => 65, label=0 => 146
#    Compare unpriv=Hispanic_Male vs priv=Asian_Female: SPD=0.0091, DI=1.0133
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1174 (unpriv_count=1120, priv_count=54)
#    => GroundTruth: label=1 => 149, label=0 => 1025
#    => Predictions: label=1 => 405, label=0 => 769
#    Compare unpriv=AfricanAmerican_Male vs priv=Asian_Female: SPD=-0.0316, DI=0.9539
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 220 (unpriv_count=166, priv_count=54)
#    => GroundTruth: label=1 => 23, label=0 => 197
#    => Predictions: label=1 => 67, label=0 => 153
#    Compare unpriv=Hispanic_Female vs priv=Asian_Female: SPD=0.0136, DI=1.0199
#
# [DEBUG] build_aif360_subset => unpriv='Other_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 168 (unpriv_count=114, priv_count=54)
#    => GroundTruth: label=1 => 14, label=0 => 154
#    => Predictions: label=1 => 60, label=0 => 108
#    Compare unpriv=Other_Male vs priv=Asian_Female: SPD=-0.0624, DI=0.9090
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 71, label=0 => 119
#    Compare unpriv=Other_Female vs priv=Asian_Female: SPD=-0.0822, DI=0.8800
#
# [DEBUG] build_aif360_subset => unpriv='Asian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 104 (unpriv_count=50, priv_count=54)
#    => GroundTruth: label=1 => 11, label=0 => 93
#    => Predictions: label=1 => 24, label=0 => 80
#    Compare unpriv=Asian_Male vs priv=Asian_Female: SPD=0.1748, DI=1.2551
#
# --- Model: pred_MLP, Privileged: Asian_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5995 (unpriv_count=5941, priv_count=54)
#    => GroundTruth: label=1 => 688, label=0 => 5307
#    => Predictions: label=1 => 2357, label=0 => 3638
#    Compare unpriv=Caucasian_Female vs priv=Asian_Female: SPD=-0.0791, DI=0.8846
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5445 (unpriv_count=5391, priv_count=54)
#    => GroundTruth: label=1 => 625, label=0 => 4820
#    => Predictions: label=1 => 2026, label=0 => 3419
#    Compare unpriv=Caucasian_Male vs priv=Asian_Female: SPD=-0.0578, DI=0.9156
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1849 (unpriv_count=1795, priv_count=54)
#    => GroundTruth: label=1 => 211, label=0 => 1638
#    => Predictions: label=1 => 696, label=0 => 1153
#    Compare unpriv=AfricanAmerican_Female vs priv=Asian_Female: SPD=-0.0635, DI=0.9074
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 211 (unpriv_count=157, priv_count=54)
#    => GroundTruth: label=1 => 20, label=0 => 191
#    => Predictions: label=1 => 70, label=0 => 141
#    Compare unpriv=Hispanic_Male vs priv=Asian_Female: SPD=-0.0228, DI=0.9668
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1174 (unpriv_count=1120, priv_count=54)
#    => GroundTruth: label=1 => 149, label=0 => 1025
#    => Predictions: label=1 => 467, label=0 => 707
#    Compare unpriv=AfricanAmerican_Male vs priv=Asian_Female: SPD=-0.0870, DI=0.8731
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 220 (unpriv_count=166, priv_count=54)
#    => GroundTruth: label=1 => 23, label=0 => 197
#    => Predictions: label=1 => 67, label=0 => 153
#    Compare unpriv=Hispanic_Female vs priv=Asian_Female: SPD=0.0136, DI=1.0199
#
# [DEBUG] build_aif360_subset => unpriv='Other_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 168 (unpriv_count=114, priv_count=54)
#    => GroundTruth: label=1 => 14, label=0 => 154
#    => Predictions: label=1 => 55, label=0 => 113
#    Compare unpriv=Other_Male vs priv=Asian_Female: SPD=-0.0185, DI=0.9730
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 69, label=0 => 121
#    Compare unpriv=Other_Female vs priv=Asian_Female: SPD=-0.0675, DI=0.9014
#
# [DEBUG] build_aif360_subset => unpriv='Asian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 104 (unpriv_count=50, priv_count=54)
#    => GroundTruth: label=1 => 11, label=0 => 93
#    => Predictions: label=1 => 25, label=0 => 79
#    Compare unpriv=Asian_Male vs priv=Asian_Female: SPD=0.1548, DI=1.2259
#
# === Aggregated Bias Results (Individual Subgroups) ===
#            Model             UnprivGroup     PrivGroup       SPD        DI  \
# 0   pred_LogReg        Caucasian_Female  Asian_Female -0.149267  0.812548
# 1   pred_LogReg          Caucasian_Male  Asian_Female -0.128517  0.838607
# 2   pred_LogReg  AfricanAmerican_Female  Asian_Female -0.130001  0.836743
# 3   pred_LogReg           Hispanic_Male  Asian_Female -0.095659  0.879870
# 4   pred_LogReg    AfricanAmerican_Male  Asian_Female -0.138261  0.826370
# 5   pred_LogReg         Hispanic_Female  Asian_Female -0.085453  0.892687
# 6   pred_LogReg              Other_Male  Asian_Female -0.191033  0.760098
# 7   pred_LogReg            Other_Female  Asian_Female -0.105120  0.867989
# 8   pred_LogReg              Asian_Male  Asian_Female -0.016296  0.979535
# 9      pred_XGB        Caucasian_Female  Asian_Female -0.083940  0.877494
# 10     pred_XGB          Caucasian_Male  Asian_Female -0.020002  0.970807
# 11     pred_XGB  AfricanAmerican_Female  Asian_Female -0.031146  0.954543
# 12     pred_XGB           Hispanic_Male  Asian_Female  0.009082  1.013255
# 13     pred_XGB    AfricanAmerican_Male  Asian_Female -0.031614  0.953861
# 14     pred_XGB         Hispanic_Female  Asian_Female  0.013610  1.019863
# 15     pred_XGB              Other_Male  Asian_Female -0.062378  0.908962
# 16     pred_XGB            Other_Female  Asian_Female -0.082244  0.879968
# 17     pred_XGB              Asian_Male  Asian_Female  0.174815  1.255135
# 18     pred_MLP        Caucasian_Female  Asian_Female -0.079058  0.884618
# 19     pred_MLP          Caucasian_Male  Asian_Female -0.057843  0.915580
# 20     pred_MLP  AfricanAmerican_Female  Asian_Female -0.063458  0.907385
# 21     pred_MLP           Hispanic_Male  Asian_Female -0.022765  0.966776
# 22     pred_MLP    AfricanAmerican_Male  Asian_Female -0.086971  0.873069
# 23     pred_MLP         Hispanic_Female  Asian_Female  0.013610  1.019863
# 24     pred_MLP              Other_Male  Asian_Female -0.018519  0.972973
# 25     pred_MLP            Other_Female  Asian_Female -0.067538  0.901431
# 26     pred_MLP              Asian_Male  Asian_Female  0.154815  1.225946
#
#          EOD       AOD   T_Index
# 0  -0.106258 -0.297264  0.377889
# 1  -0.082862 -0.285373  0.348466
# 2  -0.083412 -0.290486  0.347292
# 3  -0.050554 -0.275277  0.302739
# 4  -0.090178 -0.293341  0.350458
# 5  -0.046001 -0.228883  0.299239
# 6  -0.138758 -0.444379  0.375701
# 7  -0.050494 -0.275247  0.294778
# 8   0.029167 -0.185417  0.245949
# 9  -0.043925 -0.220887  0.430440
# 10  0.021514 -0.161968  0.348436
# 11  0.011321 -0.176860  0.361045
# 12  0.053613 -0.175574  0.331733
# 13  0.012965 -0.172422  0.356214
# 14  0.071588 -0.204402  0.309787
# 15 -0.025157 -0.241745  0.410847
# 16 -0.031073 -0.237759  0.400512
# 17  0.244444 -0.094444  0.240169
# 18 -0.022901 -0.273181  0.432354
# 19 -0.003964 -0.244308  0.408874
# 20 -0.003066 -0.272265  0.405858
# 21  0.032488 -0.233756  0.382391
# 22 -0.031708 -0.271099  0.438984
# 23  0.078999 -0.225206  0.333417
# 24  0.033412 -0.233294  0.388934
# 25 -0.001766 -0.278661  0.404139
# 26  0.198611 -0.000694  0.298614
#
# === Plot SPD/DI for each Unpriv Subgroup vs. 'Asian_Female' ===
# === (B) Lumped Bias => 'Asian_Female' privileged vs. ALL_OTHERS unpriv ===
# [pred_LogReg] Non-Asian_Female vs Asian_Female: SPD=-0.1368, DI=0.8282
# [pred_XGB] Non-Asian_Female vs Asian_Female: SPD=-0.0473, DI=0.9309
# [pred_MLP] Non-Asian_Female vs Asian_Female: SPD=-0.0671, DI=0.9021
#
# === Aggregated Bias Results (Lumped) ===
#           Model UnprivGroup     PrivGroup       SPD        DI       EOD  \
# 0  pred_LogReg  ALL_OTHERS  Asian_Female -0.136780  0.828229 -0.091830
# 1     pred_XGB  ALL_OTHERS  Asian_Female -0.047324  0.930933 -0.005674
# 2     pred_MLP  ALL_OTHERS  Asian_Female -0.067095  0.902077 -0.011135
#
#         AOD   T_Index
# 0 -0.291093  0.360042
# 1 -0.189521  0.381271
# 2 -0.260389  0.417116
#
# === Plot SPD/DI => Non-Asian_Female vs 'Asian_Female' ===

# %%
results_dir = "dataset/train_test_extracted_overunder"

df_results_sep_OF.to_csv(os.path.join(results_dir, "bias_results_sep_OF_all_demographics.csv"), index=False)
df_results_lumped_OF.to_csv(os.path.join(results_dir, "bias_results_lumped_OF_all_demographics.csv"), index=False)

df_results_sep_AF.to_csv(os.path.join(results_dir, "bias_results_sep_AF_all_demographics.csv"), index=False)
df_results_lumped_AF.to_csv(os.path.join(results_dir, "bias_results_lumped_AF_all_demographics.csv"), index=False)
