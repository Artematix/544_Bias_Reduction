# %%
import os
import numpy as np
import pandas as pd

# Sklearn
from sklearn.metrics import accuracy_score, recall_score, f1_score
import joblib

# PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F

# AIF360
from aif360.datasets import BinaryLabelDataset
from aif360.metrics import ClassificationMetric

import seaborn as sns
import matplotlib.pyplot as plt

# %%
test_data = pd.read_csv('dataset/train_test_extracted_oversample/test.csv')

race_map = {0: "Other", 1: "AfricanAmerican", 2: "Asian", 3: "Caucasian", 4: "Hispanic"}
gender_map = {0: "Female", 1: "Male"}

test_data['race_str'] = test_data['race'].map(race_map)
test_data['gender_str'] = test_data['gender'].map(gender_map)
test_data['race_gender'] = test_data['race_str'] + "_" + test_data['gender_str']

drop_cols = ['readmitted','race','gender','race_str','gender_str','race_gender',
             'race_AfricanAmerican','race_Asian','race_Caucasian','race_Hispanic','race_Other']
X_test = test_data.drop(columns=drop_cols)
y_test = test_data['readmitted']

print("X_test shape:", X_test.shape, "y_test shape:", y_test.shape)


model_paths = {
    'LogReg': 'models/oversample/LogReg.joblib',
    'XGB':    'models/oversample/XGB.joblib',
    'MLP':    'models/oversample/MLP.pth'  # PyTorch model
}
# Out:
# X_test shape: (14924, 64) y_test shape: (14924,)

# %%
class SimpleNet(nn.Module):
    def __init__(self, input_dim, hidden_dim=64, num_classes=2):
        super(SimpleNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, num_classes)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        logits = self.fc2(x)
        return logits



for model_name, path in model_paths.items():
    print(f"\n=== Loading {model_name} ===")

    if model_name in ['LogReg','XGB']:
        # scikit-learn model
        model = joblib.load(path)


        if model_name == 'LogReg':
            scaler_path = "models/oversample/scaler_LogReg.joblib"
            scaler = joblib.load(scaler_path)
            X_test_scaled = scaler.transform(X_test)
            y_pred = model.predict(X_test_scaled)
        elif model_name == 'XGB':

            y_pred = model.predict(X_test)

    else:
        # PyTorch MLP
        # Must define the same architecture used at training
        input_dim = X_test.shape[1]
        mlp_model = SimpleNet(input_dim=input_dim, hidden_dim=64, num_classes=2)
        mlp_model.load_state_dict(torch.load(path))  # Load weights


        mlp_model.eval()
        X_test_t = torch.tensor(X_test.values, dtype=torch.float32)
        with torch.no_grad():
            logits = mlp_model(X_test_t)
            probs = F.softmax(logits, dim=1)
            y_pred = torch.argmax(probs, dim=1).numpy()

    acc = accuracy_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred, zero_division=0)
    f1 = f1_score(y_test, y_pred, zero_division=0)

    print(f"[{model_name}] Accuracy: {acc:.4f}, Recall: {rec:.4f}, F1: {f1:.4f}")

    # Store predictions for bias analysis
    pred_col = f"pred_{model_name}"
    test_data[pred_col] = y_pred
# Out:
# === Loading LogReg ===
# [LogReg] Accuracy: 0.6524, Recall: 0.5073, F1: 0.2514
#
# === Loading XGB ===
# [XGB] Accuracy: 0.6551, Recall: 0.5562, F1: 0.2706
#
# === Loading MLP ===
# [MLP] Accuracy: 0.6339, Recall: 0.5393, F1: 0.2531

# %%
def build_aif360_subset(df, label_col, pred_col, unpriv_group_val, priv_group_val):
    """
    Filters 'df' so it only contains rows where race_gender is either unpriv_group_val or priv_group_val.
    Then encodes 'race_gender' as 1 => unpriv, 0 => priv.
    Returns two BinaryLabelDatasets (one ground truth, one predicted).
    Also prints debug info on how many times label=1 vs 0 in truth & predictions.
    """

    # Filter DataFrame
    df_filtered = df[df['race_gender'].isin([unpriv_group_val, priv_group_val])].copy()
    if df_filtered.empty:
        return None, None

    # Binarize race_gender => 1 if unpriv, else 0
    df_filtered['race_gender'] = df_filtered['race_gender'].apply(
        lambda x: 1 if x == unpriv_group_val else 0
    )

    unpriv_count = (df_filtered['race_gender'] == 1).sum()
    priv_count   = (df_filtered['race_gender'] == 0).sum()

    # Build dataset_true
    df_true = df_filtered[['race_gender', label_col]].copy()
    df_true.rename(columns={label_col: 'label'}, inplace=True)

    # Count how many label=1 vs. 0 in ground truth
    true_ones  = (df_true['label'] == 1).sum()
    true_zeros = (df_true['label'] == 0).sum()

    dataset_true = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_true,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    # Build dataset_pred
    df_pred = df_filtered[['race_gender', pred_col]].copy()
    df_pred.rename(columns={pred_col: 'label'}, inplace=True)

    # Count how many label=1 vs. 0 in predictions
    pred_ones  = (df_pred['label'] == 1).sum()
    pred_zeros = (df_pred['label'] == 0).sum()

    dataset_pred = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_pred,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    # Debug prints
    print(f"\n[DEBUG] build_aif360_subset => unpriv='{unpriv_group_val}'(=1), "
          f"priv='{priv_group_val}'(=0)")
    print(f"   => #rows in subset: {len(df_filtered)} (unpriv_count={unpriv_count}, priv_count={priv_count})")
    print(f"   => GroundTruth: label=1 => {true_ones}, label=0 => {true_zeros}")
    print(f"   => Predictions: label=1 => {pred_ones}, label=0 => {pred_zeros}")

    return dataset_true, dataset_pred


def compute_bias_metrics(dataset_true, dataset_pred):
    metric = ClassificationMetric(
        dataset_true,
        dataset_pred,
        unprivileged_groups=[{'race_gender': 1}],
        privileged_groups=[{'race_gender': 0}]
    )
    spd = metric.statistical_parity_difference()
    di = metric.disparate_impact()
    eod = metric.equal_opportunity_difference()  
    aod = metric.average_odds_difference()       
    t_index = metric.theil_index()               
    return spd, di, eod, aod, t_index



def plot_fairness_bar(df, x_col, y_col, hue_col, title,
                      width=8, height=6, ref_line=None,
                      label_fontsize=8):

    plt.figure(figsize=(width, height))
    ax = sns.barplot(data=df, x=x_col, y=y_col, hue=hue_col)

    if ref_line is not None:
        plt.axhline(ref_line, color='black', linewidth=1)

    for container in ax.containers:
        ax.bar_label(container, fmt="%.2f", label_type='edge', 
                     padding=3, fontsize=label_fontsize)

    plt.title(title)
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()


def build_aif360_subset_lumped(df, label_col, pred_col, privileged_grp="Asian_Female"):
    """
    Instead of splitting each unpriv group individually,
    we lump "everything that is not privileged_grp" into unpriv (1).
    """
    # Copy entire df (no filter for specific groups)
    df_temp = df.copy()

    # Binarize: 1 if not privileged_grp, else 0
    df_temp['race_gender'] = df_temp['race_gender'].apply(
        lambda x: 0 if x == privileged_grp else 1
    )

    # Build dataset_true
    df_true = df_temp[['race_gender', label_col]].copy()
    df_true.rename(columns={label_col: 'label'}, inplace=True)
    dataset_true = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_true,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    # Build dataset_pred
    df_pred = df_temp[['race_gender', pred_col]].copy()
    df_pred.rename(columns={pred_col: 'label'}, inplace=True)
    dataset_pred = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_pred,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    return dataset_true, dataset_pred

# %%
print("\n=== (A) Bias Analysis per Subgroup vs. 'Other_Female' ===")

UNPRIV_GROUP_OF = "Other_Female"
all_race_genders = test_data['race_gender'].unique()
privileged_groups = [g for g in all_race_genders if g != UNPRIV_GROUP_OF]

results_sep_OF = []
model_predictions = ['pred_LogReg','pred_XGB','pred_MLP']

for model_col in model_predictions:
    print(f"\n--- Model: {model_col}, Unprivileged: {UNPRIV_GROUP_OF} ---")
    for priv_grp in privileged_groups:
        ds_true, ds_pred = build_aif360_subset(
            df=test_data,
            label_col='readmitted',
            pred_col=model_col,
            unpriv_group_val=UNPRIV_GROUP_OF, 
            priv_group_val=priv_grp           
        )
        if ds_true is None or ds_pred is None:
            print(f"   WARNING: No data for group={priv_grp}; skipping.")
            continue

        spd, di, eod, aod, t_index = compute_bias_metrics(ds_true, ds_pred)
        print(f"   Compare {UNPRIV_GROUP_OF} vs {priv_grp}: SPD={spd:.4f}, DI={di:.4f}")

        results_sep_OF.append({
            'Model': model_col,
            'UnprivGroup': UNPRIV_GROUP_OF,
            'PrivGroup': priv_grp,
            'SPD': spd,
            'DI': di,
            'EOD': eod,
            'AOD': aod,
            'T_Index': t_index
        })

df_results_sep_OF = pd.DataFrame(results_sep_OF)
print("\n=== Aggregated Bias Results (Individual Groups) ===\n", df_results_sep_OF)

print("\n=== Plot SPD/DI for each Subgroup vs. Other_Female ===")
plot_fairness_bar(
    df=df_results_sep_OF,
    x_col='PrivGroup',
    y_col='SPD',
    hue_col='Model',
    title=f"Statistical Parity Difference vs. {UNPRIV_GROUP_OF} (Unpriv)",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_sep_OF,
    x_col='PrivGroup',
    y_col='DI',
    hue_col='Model',
    title=f"Disparate Impact vs. {UNPRIV_GROUP_OF} (Unpriv)",
    ref_line=1
)


def build_aif360_subset_lumped_OF(df, label_col, pred_col):
    """
    Lump: 'Other_Female' => 1 (unpriv), everything else => 0 (priv).
    """
    df_temp = df.copy()
    df_temp['race_gender'] = df_temp['race_gender'].apply(
        lambda x: 1 if x == "Other_Female" else 0
    )
    # Build dataset_true
    df_true = df_temp[[ 'race_gender', label_col]].copy()
    df_true.rename(columns={label_col: 'label'}, inplace=True)
    dataset_true = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_true,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )
    # Build dataset_pred
    df_pred = df_temp[['race_gender', pred_col]].copy()
    df_pred.rename(columns={pred_col: 'label'}, inplace=True)
    dataset_pred = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_pred,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )
    return dataset_true, dataset_pred


print("\n=== (B) Lumps => 'Other_Female' unpriv, All Others => priv ===")
results_lumped_OF = []

for model_col in model_predictions:
    ds_true_lumped, ds_pred_lumped = build_aif360_subset_lumped_OF(
        df=test_data,
        label_col='readmitted',
        pred_col=model_col
    )
    spd, di, eod, aod, t_index = compute_bias_metrics(ds_true_lumped, ds_pred_lumped)
    print(f"[{model_col}] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD={spd:.4f}, DI={di:.4f}")
    results_lumped_OF.append({
        'Model': model_col,
        'UnprivGroup': "Other_Female",
        'PrivGroup': "ALL_OTHERS",
        'SPD': spd,
        'DI': di,
        'EOD': eod,
        'AOD': aod,
        'T_Index': t_index
    })

df_results_lumped_OF = pd.DataFrame(results_lumped_OF)
print("\n=== Aggregated Bias Results (Lumped) ===\n", df_results_lumped_OF)

print("\n=== Plot SPD/DI => 'Other_Female'(unpriv) vs ALL_OTHERS ===")
plot_fairness_bar(
    df=df_results_lumped_OF,
    x_col='UnprivGroup',
    y_col='SPD',
    hue_col='Model',
    title="Statistical Parity Difference (Other_Female vs. ALL_OTHERS)",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_lumped_OF,
    x_col='UnprivGroup',
    y_col='DI',
    hue_col='Model',
    title="Disparate Impact (Other_Female vs. ALL_OTHERS)",
    ref_line=1
)
# Out:
# === (A) Bias Analysis per Subgroup vs. 'Other_Female' ===
#
# --- Model: pred_LogReg, Unprivileged: Other_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Female'(=0)
#    => #rows in subset: 6077 (unpriv_count=136, priv_count=5941)
#    => GroundTruth: label=1 => 700, label=0 => 5377
#    => Predictions: label=1 => 2195, label=0 => 3882
#    Compare Other_Female vs Caucasian_Female: SPD=0.0235, DI=1.0368
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Male'(=0)
#    => #rows in subset: 5527 (unpriv_count=136, priv_count=5391)
#    => GroundTruth: label=1 => 637, label=0 => 4890
#    => Predictions: label=1 => 1890, label=0 => 3637
#    Compare Other_Female vs Caucasian_Male: SPD=0.0038, DI=1.0058
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Female'(=0)
#    => #rows in subset: 1931 (unpriv_count=136, priv_count=1795)
#    => GroundTruth: label=1 => 223, label=0 => 1708
#    => Predictions: label=1 => 666, label=0 => 1265
#    Compare Other_Female vs AfricanAmerican_Female: SPD=0.0072, DI=1.0110
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Male'(=0)
#    => #rows in subset: 293 (unpriv_count=136, priv_count=157)
#    => GroundTruth: label=1 => 32, label=0 => 261
#    => Predictions: label=1 => 89, label=0 => 204
#    Compare Other_Female vs Hispanic_Male: SPD=-0.0643, DI=0.9114
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Male'(=0)
#    => #rows in subset: 1256 (unpriv_count=136, priv_count=1120)
#    => GroundTruth: label=1 => 161, label=0 => 1095
#    => Predictions: label=1 => 445, label=0 => 811
#    Compare Other_Female vs AfricanAmerican_Male: SPD=0.0180, DI=1.0280
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Female'(=0)
#    => #rows in subset: 302 (unpriv_count=136, priv_count=166)
#    => GroundTruth: label=1 => 35, label=0 => 267
#    => Predictions: label=1 => 95, label=0 => 207
#    Compare Other_Female vs Hispanic_Female: SPD=-0.0431, DI=0.9389
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Other_Male'(=0)
#    => #rows in subset: 250 (unpriv_count=136, priv_count=114)
#    => GroundTruth: label=1 => 26, label=0 => 224
#    => Predictions: label=1 => 86, label=0 => 164
#    Compare Other_Female vs Other_Male: SPD=0.0126, DI=1.0195
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 59, label=0 => 131
#    Compare Other_Female vs Asian_Female: SPD=-0.0975, DI=0.8716
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Male'(=0)
#    => #rows in subset: 186 (unpriv_count=136, priv_count=50)
#    => GroundTruth: label=1 => 23, label=0 => 163
#    => Predictions: label=1 => 56, label=0 => 130
#    Compare Other_Female vs Asian_Male: SPD=-0.1382, DI=0.8272
#
# --- Model: pred_XGB, Unprivileged: Other_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Female'(=0)
#    => #rows in subset: 6077 (unpriv_count=136, priv_count=5941)
#    => GroundTruth: label=1 => 700, label=0 => 5377
#    => Predictions: label=1 => 2286, label=0 => 3791
#    Compare Other_Female vs Caucasian_Female: SPD=-0.0364, DI=0.9417
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Male'(=0)
#    => #rows in subset: 5527 (unpriv_count=136, priv_count=5391)
#    => GroundTruth: label=1 => 637, label=0 => 4890
#    => Predictions: label=1 => 1898, label=0 => 3629
#    Compare Other_Female vs Caucasian_Male: SPD=-0.0701, DI=0.8935
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Female'(=0)
#    => #rows in subset: 1931 (unpriv_count=136, priv_count=1795)
#    => GroundTruth: label=1 => 223, label=0 => 1708
#    => Predictions: label=1 => 699, label=0 => 1232
#    Compare Other_Female vs AfricanAmerican_Female: SPD=-0.0535, DI=0.9166
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Male'(=0)
#    => #rows in subset: 293 (unpriv_count=136, priv_count=157)
#    => GroundTruth: label=1 => 32, label=0 => 261
#    => Predictions: label=1 => 107, label=0 => 186
#    Compare Other_Female vs Hispanic_Male: SPD=-0.0869, DI=0.8713
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Male'(=0)
#    => #rows in subset: 1256 (unpriv_count=136, priv_count=1120)
#    => GroundTruth: label=1 => 161, label=0 => 1095
#    => Predictions: label=1 => 461, label=0 => 795
#    Compare Other_Female vs AfricanAmerican_Male: SPD=-0.0502, DI=0.9214
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Female'(=0)
#    => #rows in subset: 302 (unpriv_count=136, priv_count=166)
#    => GroundTruth: label=1 => 35, label=0 => 267
#    => Predictions: label=1 => 109, label=0 => 193
#    Compare Other_Female vs Hispanic_Female: SPD=-0.0925, DI=0.8641
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Other_Male'(=0)
#    => #rows in subset: 250 (unpriv_count=136, priv_count=114)
#    => GroundTruth: label=1 => 26, label=0 => 224
#    => Predictions: label=1 => 92, label=0 => 158
#    Compare Other_Female vs Other_Male: SPD=-0.0960, DI=0.8597
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 73, label=0 => 117
#    Compare Other_Female vs Asian_Female: SPD=-0.0969, DI=0.8585
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Male'(=0)
#    => #rows in subset: 186 (unpriv_count=136, priv_count=50)
#    => GroundTruth: label=1 => 23, label=0 => 163
#    => Predictions: label=1 => 64, label=0 => 122
#    Compare Other_Female vs Asian_Male: SPD=-0.2518, DI=0.7003
#
# --- Model: pred_MLP, Unprivileged: Other_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Female'(=0)
#    => #rows in subset: 6077 (unpriv_count=136, priv_count=5941)
#    => GroundTruth: label=1 => 700, label=0 => 5377
#    => Predictions: label=1 => 2309, label=0 => 3768
#    Compare Other_Female vs Caucasian_Female: SPD=-0.0100, DI=0.9839
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Male'(=0)
#    => #rows in subset: 5527 (unpriv_count=136, priv_count=5391)
#    => GroundTruth: label=1 => 637, label=0 => 4890
#    => Predictions: label=1 => 2029, label=0 => 3498
#    Compare Other_Female vs Caucasian_Male: SPD=-0.0232, DI=0.9634
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Female'(=0)
#    => #rows in subset: 1931 (unpriv_count=136, priv_count=1795)
#    => GroundTruth: label=1 => 223, label=0 => 1708
#    => Predictions: label=1 => 737, label=0 => 1194
#    Compare Other_Female vs AfricanAmerican_Female: SPD=-0.0086, DI=0.9860
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Male'(=0)
#    => #rows in subset: 293 (unpriv_count=136, priv_count=157)
#    => GroundTruth: label=1 => 32, label=0 => 261
#    => Predictions: label=1 => 115, label=0 => 178
#    Compare Other_Female vs Hispanic_Male: SPD=0.0052, DI=1.0086
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Male'(=0)
#    => #rows in subset: 1256 (unpriv_count=136, priv_count=1120)
#    => GroundTruth: label=1 => 161, label=0 => 1095
#    => Predictions: label=1 => 487, label=0 => 769
#    Compare Other_Female vs AfricanAmerican_Male: SPD=-0.0022, DI=0.9964
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Female'(=0)
#    => #rows in subset: 302 (unpriv_count=136, priv_count=166)
#    => GroundTruth: label=1 => 35, label=0 => 267
#    => Predictions: label=1 => 113, label=0 => 189
#    Compare Other_Female vs Hispanic_Female: SPD=-0.0283, DI=0.9557
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Other_Male'(=0)
#    => #rows in subset: 250 (unpriv_count=136, priv_count=114)
#    => GroundTruth: label=1 => 26, label=0 => 224
#    => Predictions: label=1 => 99, label=0 => 151
#    Compare Other_Female vs Other_Male: SPD=0.0138, DI=1.0231
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 67, label=0 => 123
#    Compare Other_Female vs Asian_Female: SPD=-0.1304, DI=0.8239
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Male'(=0)
#    => #rows in subset: 186 (unpriv_count=136, priv_count=50)
#    => GroundTruth: label=1 => 23, label=0 => 163
#    => Predictions: label=1 => 67, label=0 => 119
#    Compare Other_Female vs Asian_Male: SPD=-0.1097, DI=0.8476
#
# === Aggregated Bias Results (Individual Groups) ===
#            Model   UnprivGroup               PrivGroup       SPD        DI  \
# 0   pred_LogReg  Other_Female        Caucasian_Female  0.023488  1.036800
# 1   pred_LogReg  Other_Female          Caucasian_Male  0.003816  1.005800
# 2   pred_LogReg  Other_Female  AfricanAmerican_Female  0.007169  1.010951
# 3   pred_LogReg  Other_Female           Hispanic_Male -0.064350  0.911378
# 4   pred_LogReg  Other_Female    AfricanAmerican_Male  0.018015  1.027984
# 5   pred_LogReg  Other_Female         Hispanic_Female -0.043055  0.938914
# 6   pred_LogReg  Other_Female              Other_Male  0.012642  1.019475
# 7   pred_LogReg  Other_Female            Asian_Female -0.097495  0.871593
# 8   pred_LogReg  Other_Female              Asian_Male -0.138235  0.827206
# 9      pred_XGB  Other_Female        Caucasian_Female -0.036407  0.941715
# 10     pred_XGB  Other_Female          Caucasian_Male -0.070084  0.893541
# 11     pred_XGB  Other_Female  AfricanAmerican_Female -0.053547  0.916565
# 12     pred_XGB  Other_Female           Hispanic_Male -0.086924  0.871254
# 13     pred_XGB  Other_Female    AfricanAmerican_Male -0.050158  0.921432
# 14     pred_XGB  Other_Female         Hispanic_Female -0.092488  0.864133
# 15     pred_XGB  Other_Female              Other_Male -0.095975  0.859729
# 16     pred_XGB  Other_Female            Asian_Female -0.096950  0.858506
# 17     pred_XGB  Other_Female              Asian_Male -0.251765  0.700280
# 18     pred_MLP  Other_Female        Caucasian_Female -0.009972  0.983923
# 19     pred_MLP  Other_Female          Caucasian_Male -0.023169  0.963425
# 20     pred_MLP  Other_Female  AfricanAmerican_Female -0.008647  0.986029
# 21     pred_MLP  Other_Female           Hispanic_Male  0.005199  1.008591
# 22     pred_MLP  Other_Female    AfricanAmerican_Male -0.002206  0.996399
# 23     pred_MLP  Other_Female         Hispanic_Female -0.028260  0.955744
# 24     pred_MLP  Other_Female              Other_Male  0.013803  1.023140
# 25     pred_MLP  Other_Female            Asian_Female -0.130447  0.823897
# 26     pred_MLP  Other_Female              Asian_Male -0.109706  0.847631
#
#          EOD       AOD   T_Index
# 0   0.037756 -0.005234  0.386454
# 1   0.016164 -0.018484  0.359591
# 2   0.018186 -0.010148  0.360292
# 3  -0.053336 -0.054446  0.304453
# 4   0.028590 -0.008238  0.367577
# 5  -0.043340 -0.005330  0.307417
# 6   0.025104  0.047274  0.354696
# 7  -0.055085 -0.221987  0.319869
# 8  -0.127307 -0.141431  0.294977
# 9  -0.014530 -0.082453  0.394115
# 10 -0.046930 -0.120440  0.355483
# 11 -0.029816 -0.105287  0.377357
# 12 -0.084686 -0.010597  0.346551
# 13 -0.035850 -0.085330  0.365736
# 14 -0.089239 -0.052789  0.341884
# 15 -0.062520 -0.142371  0.374333
# 16 -0.031073 -0.293315  0.396583
# 17 -0.231073 -0.276648  0.325498
# 18  0.020211 -0.081944  0.406857
# 19  0.005946 -0.091579  0.388724
# 20  0.018250 -0.069059  0.401459
# 21  0.038639 -0.056077  0.405680
# 22  0.026421 -0.078670  0.406338
# 23  0.010010 -0.120812  0.385424
# 24  0.047809 -0.024706  0.407969
# 25 -0.047316 -0.384769  0.360328
# 26 -0.072316 -0.197269  0.348021
#
# === Plot SPD/DI for each Subgroup vs. Other_Female ===
# === (B) Lumps => 'Other_Female' unpriv, All Others => priv ===
# [pred_LogReg] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD=0.0112, DI=1.0172
# [pred_XGB] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD=-0.0544, DI=0.9154
# [pred_MLP] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD=-0.0147, DI=0.9765
#
# === Aggregated Bias Results (Lumped) ===
#           Model   UnprivGroup   PrivGroup       SPD        DI       EOD  \
# 0  pred_LogReg  Other_Female  ALL_OTHERS  0.011170  1.017168  0.023894
# 1     pred_XGB  Other_Female  ALL_OTHERS -0.054380  0.915377 -0.032601
# 2     pred_MLP  Other_Female  ALL_OTHERS -0.014672  0.976523  0.014978
#
#         AOD   T_Index
# 0 -0.012447  0.369530
# 1 -0.100190  0.371651
# 2 -0.084935  0.400572
#
# === Plot SPD/DI => 'Other_Female'(unpriv) vs ALL_OTHERS ===

# %%
print("\n=== (A) Bias Analysis: Subgroup vs. 'Asian_Female' (Privileged) ===")

PRIV_GROUP_AF = "Asian_Female"
# all subgroups that are NOT 'Asian_Female' are tested as unprivileged, one by one
all_race_genders = test_data['race_gender'].unique()
unprivileged_groups = [g for g in all_race_genders if g != PRIV_GROUP_AF]

results_sep_AF = []
model_predictions = ['pred_LogReg','pred_XGB','pred_MLP']

for model_col in model_predictions:
    print(f"\n--- Model: {model_col}, Privileged: {PRIV_GROUP_AF} ---")
    for unpriv_grp in unprivileged_groups:
        ds_true, ds_pred = build_aif360_subset(
            df=test_data,
            label_col='readmitted',
            pred_col=model_col,
            unpriv_group_val=unpriv_grp,      # => 1
            priv_group_val=PRIV_GROUP_AF      # => 0
        )
        if ds_true is None or ds_pred is None:
            # If no rows match unpriv_grp or PRIV_GROUP_AF in test_data['race_gender']
            continue

        spd, di, eod, aod, t_index = compute_bias_metrics(ds_true, ds_pred)
        print(f"   Compare unpriv={unpriv_grp} vs priv={PRIV_GROUP_AF}: SPD={spd:.4f}, DI={di:.4f}")

        results_sep_AF.append({
            'Model': model_col,
            'UnprivGroup': unpriv_grp,
            'PrivGroup': PRIV_GROUP_AF,
            'SPD': spd,
            'DI': di,
            'EOD': eod,
            'AOD': aod,
            'T_Index': t_index
        })

df_results_sep_AF = pd.DataFrame(results_sep_AF)
print("\n=== Aggregated Bias Results (Individual Subgroups) ===\n", df_results_sep_AF)

# Plot SPD & DI
print("\n=== Plot SPD/DI for each Unpriv Subgroup vs. 'Asian_Female' ===")
plot_fairness_bar(
    df=df_results_sep_AF,
    x_col='UnprivGroup',
    y_col='SPD',
    hue_col='Model',
    title=f"Statistical Parity Difference vs. {PRIV_GROUP_AF}",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_sep_AF,
    x_col='UnprivGroup',
    y_col='DI',
    hue_col='Model',
    title=f"Disparate Impact vs. {PRIV_GROUP_AF}",
    ref_line=1
)


print("\n=== (B) Lumped Bias => 'Asian_Female' privileged vs. ALL_OTHERS unpriv ===")

results_lumped_AF = []

for model_col in model_predictions:
    ds_true_lumped, ds_pred_lumped = build_aif360_subset_lumped(
        df=test_data,
        label_col='readmitted',
        pred_col=model_col,
        privileged_grp=PRIV_GROUP_AF
    )
    # This lumps everything that is not 'Asian_Female' => 1, 
    # 'Asian_Female' => 0

    spd, di, eod, aod, t_index = compute_bias_metrics(ds_true_lumped, ds_pred_lumped)
    print(f"[{model_col}] Non-Asian_Female vs {PRIV_GROUP_AF}: SPD={spd:.4f}, DI={di:.4f}")

    results_lumped_AF.append({
        'Model': model_col,
        'UnprivGroup': "ALL_OTHERS",
        'PrivGroup': PRIV_GROUP_AF,
        'SPD': spd,
        'DI': di,
        'EOD': eod,
        'AOD': aod,
        'T_Index': t_index
    })

df_results_lumped_AF = pd.DataFrame(results_lumped_AF)
print("\n=== Aggregated Bias Results (Lumped) ===\n", df_results_lumped_AF)

print("\n=== Plot SPD/DI => Non-Asian_Female vs 'Asian_Female' ===")
plot_fairness_bar(
    df=df_results_lumped_AF,
    x_col='UnprivGroup',
    y_col='SPD',
    hue_col='Model',
    title=f"Statistical Parity Difference (All Non-Asian_Female vs. {PRIV_GROUP_AF})",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_lumped_AF,
    x_col='UnprivGroup',
    y_col='DI',
    hue_col='Model',
    title=f"Disparate Impact (All Non-Asian_Female vs. {PRIV_GROUP_AF})",
    ref_line=1
)
# Out:
# === (A) Bias Analysis: Subgroup vs. 'Asian_Female' (Privileged) ===
#
# --- Model: pred_LogReg, Privileged: Asian_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5995 (unpriv_count=5941, priv_count=54)
#    => GroundTruth: label=1 => 688, label=0 => 5307
#    => Predictions: label=1 => 2162, label=0 => 3833
#    Compare unpriv=Caucasian_Female vs priv=Asian_Female: SPD=-0.1210, DI=0.8407
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5445 (unpriv_count=5391, priv_count=54)
#    => GroundTruth: label=1 => 625, label=0 => 4820
#    => Predictions: label=1 => 1857, label=0 => 3588
#    Compare unpriv=Caucasian_Male vs priv=Asian_Female: SPD=-0.1013, DI=0.8666
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1849 (unpriv_count=1795, priv_count=54)
#    => GroundTruth: label=1 => 211, label=0 => 1638
#    => Predictions: label=1 => 633, label=0 => 1216
#    Compare unpriv=AfricanAmerican_Female vs priv=Asian_Female: SPD=-0.1047, DI=0.8622
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 211 (unpriv_count=157, priv_count=54)
#    => GroundTruth: label=1 => 20, label=0 => 191
#    => Predictions: label=1 => 56, label=0 => 155
#    Compare unpriv=Hispanic_Male vs priv=Asian_Female: SPD=-0.0331, DI=0.9563
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1174 (unpriv_count=1120, priv_count=54)
#    => GroundTruth: label=1 => 149, label=0 => 1025
#    => Predictions: label=1 => 412, label=0 => 762
#    Compare unpriv=AfricanAmerican_Male vs priv=Asian_Female: SPD=-0.1155, DI=0.8479
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 220 (unpriv_count=166, priv_count=54)
#    => GroundTruth: label=1 => 23, label=0 => 197
#    => Predictions: label=1 => 62, label=0 => 158
#    Compare unpriv=Hispanic_Female vs priv=Asian_Female: SPD=-0.0544, DI=0.9283
#
# [DEBUG] build_aif360_subset => unpriv='Other_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 168 (unpriv_count=114, priv_count=54)
#    => GroundTruth: label=1 => 14, label=0 => 154
#    => Predictions: label=1 => 53, label=0 => 115
#    Compare unpriv=Other_Male vs priv=Asian_Female: SPD=-0.1101, DI=0.8549
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 59, label=0 => 131
#    Compare unpriv=Other_Female vs priv=Asian_Female: SPD=-0.0975, DI=0.8716
#
# [DEBUG] build_aif360_subset => unpriv='Asian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 104 (unpriv_count=50, priv_count=54)
#    => GroundTruth: label=1 => 11, label=0 => 93
#    => Predictions: label=1 => 23, label=0 => 81
#    Compare unpriv=Asian_Male vs priv=Asian_Female: SPD=0.0407, DI=1.0537
#
# --- Model: pred_XGB, Privileged: Asian_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5995 (unpriv_count=5941, priv_count=54)
#    => GroundTruth: label=1 => 688, label=0 => 5307
#    => Predictions: label=1 => 2247, label=0 => 3748
#    Compare unpriv=Caucasian_Female vs priv=Asian_Female: SPD=-0.0605, DI=0.9116
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5445 (unpriv_count=5391, priv_count=54)
#    => GroundTruth: label=1 => 625, label=0 => 4820
#    => Predictions: label=1 => 1859, label=0 => 3586
#    Compare unpriv=Caucasian_Male vs priv=Asian_Female: SPD=-0.0269, DI=0.9608
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1849 (unpriv_count=1795, priv_count=54)
#    => GroundTruth: label=1 => 211, label=0 => 1638
#    => Predictions: label=1 => 660, label=0 => 1189
#    Compare unpriv=AfricanAmerican_Female vs priv=Asian_Female: SPD=-0.0434, DI=0.9367
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 211 (unpriv_count=157, priv_count=54)
#    => GroundTruth: label=1 => 20, label=0 => 191
#    => Predictions: label=1 => 68, label=0 => 143
#    Compare unpriv=Hispanic_Male vs priv=Asian_Female: SPD=-0.0100, DI=0.9854
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1174 (unpriv_count=1120, priv_count=54)
#    => GroundTruth: label=1 => 149, label=0 => 1025
#    => Predictions: label=1 => 422, label=0 => 752
#    Compare unpriv=AfricanAmerican_Male vs priv=Asian_Female: SPD=-0.0468, DI=0.9317
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 220 (unpriv_count=166, priv_count=54)
#    => GroundTruth: label=1 => 23, label=0 => 197
#    => Predictions: label=1 => 70, label=0 => 150
#    Compare unpriv=Hispanic_Female vs priv=Asian_Female: SPD=-0.0045, DI=0.9935
#
# [DEBUG] build_aif360_subset => unpriv='Other_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 168 (unpriv_count=114, priv_count=54)
#    => GroundTruth: label=1 => 14, label=0 => 154
#    => Predictions: label=1 => 53, label=0 => 115
#    Compare unpriv=Other_Male vs priv=Asian_Female: SPD=-0.0010, DI=0.9986
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 73, label=0 => 117
#    Compare unpriv=Other_Female vs priv=Asian_Female: SPD=-0.0969, DI=0.8585
#
# [DEBUG] build_aif360_subset => unpriv='Asian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 104 (unpriv_count=50, priv_count=54)
#    => GroundTruth: label=1 => 11, label=0 => 93
#    => Predictions: label=1 => 25, label=0 => 79
#    Compare unpriv=Asian_Male vs priv=Asian_Female: SPD=0.1548, DI=1.2259
#
# --- Model: pred_MLP, Privileged: Asian_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5995 (unpriv_count=5941, priv_count=54)
#    => GroundTruth: label=1 => 688, label=0 => 5307
#    => Predictions: label=1 => 2270, label=0 => 3725
#    Compare unpriv=Caucasian_Female vs priv=Asian_Female: SPD=-0.1205, DI=0.8374
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5445 (unpriv_count=5391, priv_count=54)
#    => GroundTruth: label=1 => 625, label=0 => 4820
#    => Predictions: label=1 => 1990, label=0 => 3455
#    Compare unpriv=Caucasian_Male vs priv=Asian_Female: SPD=-0.1073, DI=0.8552
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1849 (unpriv_count=1795, priv_count=54)
#    => GroundTruth: label=1 => 211, label=0 => 1638
#    => Predictions: label=1 => 698, label=0 => 1151
#    Compare unpriv=AfricanAmerican_Female vs priv=Asian_Female: SPD=-0.1218, DI=0.8356
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 211 (unpriv_count=157, priv_count=54)
#    => GroundTruth: label=1 => 20, label=0 => 191
#    => Predictions: label=1 => 76, label=0 => 135
#    Compare unpriv=Hispanic_Male vs priv=Asian_Female: SPD=-0.1356, DI=0.8169
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1174 (unpriv_count=1120, priv_count=54)
#    => GroundTruth: label=1 => 149, label=0 => 1025
#    => Predictions: label=1 => 448, label=0 => 726
#    Compare unpriv=AfricanAmerican_Male vs priv=Asian_Female: SPD=-0.1282, DI=0.8269
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 220 (unpriv_count=166, priv_count=54)
#    => GroundTruth: label=1 => 23, label=0 => 197
#    => Predictions: label=1 => 74, label=0 => 146
#    Compare unpriv=Hispanic_Female vs priv=Asian_Female: SPD=-0.1022, DI=0.8620
#
# [DEBUG] build_aif360_subset => unpriv='Other_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 168 (unpriv_count=114, priv_count=54)
#    => GroundTruth: label=1 => 14, label=0 => 154
#    => Predictions: label=1 => 60, label=0 => 108
#    Compare unpriv=Other_Male vs priv=Asian_Female: SPD=-0.1442, DI=0.8053
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 67, label=0 => 123
#    Compare unpriv=Other_Female vs priv=Asian_Female: SPD=-0.1304, DI=0.8239
#
# [DEBUG] build_aif360_subset => unpriv='Asian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 104 (unpriv_count=50, priv_count=54)
#    => GroundTruth: label=1 => 11, label=0 => 93
#    => Predictions: label=1 => 28, label=0 => 76
#    Compare unpriv=Asian_Male vs priv=Asian_Female: SPD=-0.0207, DI=0.9720
#
# === Aggregated Bias Results (Individual Subgroups) ===
#            Model             UnprivGroup     PrivGroup       SPD        DI  \
# 0   pred_LogReg        Caucasian_Female  Asian_Female -0.120983  0.840657
# 1   pred_LogReg          Caucasian_Male  Asian_Female -0.101311  0.866566
# 2   pred_LogReg  AfricanAmerican_Female  Asian_Female -0.104663  0.862151
# 3   pred_LogReg           Hispanic_Male  Asian_Female -0.033145  0.956346
# 4   pred_LogReg    AfricanAmerican_Male  Asian_Female -0.115509  0.847866
# 5   pred_LogReg         Hispanic_Female  Asian_Female -0.054440  0.928299
# 6   pred_LogReg              Other_Male  Asian_Female -0.110136  0.854942
# 7   pred_LogReg            Other_Female  Asian_Female -0.097495  0.871593
# 8   pred_LogReg              Asian_Male  Asian_Female  0.040741  1.053659
# 9      pred_XGB        Caucasian_Female  Asian_Female -0.060543  0.911640
# 10     pred_XGB          Caucasian_Male  Asian_Female -0.026866  0.960791
# 11     pred_XGB  AfricanAmerican_Female  Asian_Female -0.043402  0.936656
# 12     pred_XGB           Hispanic_Male  Asian_Female -0.010026  0.985368
# 13     pred_XGB    AfricanAmerican_Male  Asian_Female -0.046792  0.931708
# 14     pred_XGB         Hispanic_Female  Asian_Female -0.004462  0.993487
# 15     pred_XGB              Other_Male  Asian_Female -0.000975  0.998578
# 16     pred_XGB            Other_Female  Asian_Female -0.096950  0.858506
# 17     pred_XGB              Asian_Male  Asian_Female  0.154815  1.225946
# 18     pred_MLP        Caucasian_Female  Asian_Female -0.120475  0.837359
# 19     pred_MLP          Caucasian_Male  Asian_Female -0.107278  0.855175
# 20     pred_MLP  AfricanAmerican_Female  Asian_Female -0.121799  0.835571
# 21     pred_MLP           Hispanic_Male  Asian_Female -0.135645  0.816879
# 22     pred_MLP    AfricanAmerican_Male  Asian_Female -0.128241  0.826875
# 23     pred_MLP         Hispanic_Female  Asian_Female -0.102187  0.862048
# 24     pred_MLP              Other_Male  Asian_Female -0.144250  0.805263
# 25     pred_MLP            Other_Female  Asian_Female -0.130447  0.823897
# 26     pred_MLP              Asian_Male  Asian_Female -0.020741  0.972000
#
#          EOD       AOD   T_Index
# 0  -0.092841 -0.216753  0.386755
# 1  -0.071249 -0.203503  0.359516
# 2  -0.073270 -0.211838  0.360104
# 3  -0.001748 -0.167541  0.282132
# 4  -0.083675 -0.213749  0.367759
# 5  -0.011745 -0.216657  0.287040
# 6  -0.080189 -0.269261  0.350123
# 7  -0.055085 -0.221987  0.319869
# 8   0.072222 -0.080556  0.243150
# 9  -0.016543 -0.210862  0.393988
# 10  0.015856 -0.172874  0.354772
# 11 -0.001258 -0.188027  0.376204
# 12  0.053613 -0.282717  0.326147
# 13  0.004777 -0.207985  0.363138
# 14  0.058166 -0.240525  0.320469
# 15  0.031447 -0.150943  0.360870
# 16 -0.031073 -0.293315  0.396583
# 17  0.200000 -0.016667  0.267807
# 18 -0.067527 -0.302825  0.407210
# 19 -0.053262 -0.293190  0.388835
# 20 -0.065566 -0.315710  0.402385
# 21 -0.085956 -0.328692  0.415759
# 22 -0.073738 -0.306100  0.408020
# 23 -0.057327 -0.263957  0.386773
# 24 -0.095126 -0.360063  0.422211
# 25 -0.047316 -0.384769  0.360328
# 26  0.025000 -0.187500  0.321893
#
# === Plot SPD/DI for each Unpriv Subgroup vs. 'Asian_Female' ===
# === (B) Lumped Bias => 'Asian_Female' privileged vs. ALL_OTHERS unpriv ===
# [pred_LogReg] Non-Asian_Female vs Asian_Female: SPD=-0.1090, DI=0.8565
# [pred_XGB] Non-Asian_Female vs Asian_Female: SPD=-0.0432, DI=0.9369
# [pred_MLP] Non-Asian_Female vs Asian_Female: SPD=-0.1163, DI=0.8430
#
# === Aggregated Bias Results (Lumped) ===
#           Model UnprivGroup     PrivGroup       SPD        DI       EOD  \
# 0  pred_LogReg  ALL_OTHERS  Asian_Female -0.108957  0.856496 -0.079052
# 1     pred_XGB  ALL_OTHERS  Asian_Female -0.043221  0.936920  0.001241
# 2     pred_MLP  ALL_OTHERS  Asian_Female -0.116329  0.842956 -0.062388
#
#         AOD   T_Index
# 0 -0.210430  0.369530
# 1 -0.194830  0.371651
# 2 -0.301796  0.400572
#
# === Plot SPD/DI => Non-Asian_Female vs 'Asian_Female' ===

# %%
results_dir = "dataset/train_test_extracted_oversample"

df_results_sep_OF.to_csv(os.path.join(results_dir, "bias_results_sep_OF.csv"), index=False)
df_results_lumped_OF.to_csv(os.path.join(results_dir, "bias_results_lumped_OF.csv"), index=False)

df_results_sep_AF.to_csv(os.path.join(results_dir, "bias_results_sep_AF.csv"), index=False)
df_results_lumped_AF.to_csv(os.path.join(results_dir, "bias_results_lumped_AF.csv"), index=False)
