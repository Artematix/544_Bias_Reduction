# %%
import os
import numpy as np
import pandas as pd

# Sklearn
from sklearn.metrics import accuracy_score, recall_score, f1_score
import joblib

# PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F

# AIF360
from aif360.datasets import BinaryLabelDataset
from aif360.metrics import ClassificationMetric

import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# WARNING:root:No module named 'tensorflow.python': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'
# WARNING:root:No module named 'tensorflow.python': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'
# WARNING:root:No module named 'fairlearn': ExponentiatedGradientReduction will be unavailable. To install, run:
# pip install 'aif360[Reductions]'
# WARNING:root:No module named 'fairlearn': GridSearchReduction will be unavailable. To install, run:
# pip install 'aif360[Reductions]'
# WARNING:root:No module named 'inFairness': SenSeI and SenSR will be unavailable. To install, run:
# pip install 'aif360[inFairness]'
# WARNING:root:No module named 'fairlearn': GridSearchReduction will be unavailable. To install, run:
# pip install 'aif360[Reductions]'

# %%
test_data = pd.read_csv('dataset/train_test_extracted_oversample/test_cherry_picked.csv')

race_map = {0: "Other", 1: "AfricanAmerican", 2: "Asian", 3: "Caucasian", 4: "Hispanic"}
gender_map = {0: "Female", 1: "Male"}

test_data['race_str'] = test_data['race'].map(race_map)
test_data['gender_str'] = test_data['gender'].map(gender_map)
test_data['race_gender'] = test_data['race_str'] + "_" + test_data['gender_str']

# readmitted=0 => favorable outcome ("no readmission")
# readmitted=1 => unfavorable outcome ("readmission")

# List of features for test
drop_cols = ['readmitted','race','gender','race_str','gender_str','race_gender',
             'race_AfricanAmerican','race_Asian','race_Caucasian','race_Hispanic','race_Other']
X_test = test_data.drop(columns=drop_cols)
y_test = test_data['readmitted']

print("X_test shape:", X_test.shape, "y_test shape:", y_test.shape)

model_paths = {
    'LogReg': 'models/oversample_cherry_picked/LogReg.joblib',
    'XGB':    'models/oversample_cherry_picked/XGB.joblib',
    'MLP':    'models/oversample_cherry_picked/MLP.pth'  # PyTorch model
}
# Out:
# X_test shape: (14924, 21) y_test shape: (14924,)

# %%
class SimpleNet(nn.Module):
    def __init__(self, input_dim, hidden_dim=64, num_classes=2):
        super(SimpleNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, num_classes)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        logits = self.fc2(x)
        return logits


for model_name, path in model_paths.items():
    print(f"\n=== Loading {model_name} ===")

    if model_name in ['LogReg','XGB']:
        # scikit-learn model
        model = joblib.load(path)


        if model_name == 'LogReg':
            scaler_path = "models/oversample_cherry_picked/scaler_LogReg.joblib"
            scaler = joblib.load(scaler_path)
            X_test_scaled = scaler.transform(X_test)
            y_pred = model.predict(X_test_scaled)
        elif model_name == 'XGB':

            y_pred = model.predict(X_test)

    else:

        input_dim = X_test.shape[1]
        mlp_model = SimpleNet(input_dim=input_dim, hidden_dim=64, num_classes=2)
        mlp_model.load_state_dict(torch.load(path))  # Load weights

        mlp_model.eval()
        X_test_t = torch.tensor(X_test.values, dtype=torch.float32)
        with torch.no_grad():
            logits = mlp_model(X_test_t)
            probs = F.softmax(logits, dim=1)
            y_pred = torch.argmax(probs, dim=1).numpy()

    acc = accuracy_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred, zero_division=0)
    f1 = f1_score(y_test, y_pred, zero_division=0)

    print(f"[{model_name}] Accuracy: {acc:.4f}, Recall: {rec:.4f}, F1: {f1:.4f}")

    # Store predictions for bias analysis
    pred_col = f"pred_{model_name}"
    test_data[pred_col] = y_pred
# Out:
# === Loading LogReg ===
# [LogReg] Accuracy: 0.6660, Recall: 0.4980, F1: 0.2554
#
# === Loading XGB ===
# [XGB] Accuracy: 0.6936, Recall: 0.4822, F1: 0.2659
#
# === Loading MLP ===
# [MLP] Accuracy: 0.6318, Recall: 0.5381, F1: 0.2517

# %%
def build_aif360_subset(df, label_col, pred_col, unpriv_group_val, priv_group_val):
    """
    Filters 'df' so it only contains rows where race_gender is either unpriv_group_val or priv_group_val.
    Then encodes 'race_gender' as 1 => unpriv, 0 => priv.
    Returns two BinaryLabelDatasets (one ground truth, one predicted).
    Also prints debug info on how many times label=1 vs 0 in truth & predictions.
    """

    # Filter DataFrame
    df_filtered = df[df['race_gender'].isin([unpriv_group_val, priv_group_val])].copy()
    if df_filtered.empty:
        return None, None

    # Binarize race_gender => 1 if unpriv, else 0
    df_filtered['race_gender'] = df_filtered['race_gender'].apply(
        lambda x: 1 if x == unpriv_group_val else 0
    )

    unpriv_count = (df_filtered['race_gender'] == 1).sum()
    priv_count   = (df_filtered['race_gender'] == 0).sum()

    # Build dataset_true
    df_true = df_filtered[['race_gender', label_col]].copy()
    df_true.rename(columns={label_col: 'label'}, inplace=True)

    # Count how many label=1 vs. 0 in ground truth
    true_ones  = (df_true['label'] == 1).sum()
    true_zeros = (df_true['label'] == 0).sum()

    dataset_true = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_true,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    # Build dataset_pred
    df_pred = df_filtered[['race_gender', pred_col]].copy()
    df_pred.rename(columns={pred_col: 'label'}, inplace=True)

    # Count how many label=1 vs. 0 in predictions
    pred_ones  = (df_pred['label'] == 1).sum()
    pred_zeros = (df_pred['label'] == 0).sum()

    dataset_pred = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_pred,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    # Debug prints
    print(f"\n[DEBUG] build_aif360_subset => unpriv='{unpriv_group_val}'(=1), "
          f"priv='{priv_group_val}'(=0)")
    print(f"   => #rows in subset: {len(df_filtered)} (unpriv_count={unpriv_count}, priv_count={priv_count})")
    print(f"   => GroundTruth: label=1 => {true_ones}, label=0 => {true_zeros}")
    print(f"   => Predictions: label=1 => {pred_ones}, label=0 => {pred_zeros}")

    return dataset_true, dataset_pred


def compute_bias_metrics(dataset_true, dataset_pred):
    metric = ClassificationMetric(
        dataset_true,
        dataset_pred,
        unprivileged_groups=[{'race_gender': 1}],
        privileged_groups=[{'race_gender': 0}]
    )
    spd = metric.statistical_parity_difference()
    di = metric.disparate_impact()
    eod = metric.equal_opportunity_difference()  
    aod = metric.average_odds_difference()       
    t_index = metric.theil_index()               
    return spd, di, eod, aod, t_index



def plot_fairness_bar(df, x_col, y_col, hue_col, title,
                      width=8, height=6, ref_line=None,
                      label_fontsize=8):

    plt.figure(figsize=(width, height))
    ax = sns.barplot(data=df, x=x_col, y=y_col, hue=hue_col)

    if ref_line is not None:
        plt.axhline(ref_line, color='black', linewidth=1)

    for container in ax.containers:
        ax.bar_label(container, fmt="%.2f", label_type='edge', 
                     padding=3, fontsize=label_fontsize)

    plt.title(title)
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()


def build_aif360_subset_lumped(df, label_col, pred_col, privileged_grp="Asian_Female"):
    """
    Instead of splitting each unpriv group individually,
    we lump "everything that is not privileged_grp" into unpriv (1).
    """
    # Copy entire df (no filter for specific groups)
    df_temp = df.copy()

    # Binarize: 1 if not privileged_grp, else 0
    df_temp['race_gender'] = df_temp['race_gender'].apply(
        lambda x: 0 if x == privileged_grp else 1
    )

    # Build dataset_true
    df_true = df_temp[['race_gender', label_col]].copy()
    df_true.rename(columns={label_col: 'label'}, inplace=True)
    dataset_true = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_true,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    # Build dataset_pred
    df_pred = df_temp[['race_gender', pred_col]].copy()
    df_pred.rename(columns={pred_col: 'label'}, inplace=True)
    dataset_pred = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_pred,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    return dataset_true, dataset_pred

# %%
print("\n=== (A) Bias Analysis per Subgroup vs. 'Other_Female' ===")

UNPRIV_GROUP_OF = "Other_Female"
all_race_genders = test_data['race_gender'].unique()
privileged_groups = [g for g in all_race_genders if g != UNPRIV_GROUP_OF]

results_sep_OF = []
model_predictions = ['pred_LogReg','pred_XGB','pred_MLP']

for model_col in model_predictions:
    print(f"\n--- Model: {model_col}, Unprivileged: {UNPRIV_GROUP_OF} ---")
    for priv_grp in privileged_groups:
        ds_true, ds_pred = build_aif360_subset(
            df=test_data,
            label_col='readmitted',
            pred_col=model_col,
            unpriv_group_val=UNPRIV_GROUP_OF, 
            priv_group_val=priv_grp           
        )
        if ds_true is None or ds_pred is None:
            print(f"   WARNING: No data for group={priv_grp}; skipping.")
            continue

        spd, di, eod, aod, t_index = compute_bias_metrics(ds_true, ds_pred)
        print(f"   Compare {UNPRIV_GROUP_OF} vs {priv_grp}: SPD={spd:.4f}, DI={di:.4f}")

        results_sep_OF.append({
            'Model': model_col,
            'UnprivGroup': UNPRIV_GROUP_OF,
            'PrivGroup': priv_grp,
            'SPD': spd,
            'DI': di,
            'EOD': eod,
            'AOD': aod,
            'T_Index': t_index
        })

df_results_sep_OF = pd.DataFrame(results_sep_OF)
print("\n=== Aggregated Bias Results (Individual Groups) ===\n", df_results_sep_OF)

print("\n=== Plot SPD/DI for each Subgroup vs. Other_Female ===")
plot_fairness_bar(
    df=df_results_sep_OF,
    x_col='PrivGroup',
    y_col='SPD',
    hue_col='Model',
    title=f"Statistical Parity Difference vs. {UNPRIV_GROUP_OF} (Unpriv)",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_sep_OF,
    x_col='PrivGroup',
    y_col='DI',
    hue_col='Model',
    title=f"Disparate Impact vs. {UNPRIV_GROUP_OF} (Unpriv)",
    ref_line=1
)


def build_aif360_subset_lumped_OF(df, label_col, pred_col):
    """
    Lump: 'Other_Female' => 1 (unpriv), everything else => 0 (priv).
    """
    df_temp = df.copy()
    df_temp['race_gender'] = df_temp['race_gender'].apply(
        lambda x: 1 if x == "Other_Female" else 0
    )
    # Build dataset_true
    df_true = df_temp[[ 'race_gender', label_col]].copy()
    df_true.rename(columns={label_col: 'label'}, inplace=True)
    dataset_true = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_true,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )
    # Build dataset_pred
    df_pred = df_temp[['race_gender', pred_col]].copy()
    df_pred.rename(columns={pred_col: 'label'}, inplace=True)
    dataset_pred = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_pred,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )
    return dataset_true, dataset_pred


print("\n=== (B) Lumps => 'Other_Female' unpriv, All Others => priv ===")
results_lumped_OF = []

for model_col in model_predictions:
    ds_true_lumped, ds_pred_lumped = build_aif360_subset_lumped_OF(
        df=test_data,
        label_col='readmitted',
        pred_col=model_col
    )
    spd, di, eod, aod, t_index = compute_bias_metrics(ds_true_lumped, ds_pred_lumped)
    print(f"[{model_col}] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD={spd:.4f}, DI={di:.4f}")
    results_lumped_OF.append({
        'Model': model_col,
        'UnprivGroup': "Other_Female",
        'PrivGroup': "ALL_OTHERS",
        'SPD': spd,
        'DI': di,
        'EOD': eod,
        'AOD': aod,
        'T_Index': t_index
    })

df_results_lumped_OF = pd.DataFrame(results_lumped_OF)
print("\n=== Aggregated Bias Results (Lumped) ===\n", df_results_lumped_OF)

print("\n=== Plot SPD/DI => 'Other_Female'(unpriv) vs ALL_OTHERS ===")
plot_fairness_bar(
    df=df_results_lumped_OF,
    x_col='UnprivGroup',
    y_col='SPD',
    hue_col='Model',
    title="Statistical Parity Difference (Other_Female vs. ALL_OTHERS)",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_lumped_OF,
    x_col='UnprivGroup',
    y_col='DI',
    hue_col='Model',
    title="Disparate Impact (Other_Female vs. ALL_OTHERS)",
    ref_line=1
)
# Out:
# === (A) Bias Analysis per Subgroup vs. 'Other_Female' ===
#
# --- Model: pred_LogReg, Unprivileged: Other_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Female'(=0)
#    => #rows in subset: 6077 (unpriv_count=136, priv_count=5941)
#    => GroundTruth: label=1 => 700, label=0 => 5377
#    => Predictions: label=1 => 2099, label=0 => 3978
#    Compare Other_Female vs Caucasian_Female: SPD=0.0449, DI=1.0688
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Male'(=0)
#    => #rows in subset: 5527 (unpriv_count=136, priv_count=5391)
#    => GroundTruth: label=1 => 637, label=0 => 4890
#    => Predictions: label=1 => 1775, label=0 => 3752
#    Compare Other_Female vs Caucasian_Male: SPD=0.0202, DI=1.0297
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Female'(=0)
#    => #rows in subset: 1931 (unpriv_count=136, priv_count=1795)
#    => GroundTruth: label=1 => 223, label=0 => 1708
#    => Predictions: label=1 => 646, label=0 => 1285
#    Compare Other_Female vs AfricanAmerican_Female: SPD=0.0356, DI=1.0537
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Male'(=0)
#    => #rows in subset: 293 (unpriv_count=136, priv_count=157)
#    => GroundTruth: label=1 => 32, label=0 => 261
#    => Predictions: label=1 => 82, label=0 => 211
#    Compare Other_Female vs Hispanic_Male: SPD=-0.0403, DI=0.9454
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Male'(=0)
#    => #rows in subset: 1256 (unpriv_count=136, priv_count=1120)
#    => GroundTruth: label=1 => 161, label=0 => 1095
#    => Predictions: label=1 => 430, label=0 => 826
#    Compare Other_Female vs AfricanAmerican_Male: SPD=0.0459, DI=1.0703
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Female'(=0)
#    => #rows in subset: 302 (unpriv_count=136, priv_count=166)
#    => GroundTruth: label=1 => 35, label=0 => 267
#    => Predictions: label=1 => 89, label=0 => 213
#    Compare Other_Female vs Hispanic_Female: SPD=-0.0123, DI=0.9827
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Other_Male'(=0)
#    => #rows in subset: 250 (unpriv_count=136, priv_count=114)
#    => GroundTruth: label=1 => 26, label=0 => 224
#    => Predictions: label=1 => 81, label=0 => 169
#    Compare Other_Female vs Other_Male: SPD=0.0494, DI=1.0761
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 51, label=0 => 139
#    Compare Other_Female vs Asian_Female: SPD=-0.1163, DI=0.8573
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Male'(=0)
#    => #rows in subset: 186 (unpriv_count=136, priv_count=50)
#    => GroundTruth: label=1 => 23, label=0 => 163
#    => Predictions: label=1 => 53, label=0 => 133
#    Compare Other_Female vs Asian_Male: SPD=-0.0615, DI=0.9191
#
# --- Model: pred_XGB, Unprivileged: Other_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Female'(=0)
#    => #rows in subset: 6077 (unpriv_count=136, priv_count=5941)
#    => GroundTruth: label=1 => 700, label=0 => 5377
#    => Predictions: label=1 => 1977, label=0 => 4100
#    Compare Other_Female vs Caucasian_Female: SPD=0.0169, DI=1.0250
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Male'(=0)
#    => #rows in subset: 5527 (unpriv_count=136, priv_count=5391)
#    => GroundTruth: label=1 => 637, label=0 => 4890
#    => Predictions: label=1 => 1541, label=0 => 3986
#    Compare Other_Female vs Caucasian_Male: SPD=-0.0308, DI=0.9574
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Female'(=0)
#    => #rows in subset: 1931 (unpriv_count=136, priv_count=1795)
#    => GroundTruth: label=1 => 223, label=0 => 1708
#    => Predictions: label=1 => 587, label=0 => 1344
#    Compare Other_Female vs AfricanAmerican_Female: SPD=-0.0052, DI=0.9925
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Male'(=0)
#    => #rows in subset: 293 (unpriv_count=136, priv_count=157)
#    => GroundTruth: label=1 => 32, label=0 => 261
#    => Predictions: label=1 => 90, label=0 => 203
#    Compare Other_Female vs Hispanic_Male: SPD=-0.0031, DI=0.9955
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Male'(=0)
#    => #rows in subset: 1256 (unpriv_count=136, priv_count=1120)
#    => GroundTruth: label=1 => 161, label=0 => 1095
#    => Predictions: label=1 => 386, label=0 => 870
#    Compare Other_Female vs AfricanAmerican_Male: SPD=-0.0017, DI=0.9976
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Female'(=0)
#    => #rows in subset: 302 (unpriv_count=136, priv_count=166)
#    => GroundTruth: label=1 => 35, label=0 => 267
#    => Predictions: label=1 => 87, label=0 => 215
#    Compare Other_Female vs Hispanic_Female: SPD=-0.0377, DI=0.9482
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Other_Male'(=0)
#    => #rows in subset: 250 (unpriv_count=136, priv_count=114)
#    => GroundTruth: label=1 => 26, label=0 => 224
#    => Predictions: label=1 => 74, label=0 => 176
#    Compare Other_Female vs Other_Male: SPD=-0.0281, DI=0.9609
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 57, label=0 => 133
#    Compare Other_Female vs Asian_Female: SPD=-0.0310, DI=0.9570
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Male'(=0)
#    => #rows in subset: 186 (unpriv_count=136, priv_count=50)
#    => GroundTruth: label=1 => 23, label=0 => 163
#    => Predictions: label=1 => 49, label=0 => 137
#    Compare Other_Female vs Asian_Male: SPD=-0.1688, DI=0.8037
#
# --- Model: pred_MLP, Unprivileged: Other_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Female'(=0)
#    => #rows in subset: 6077 (unpriv_count=136, priv_count=5941)
#    => GroundTruth: label=1 => 700, label=0 => 5377
#    => Predictions: label=1 => 2434, label=0 => 3643
#    Compare Other_Female vs Caucasian_Female: SPD=0.0261, DI=1.0436
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Male'(=0)
#    => #rows in subset: 5527 (unpriv_count=136, priv_count=5391)
#    => GroundTruth: label=1 => 637, label=0 => 4890
#    => Predictions: label=1 => 1997, label=0 => 3530
#    Compare Other_Female vs Caucasian_Male: SPD=-0.0140, DI=0.9780
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Female'(=0)
#    => #rows in subset: 1931 (unpriv_count=136, priv_count=1795)
#    => GroundTruth: label=1 => 223, label=0 => 1708
#    => Predictions: label=1 => 743, label=0 => 1188
#    Compare Other_Female vs AfricanAmerican_Female: SPD=0.0105, DI=1.0171
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Male'(=0)
#    => #rows in subset: 293 (unpriv_count=136, priv_count=157)
#    => GroundTruth: label=1 => 32, label=0 => 261
#    => Predictions: label=1 => 98, label=0 => 195
#    Compare Other_Female vs Hispanic_Male: SPD=-0.0756, DI=0.8920
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Male'(=0)
#    => #rows in subset: 1256 (unpriv_count=136, priv_count=1120)
#    => GroundTruth: label=1 => 161, label=0 => 1095
#    => Predictions: label=1 => 441, label=0 => 815
#    Compare Other_Female vs AfricanAmerican_Male: SPD=-0.0268, DI=0.9589
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Female'(=0)
#    => #rows in subset: 302 (unpriv_count=136, priv_count=166)
#    => GroundTruth: label=1 => 35, label=0 => 267
#    => Predictions: label=1 => 107, label=0 => 195
#    Compare Other_Female vs Hispanic_Female: SPD=-0.0377, DI=0.9432
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Other_Male'(=0)
#    => #rows in subset: 250 (unpriv_count=136, priv_count=114)
#    => GroundTruth: label=1 => 26, label=0 => 224
#    => Predictions: label=1 => 85, label=0 => 165
#    Compare Other_Female vs Other_Male: SPD=-0.0768, DI=0.8906
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 68, label=0 => 122
#    Compare Other_Female vs Asian_Female: SPD=-0.0602, DI=0.9122
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Male'(=0)
#    => #rows in subset: 186 (unpriv_count=136, priv_count=50)
#    => GroundTruth: label=1 => 23, label=0 => 163
#    => Predictions: label=1 => 61, label=0 => 125
#    Compare Other_Female vs Asian_Male: SPD=-0.1750, DI=0.7812
#
# === Aggregated Bias Results (Individual Groups) ===
#            Model   UnprivGroup               PrivGroup       SPD        DI  \
# 0   pred_LogReg  Other_Female        Caucasian_Female  0.044936  1.068752
# 1   pred_LogReg  Other_Female          Caucasian_Male  0.020177  1.029744
# 2   pred_LogReg  Other_Female  AfricanAmerican_Female  0.035577  1.053664
# 3   pred_LogReg  Other_Female           Hispanic_Male -0.040324  0.945423
# 4   pred_LogReg  Other_Female    AfricanAmerican_Male  0.045851  1.070250
# 5   pred_LogReg  Other_Female         Hispanic_Female -0.012314  0.982677
# 6   pred_LogReg  Other_Female              Other_Male  0.049407  1.076113
# 7   pred_LogReg  Other_Female            Asian_Female -0.116285  0.857286
# 8   pred_LogReg  Other_Female              Asian_Male -0.061471  0.919118
# 9      pred_XGB  Other_Female        Caucasian_Female  0.016879  1.025032
# 10     pred_XGB  Other_Female          Caucasian_Male -0.030768  0.957382
# 11     pred_XGB  Other_Female  AfricanAmerican_Female -0.005202  0.992529
# 12     pred_XGB  Other_Female           Hispanic_Male -0.003091  0.995548
# 13     pred_XGB  Other_Female    AfricanAmerican_Male -0.001681  0.997574
# 14     pred_XGB  Other_Female         Hispanic_Female -0.037739  0.948226
# 15     pred_XGB  Other_Female              Other_Male -0.028122  0.960904
# 16     pred_XGB  Other_Female            Asian_Female -0.031046  0.957014
# 17     pred_XGB  Other_Female              Asian_Male -0.168824  0.803694
# 18     pred_MLP  Other_Female        Caucasian_Female  0.026111  1.043599
# 19     pred_MLP  Other_Female          Caucasian_Male -0.014028  0.978048
# 20     pred_MLP  Other_Female  AfricanAmerican_Female  0.010515  1.017112
# 21     pred_MLP  Other_Female           Hispanic_Male -0.075637  0.892045
# 22     pred_MLP  Other_Female    AfricanAmerican_Male -0.026786  0.958904
# 23     pred_MLP  Other_Female         Hispanic_Female -0.037651  0.943182
# 24     pred_MLP  Other_Female              Other_Male -0.076754  0.890625
# 25     pred_MLP  Other_Female            Asian_Female -0.060185  0.912162
# 26     pred_MLP  Other_Female              Asian_Male -0.175000  0.781250
#
#          EOD       AOD   T_Index
# 0   0.062825  0.007301  0.363583
# 1   0.038210 -0.017962  0.334461
# 2   0.053640 -0.002177  0.349295
# 3  -0.031943 -0.008035  0.266980
# 4   0.059704  0.010815  0.349168
# 5  -0.000967 -0.013555  0.286437
# 6   0.058043  0.126244  0.319553
# 7  -0.054379 -0.304967  0.272342
# 8  -0.040490 -0.098023  0.273642
# 9   0.054675 -0.073510  0.331781
# 10  0.012200 -0.138533  0.285355
# 11  0.037885 -0.112900  0.311498
# 12  0.047944 -0.122854  0.297276
# 13  0.028546 -0.081104  0.294215
# 14 -0.017575 -0.046369  0.249963
# 15  0.027822 -0.159700  0.281822
# 16  0.066737 -0.327742  0.287907
# 17 -0.134652 -0.228437  0.219888
# 18  0.060168 -0.057567  0.436175
# 19  0.018285 -0.091872  0.382919
# 20  0.042117 -0.064443  0.409041
# 21 -0.056300 -0.067832  0.316293
# 22  0.000382 -0.098683  0.355913
# 23 -0.033443  0.004520  0.326594
# 24 -0.039015 -0.130619  0.334510
# 25  0.011299 -0.272128  0.358369
# 26 -0.122034 -0.322128  0.312836
#
# === Plot SPD/DI for each Subgroup vs. Other_Female ===
# === (B) Lumps => 'Other_Female' unpriv, All Others => priv ===
# [pred_LogReg] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD=0.0324, DI=1.0486
# [pred_XGB] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD=-0.0066, DI=0.9906
# [pred_MLP] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD=0.0020, DI=1.0032
#
# === Aggregated Bias Results (Lumped) ===
#           Model   UnprivGroup   PrivGroup       SPD        DI       EOD  \
# 0  pred_LogReg  Other_Female  ALL_OTHERS  0.032381  1.048610  0.049917
# 1     pred_XGB  Other_Female  ALL_OTHERS -0.006551  0.990610  0.033479
# 2     pred_MLP  Other_Female  ALL_OTHERS  0.001995  1.003202  0.034296
#
#         AOD   T_Index
# 0 -0.004144  0.349009
# 1 -0.104524  0.308980
# 2 -0.075864  0.403516
#
# === Plot SPD/DI => 'Other_Female'(unpriv) vs ALL_OTHERS ===

# %%
print("\n=== (A) Bias Analysis: Subgroup vs. 'Asian_Female' (Privileged) ===")

PRIV_GROUP_AF = "Asian_Female"
# all subgroups that are NOT 'Asian_Female' are tested as unprivileged, one by one
all_race_genders = test_data['race_gender'].unique()
unprivileged_groups = [g for g in all_race_genders if g != PRIV_GROUP_AF]

results_sep_AF = []
model_predictions = ['pred_LogReg','pred_XGB','pred_MLP']

for model_col in model_predictions:
    print(f"\n--- Model: {model_col}, Privileged: {PRIV_GROUP_AF} ---")
    for unpriv_grp in unprivileged_groups:
        ds_true, ds_pred = build_aif360_subset(
            df=test_data,
            label_col='readmitted',
            pred_col=model_col,
            unpriv_group_val=unpriv_grp,      # => 1
            priv_group_val=PRIV_GROUP_AF      # => 0
        )
        if ds_true is None or ds_pred is None:
            # If no rows match unpriv_grp or PRIV_GROUP_AF in test_data['race_gender']
            continue

        spd, di, eod, aod, t_index = compute_bias_metrics(ds_true, ds_pred)
        print(f"   Compare unpriv={unpriv_grp} vs priv={PRIV_GROUP_AF}: SPD={spd:.4f}, DI={di:.4f}")

        results_sep_AF.append({
            'Model': model_col,
            'UnprivGroup': unpriv_grp,
            'PrivGroup': PRIV_GROUP_AF,
            'SPD': spd,
            'DI': di,
            'EOD': eod,
            'AOD': aod,
            'T_Index': t_index
        })

df_results_sep_AF = pd.DataFrame(results_sep_AF)
print("\n=== Aggregated Bias Results (Individual Subgroups) ===\n", df_results_sep_AF)

# Plot SPD & DI
print("\n=== Plot SPD/DI for each Unpriv Subgroup vs. 'Asian_Female' ===")
plot_fairness_bar(
    df=df_results_sep_AF,
    x_col='UnprivGroup',
    y_col='SPD',
    hue_col='Model',
    title=f"Statistical Parity Difference vs. {PRIV_GROUP_AF}",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_sep_AF,
    x_col='UnprivGroup',
    y_col='DI',
    hue_col='Model',
    title=f"Disparate Impact vs. {PRIV_GROUP_AF}",
    ref_line=1
)


print("\n=== (B) Lumped Bias => 'Asian_Female' privileged vs. ALL_OTHERS unpriv ===")

results_lumped_AF = []

for model_col in model_predictions:
    ds_true_lumped, ds_pred_lumped = build_aif360_subset_lumped(
        df=test_data,
        label_col='readmitted',
        pred_col=model_col,
        privileged_grp=PRIV_GROUP_AF
    )
    # This lumps everything that is not 'Asian_Female' => 1, 
    # 'Asian_Female' => 0

    spd, di, eod, aod, t_index = compute_bias_metrics(ds_true_lumped, ds_pred_lumped)
    print(f"[{model_col}] Non-Asian_Female vs {PRIV_GROUP_AF}: SPD={spd:.4f}, DI={di:.4f}")

    results_lumped_AF.append({
        'Model': model_col,
        'UnprivGroup': "ALL_OTHERS",
        'PrivGroup': PRIV_GROUP_AF,
        'SPD': spd,
        'DI': di,
        'EOD': eod,
        'AOD': aod,
        'T_Index': t_index
    })

df_results_lumped_AF = pd.DataFrame(results_lumped_AF)
print("\n=== Aggregated Bias Results (Lumped) ===\n", df_results_lumped_AF)

print("\n=== Plot SPD/DI => Non-Asian_Female vs 'Asian_Female' ===")
plot_fairness_bar(
    df=df_results_lumped_AF,
    x_col='UnprivGroup',
    y_col='SPD',
    hue_col='Model',
    title=f"Statistical Parity Difference (All Non-Asian_Female vs. {PRIV_GROUP_AF})",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_lumped_AF,
    x_col='UnprivGroup',
    y_col='DI',
    hue_col='Model',
    title=f"Disparate Impact (All Non-Asian_Female vs. {PRIV_GROUP_AF})",
    ref_line=1
)
# Out:
# === (A) Bias Analysis: Subgroup vs. 'Asian_Female' (Privileged) ===
#
# --- Model: pred_LogReg, Privileged: Asian_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5995 (unpriv_count=5941, priv_count=54)
#    => GroundTruth: label=1 => 688, label=0 => 5307
#    => Predictions: label=1 => 2068, label=0 => 3927
#    Compare unpriv=Caucasian_Female vs priv=Asian_Female: SPD=-0.1612, DI=0.8021
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5445 (unpriv_count=5391, priv_count=54)
#    => GroundTruth: label=1 => 625, label=0 => 4820
#    => Predictions: label=1 => 1744, label=0 => 3701
#    Compare unpriv=Caucasian_Male vs priv=Asian_Female: SPD=-0.1365, DI=0.8325
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1849 (unpriv_count=1795, priv_count=54)
#    => GroundTruth: label=1 => 211, label=0 => 1638
#    => Predictions: label=1 => 615, label=0 => 1234
#    Compare unpriv=AfricanAmerican_Female vs priv=Asian_Female: SPD=-0.1519, DI=0.8136
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 211 (unpriv_count=157, priv_count=54)
#    => GroundTruth: label=1 => 20, label=0 => 191
#    => Predictions: label=1 => 51, label=0 => 160
#    Compare unpriv=Hispanic_Male vs priv=Asian_Female: SPD=-0.0760, DI=0.9068
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1174 (unpriv_count=1120, priv_count=54)
#    => GroundTruth: label=1 => 149, label=0 => 1025
#    => Predictions: label=1 => 399, label=0 => 775
#    Compare unpriv=AfricanAmerican_Male vs priv=Asian_Female: SPD=-0.1621, DI=0.8010
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 220 (unpriv_count=166, priv_count=54)
#    => GroundTruth: label=1 => 23, label=0 => 197
#    => Predictions: label=1 => 58, label=0 => 162
#    Compare unpriv=Hispanic_Female vs priv=Asian_Female: SPD=-0.1040, DI=0.8724
#
# [DEBUG] build_aif360_subset => unpriv='Other_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 168 (unpriv_count=114, priv_count=54)
#    => GroundTruth: label=1 => 14, label=0 => 154
#    => Predictions: label=1 => 50, label=0 => 118
#    Compare unpriv=Other_Male vs priv=Asian_Female: SPD=-0.1657, DI=0.7967
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 51, label=0 => 139
#    Compare unpriv=Other_Female vs priv=Asian_Female: SPD=-0.1163, DI=0.8573
#
# [DEBUG] build_aif360_subset => unpriv='Asian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 104 (unpriv_count=50, priv_count=54)
#    => GroundTruth: label=1 => 11, label=0 => 93
#    => Predictions: label=1 => 22, label=0 => 82
#    Compare unpriv=Asian_Male vs priv=Asian_Female: SPD=-0.0548, DI=0.9327
#
# --- Model: pred_XGB, Privileged: Asian_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5995 (unpriv_count=5941, priv_count=54)
#    => GroundTruth: label=1 => 688, label=0 => 5307
#    => Predictions: label=1 => 1950, label=0 => 4045
#    Compare unpriv=Caucasian_Female vs priv=Asian_Female: SPD=-0.0479, DI=0.9336
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5445 (unpriv_count=5391, priv_count=54)
#    => GroundTruth: label=1 => 625, label=0 => 4820
#    => Predictions: label=1 => 1514, label=0 => 3931
#    Compare unpriv=Caucasian_Male vs priv=Asian_Female: SPD=-0.0003, DI=0.9996
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1849 (unpriv_count=1795, priv_count=54)
#    => GroundTruth: label=1 => 211, label=0 => 1638
#    => Predictions: label=1 => 560, label=0 => 1289
#    Compare unpriv=AfricanAmerican_Female vs priv=Asian_Female: SPD=-0.0258, DI=0.9642
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 211 (unpriv_count=157, priv_count=54)
#    => GroundTruth: label=1 => 20, label=0 => 191
#    => Predictions: label=1 => 63, label=0 => 148
#    Compare unpriv=Hispanic_Male vs priv=Asian_Female: SPD=-0.0280, DI=0.9613
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1174 (unpriv_count=1120, priv_count=54)
#    => GroundTruth: label=1 => 149, label=0 => 1025
#    => Predictions: label=1 => 359, label=0 => 815
#    Compare unpriv=AfricanAmerican_Male vs priv=Asian_Female: SPD=-0.0294, DI=0.9593
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 220 (unpriv_count=166, priv_count=54)
#    => GroundTruth: label=1 => 23, label=0 => 197
#    => Predictions: label=1 => 60, label=0 => 160
#    Compare unpriv=Hispanic_Female vs priv=Asian_Female: SPD=0.0067, DI=1.0093
#
# [DEBUG] build_aif360_subset => unpriv='Other_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 168 (unpriv_count=114, priv_count=54)
#    => GroundTruth: label=1 => 14, label=0 => 154
#    => Predictions: label=1 => 47, label=0 => 121
#    Compare unpriv=Other_Male vs priv=Asian_Female: SPD=-0.0029, DI=0.9960
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 57, label=0 => 133
#    Compare unpriv=Other_Female vs priv=Asian_Female: SPD=-0.0310, DI=0.9570
#
# [DEBUG] build_aif360_subset => unpriv='Asian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 104 (unpriv_count=50, priv_count=54)
#    => GroundTruth: label=1 => 11, label=0 => 93
#    => Predictions: label=1 => 22, label=0 => 82
#    Compare unpriv=Asian_Male vs priv=Asian_Female: SPD=0.1378, DI=1.1908
#
# --- Model: pred_MLP, Privileged: Asian_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5995 (unpriv_count=5941, priv_count=54)
#    => GroundTruth: label=1 => 688, label=0 => 5307
#    => Predictions: label=1 => 2400, label=0 => 3595
#    Compare unpriv=Caucasian_Female vs priv=Asian_Female: SPD=-0.0863, DI=0.8741
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5445 (unpriv_count=5391, priv_count=54)
#    => GroundTruth: label=1 => 625, label=0 => 4820
#    => Predictions: label=1 => 1963, label=0 => 3482
#    Compare unpriv=Caucasian_Male vs priv=Asian_Female: SPD=-0.0462, DI=0.9326
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1849 (unpriv_count=1795, priv_count=54)
#    => GroundTruth: label=1 => 211, label=0 => 1638
#    => Predictions: label=1 => 709, label=0 => 1140
#    Compare unpriv=AfricanAmerican_Female vs priv=Asian_Female: SPD=-0.0707, DI=0.8968
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 211 (unpriv_count=157, priv_count=54)
#    => GroundTruth: label=1 => 20, label=0 => 191
#    => Predictions: label=1 => 64, label=0 => 147
#    Compare unpriv=Hispanic_Male vs priv=Asian_Female: SPD=0.0155, DI=1.0226
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1174 (unpriv_count=1120, priv_count=54)
#    => GroundTruth: label=1 => 149, label=0 => 1025
#    => Predictions: label=1 => 407, label=0 => 767
#    Compare unpriv=AfricanAmerican_Male vs priv=Asian_Female: SPD=-0.0334, DI=0.9513
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 220 (unpriv_count=166, priv_count=54)
#    => GroundTruth: label=1 => 23, label=0 => 197
#    => Predictions: label=1 => 73, label=0 => 147
#    Compare unpriv=Hispanic_Female vs priv=Asian_Female: SPD=-0.0225, DI=0.9671
#
# [DEBUG] build_aif360_subset => unpriv='Other_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 168 (unpriv_count=114, priv_count=54)
#    => GroundTruth: label=1 => 14, label=0 => 154
#    => Predictions: label=1 => 51, label=0 => 117
#    Compare unpriv=Other_Male vs priv=Asian_Female: SPD=0.0166, DI=1.0242
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 68, label=0 => 122
#    Compare unpriv=Other_Female vs priv=Asian_Female: SPD=-0.0602, DI=0.9122
#
# [DEBUG] build_aif360_subset => unpriv='Asian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 104 (unpriv_count=50, priv_count=54)
#    => GroundTruth: label=1 => 11, label=0 => 93
#    => Predictions: label=1 => 27, label=0 => 77
#    Compare unpriv=Asian_Male vs priv=Asian_Female: SPD=0.1148, DI=1.1676
#
# === Aggregated Bias Results (Individual Subgroups) ===
#            Model             UnprivGroup     PrivGroup       SPD        DI  \
# 0   pred_LogReg        Caucasian_Female  Asian_Female -0.161221  0.802138
# 1   pred_LogReg          Caucasian_Male  Asian_Female -0.136462  0.832524
# 2   pred_LogReg  AfricanAmerican_Female  Asian_Female -0.151862  0.813624
# 3   pred_LogReg           Hispanic_Male  Asian_Female -0.075961  0.906775
# 4   pred_LogReg    AfricanAmerican_Male  Asian_Female -0.162136  0.801015
# 5   pred_LogReg         Hispanic_Female  Asian_Female -0.103971  0.872399
# 6   pred_LogReg              Other_Male  Asian_Female -0.165692  0.796651
# 7   pred_LogReg            Other_Female  Asian_Female -0.116285  0.857286
# 8   pred_LogReg              Asian_Male  Asian_Female -0.054815  0.932727
# 9      pred_XGB        Caucasian_Female  Asian_Female -0.047925  0.933642
# 10     pred_XGB          Caucasian_Male  Asian_Female -0.000278  0.999615
# 11     pred_XGB  AfricanAmerican_Female  Asian_Female -0.025843  0.964217
# 12     pred_XGB           Hispanic_Male  Asian_Female -0.027955  0.961293
# 13     pred_XGB    AfricanAmerican_Male  Asian_Female -0.029365  0.959341
# 14     pred_XGB         Hispanic_Female  Asian_Female  0.006693  1.009268
# 15     pred_XGB              Other_Male  Asian_Female -0.002924  0.995951
# 16     pred_XGB            Other_Female  Asian_Female -0.031046  0.957014
# 17     pred_XGB              Asian_Male  Asian_Female  0.137778  1.190769
# 18     pred_MLP        Caucasian_Female  Asian_Female -0.086296  0.874054
# 19     pred_MLP          Caucasian_Male  Asian_Female -0.046157  0.932635
# 20     pred_MLP  AfricanAmerican_Female  Asian_Female -0.070701  0.896815
# 21     pred_MLP           Hispanic_Male  Asian_Female  0.015452  1.022551
# 22     pred_MLP    AfricanAmerican_Male  Asian_Female -0.033399  0.951255
# 23     pred_MLP         Hispanic_Female  Asian_Female -0.022535  0.967112
# 24     pred_MLP              Other_Male  Asian_Female  0.016569  1.024182
# 25     pred_MLP            Other_Female  Asian_Female -0.060185  0.912162
# 26     pred_MLP              Asian_Male  Asian_Female  0.114815  1.167568
#
#          EOD       AOD   T_Index
# 0  -0.117204 -0.312268  0.364347
# 1  -0.092589 -0.287005  0.334844
# 2  -0.108019 -0.302790  0.351107
# 3  -0.022436 -0.296932  0.251321
# 4  -0.114082 -0.315782  0.351984
# 5  -0.053412 -0.291412  0.278180
# 6  -0.112421 -0.431211  0.325180
# 7  -0.054379 -0.304967  0.272342
# 8  -0.013889 -0.206944  0.245949
# 9   0.012063 -0.254233  0.333902
# 10  0.054537 -0.189210  0.286880
# 11  0.028852 -0.214842  0.317311
# 12  0.018794 -0.204889  0.343419
# 13  0.038191 -0.246639  0.302059
# 14  0.084312 -0.281373  0.275046
# 15  0.038915 -0.168042  0.331647
# 16  0.066737 -0.327742  0.287907
# 17  0.201389 -0.099306  0.245949
# 18 -0.048869 -0.214561  0.437906
# 19 -0.006985 -0.180256  0.383943
# 20 -0.030818 -0.207685  0.413334
# 21  0.067599 -0.204296  0.316876
# 22  0.010918 -0.173446  0.358635
# 23  0.044743 -0.276648  0.331221
# 24  0.050314 -0.141509  0.344008
# 25  0.011299 -0.272128  0.358369
# 26  0.133333  0.050000  0.308834
#
# === Plot SPD/DI for each Unpriv Subgroup vs. 'Asian_Female' ===
# === (B) Lumped Bias => 'Asian_Female' privileged vs. ALL_OTHERS unpriv ===
# [pred_LogReg] Non-Asian_Female vs Asian_Female: SPD=-0.1489, DI=0.8172
# [pred_XGB] Non-Asian_Female vs Asian_Female: SPD=-0.0246, DI=0.9659
# [pred_MLP] Non-Asian_Female vs Asian_Female: SPD=-0.0624, DI=0.9089
#
# === Aggregated Bias Results (Lumped) ===
#           Model UnprivGroup     PrivGroup       SPD        DI       EOD  \
# 0  pred_LogReg  ALL_OTHERS  Asian_Female -0.148910  0.817246 -0.104228
# 1     pred_XGB  ALL_OTHERS  Asian_Female -0.024643  0.965879  0.033679
# 2     pred_MLP  ALL_OTHERS  Asian_Female -0.062388  0.908948 -0.022773
#
#         AOD   T_Index
# 0 -0.301968  0.349009
# 1 -0.225124  0.308980
# 2 -0.197778  0.403516
#
# === Plot SPD/DI => Non-Asian_Female vs 'Asian_Female' ===

# %%
results_dir = "dataset/train_test_extracted_oversample"

df_results_sep_OF.to_csv(os.path.join(results_dir, "bias_results_sep_OF_cherry_picked.csv"), index=False)
df_results_lumped_OF.to_csv(os.path.join(results_dir, "bias_results_lumped_OF_cherry_picked.csv"), index=False)

df_results_sep_AF.to_csv(os.path.join(results_dir, "bias_results_sep_AF_cherry_picked.csv"), index=False)
df_results_lumped_AF.to_csv(os.path.join(results_dir, "bias_results_lumped_AF_cherry_picked.csv"), index=False)
