# %%
import os
import numpy as np
import pandas as pd

# Sklearn
from sklearn.metrics import accuracy_score, recall_score, f1_score
import joblib

# PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F

# AIF360
from aif360.datasets import BinaryLabelDataset
from aif360.metrics import ClassificationMetric

import seaborn as sns
import matplotlib.pyplot as plt

# %%
test_data = pd.read_csv('dataset/train_test_extracted_oversample/test_all_demographics.csv')

race_map = {0: "Other", 1: "AfricanAmerican", 2: "Asian", 3: "Caucasian", 4: "Hispanic"}
gender_map = {0: "Female", 1: "Male"}

test_data['race_str'] = test_data['race'].map(race_map)
test_data['gender_str'] = test_data['gender'].map(gender_map)
test_data['race_gender'] = test_data['race_str'] + "_" + test_data['gender_str']

# List of features for test
drop_cols = ['readmitted','race','gender','race_str','gender_str','race_gender',
             'race_AfricanAmerican','race_Asian','race_Caucasian','race_Hispanic','race_Other']
X_test = test_data.drop(columns=drop_cols)
y_test = test_data['readmitted']

print("X_test shape:", X_test.shape, "y_test shape:", y_test.shape)


model_paths = {
    'LogReg': 'models/oversample_all_demographics/LogReg.joblib',
    'XGB':    'models/oversample_all_demographics/XGB.joblib',
    'MLP':    'models/oversample_all_demographics/MLP.pth'  # PyTorch model
}
# Out:
# X_test shape: (14924, 26) y_test shape: (14924,)

# %%
class SimpleNet(nn.Module):
    def __init__(self, input_dim, hidden_dim=64, num_classes=2):
        super(SimpleNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, num_classes)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        logits = self.fc2(x)
        return logits



for model_name, path in model_paths.items():
    print(f"\n=== Loading {model_name} ===")

    if model_name in ['LogReg','XGB']:
        # scikit-learn model
        model = joblib.load(path)


        if model_name == 'LogReg':
            scaler_path = "models/oversample_all_demographics/scaler_LogReg.joblib"
            scaler = joblib.load(scaler_path)
            X_test_scaled = scaler.transform(X_test)
            y_pred = model.predict(X_test_scaled)
        elif model_name == 'XGB':
            y_pred = model.predict(X_test)

    else:
        # PyTorch MLP
        # Must define the same architecture used at training
        input_dim = X_test.shape[1]
        mlp_model = SimpleNet(input_dim=input_dim, hidden_dim=64, num_classes=2)
        mlp_model.load_state_dict(torch.load(path))  # Load weights


        mlp_model.eval()
        X_test_t = torch.tensor(X_test.values, dtype=torch.float32)
        with torch.no_grad():
            logits = mlp_model(X_test_t)
            probs = F.softmax(logits, dim=1)
            y_pred = torch.argmax(probs, dim=1).numpy()

    acc = accuracy_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred, zero_division=0)
    f1 = f1_score(y_test, y_pred, zero_division=0)

    print(f"[{model_name}] Accuracy: {acc:.4f}, Recall: {rec:.4f}, F1: {f1:.4f}")

    # Store predictions for bias analysis
    pred_col = f"pred_{model_name}"
    test_data[pred_col] = y_pred
# Out:
# === Loading LogReg ===
# [LogReg] Accuracy: 0.6656, Recall: 0.4997, F1: 0.2559
#
# === Loading XGB ===
# [XGB] Accuracy: 0.6615, Recall: 0.5335, F1: 0.2661
#
# === Loading MLP ===
# [MLP] Accuracy: 0.6246, Recall: 0.5463, F1: 0.2509

# %%
def build_aif360_subset(df, label_col, pred_col, unpriv_group_val, priv_group_val):
    """
    Filters 'df' so it only contains rows where race_gender is either unpriv_group_val or priv_group_val.
    Then encodes 'race_gender' as 1 => unpriv, 0 => priv.
    Returns two BinaryLabelDatasets (one ground truth, one predicted).
    Also prints debug info on how many times label=1 vs 0 in truth & predictions.
    """

    # Filter DataFrame
    df_filtered = df[df['race_gender'].isin([unpriv_group_val, priv_group_val])].copy()
    if df_filtered.empty:
        return None, None

    # Binarize race_gender => 1 if unpriv, else 0
    df_filtered['race_gender'] = df_filtered['race_gender'].apply(
        lambda x: 1 if x == unpriv_group_val else 0
    )

    unpriv_count = (df_filtered['race_gender'] == 1).sum()
    priv_count   = (df_filtered['race_gender'] == 0).sum()

    # Build dataset_true
    df_true = df_filtered[['race_gender', label_col]].copy()
    df_true.rename(columns={label_col: 'label'}, inplace=True)

    # Count how many label=1 vs. 0 in ground truth
    true_ones  = (df_true['label'] == 1).sum()
    true_zeros = (df_true['label'] == 0).sum()

    dataset_true = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_true,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    # Build dataset_pred
    df_pred = df_filtered[['race_gender', pred_col]].copy()
    df_pred.rename(columns={pred_col: 'label'}, inplace=True)

    # Count how many label=1 vs. 0 in predictions
    pred_ones  = (df_pred['label'] == 1).sum()
    pred_zeros = (df_pred['label'] == 0).sum()

    dataset_pred = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_pred,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    # Debug prints
    print(f"\n[DEBUG] build_aif360_subset => unpriv='{unpriv_group_val}'(=1), "
          f"priv='{priv_group_val}'(=0)")
    print(f"   => #rows in subset: {len(df_filtered)} (unpriv_count={unpriv_count}, priv_count={priv_count})")
    print(f"   => GroundTruth: label=1 => {true_ones}, label=0 => {true_zeros}")
    print(f"   => Predictions: label=1 => {pred_ones}, label=0 => {pred_zeros}")

    return dataset_true, dataset_pred


def compute_bias_metrics(dataset_true, dataset_pred):
    metric = ClassificationMetric(
        dataset_true,
        dataset_pred,
        unprivileged_groups=[{'race_gender': 1}],
        privileged_groups=[{'race_gender': 0}]
    )
    spd = metric.statistical_parity_difference()
    di = metric.disparate_impact()
    eod = metric.equal_opportunity_difference()  
    aod = metric.average_odds_difference()       
    t_index = metric.theil_index()               
    return spd, di, eod, aod, t_index



def plot_fairness_bar(df, x_col, y_col, hue_col, title,
                      width=8, height=6, ref_line=None,
                      label_fontsize=8):

    plt.figure(figsize=(width, height))
    ax = sns.barplot(data=df, x=x_col, y=y_col, hue=hue_col)

    if ref_line is not None:
        plt.axhline(ref_line, color='black', linewidth=1)

    for container in ax.containers:
        ax.bar_label(container, fmt="%.2f", label_type='edge', 
                     padding=3, fontsize=label_fontsize)

    plt.title(title)
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()


def build_aif360_subset_lumped(df, label_col, pred_col, privileged_grp="Asian_Female"):
    """
    Instead of splitting each unpriv group individually,
    we lump "everything that is not privileged_grp" into unpriv (1).
    """
    # Copy entire df (no filter for specific groups)
    df_temp = df.copy()

    # Binarize: 1 if not privileged_grp, else 0
    df_temp['race_gender'] = df_temp['race_gender'].apply(
        lambda x: 0 if x == privileged_grp else 1
    )

    # Build dataset_true
    df_true = df_temp[['race_gender', label_col]].copy()
    df_true.rename(columns={label_col: 'label'}, inplace=True)
    dataset_true = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_true,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    # Build dataset_pred
    df_pred = df_temp[['race_gender', pred_col]].copy()
    df_pred.rename(columns={pred_col: 'label'}, inplace=True)
    dataset_pred = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_pred,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    return dataset_true, dataset_pred

# %%
print("\n=== (A) Bias Analysis per Subgroup vs. 'Other_Female' ===")

UNPRIV_GROUP_OF = "Other_Female"
all_race_genders = test_data['race_gender'].unique()
privileged_groups = [g for g in all_race_genders if g != UNPRIV_GROUP_OF]

results_sep_OF = []
model_predictions = ['pred_LogReg','pred_XGB','pred_MLP']

for model_col in model_predictions:
    print(f"\n--- Model: {model_col}, Unprivileged: {UNPRIV_GROUP_OF} ---")
    for priv_grp in privileged_groups:
        ds_true, ds_pred = build_aif360_subset(
            df=test_data,
            label_col='readmitted',
            pred_col=model_col,
            unpriv_group_val=UNPRIV_GROUP_OF, 
            priv_group_val=priv_grp           
        )
        if ds_true is None or ds_pred is None:
            print(f"   WARNING: No data for group={priv_grp}; skipping.")
            continue

        spd, di, eod, aod, t_index = compute_bias_metrics(ds_true, ds_pred)
        print(f"   Compare {UNPRIV_GROUP_OF} vs {priv_grp}: SPD={spd:.4f}, DI={di:.4f}")

        results_sep_OF.append({
            'Model': model_col,
            'UnprivGroup': UNPRIV_GROUP_OF,
            'PrivGroup': priv_grp,
            'SPD': spd,
            'DI': di,
            'EOD': eod,
            'AOD': aod,
            'T_Index': t_index
        })

df_results_sep_OF = pd.DataFrame(results_sep_OF)
print("\n=== Aggregated Bias Results (Individual Groups) ===\n", df_results_sep_OF)

print("\n=== Plot SPD/DI for each Subgroup vs. Other_Female ===")
plot_fairness_bar(
    df=df_results_sep_OF,
    x_col='PrivGroup',
    y_col='SPD',
    hue_col='Model',
    title=f"Statistical Parity Difference vs. {UNPRIV_GROUP_OF} (Unpriv)",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_sep_OF,
    x_col='PrivGroup',
    y_col='DI',
    hue_col='Model',
    title=f"Disparate Impact vs. {UNPRIV_GROUP_OF} (Unpriv)",
    ref_line=1
)


def build_aif360_subset_lumped_OF(df, label_col, pred_col):
    """
    Lump: 'Other_Female' => 1 (unpriv), everything else => 0 (priv).
    """
    df_temp = df.copy()
    df_temp['race_gender'] = df_temp['race_gender'].apply(
        lambda x: 1 if x == "Other_Female" else 0
    )
    # Build dataset_true
    df_true = df_temp[[ 'race_gender', label_col]].copy()
    df_true.rename(columns={label_col: 'label'}, inplace=True)
    dataset_true = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_true,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )
    # Build dataset_pred
    df_pred = df_temp[['race_gender', pred_col]].copy()
    df_pred.rename(columns={pred_col: 'label'}, inplace=True)
    dataset_pred = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_pred,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )
    return dataset_true, dataset_pred


print("\n=== (B) Lumps => 'Other_Female' unpriv, All Others => priv ===")
results_lumped_OF = []

for model_col in model_predictions:
    ds_true_lumped, ds_pred_lumped = build_aif360_subset_lumped_OF(
        df=test_data,
        label_col='readmitted',
        pred_col=model_col
    )
    spd, di, eod, aod, t_index = compute_bias_metrics(ds_true_lumped, ds_pred_lumped)
    print(f"[{model_col}] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD={spd:.4f}, DI={di:.4f}")
    results_lumped_OF.append({
        'Model': model_col,
        'UnprivGroup': "Other_Female",
        'PrivGroup': "ALL_OTHERS",
        'SPD': spd,
        'DI': di,
        'EOD': eod,
        'AOD': aod,
        'T_Index': t_index
    })

df_results_lumped_OF = pd.DataFrame(results_lumped_OF)
print("\n=== Aggregated Bias Results (Lumped) ===\n", df_results_lumped_OF)

print("\n=== Plot SPD/DI => 'Other_Female'(unpriv) vs ALL_OTHERS ===")
plot_fairness_bar(
    df=df_results_lumped_OF,
    x_col='UnprivGroup',
    y_col='SPD',
    hue_col='Model',
    title="Statistical Parity Difference (Other_Female vs. ALL_OTHERS)",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_lumped_OF,
    x_col='UnprivGroup',
    y_col='DI',
    hue_col='Model',
    title="Disparate Impact (Other_Female vs. ALL_OTHERS)",
    ref_line=1
)
# Out:
# === (A) Bias Analysis per Subgroup vs. 'Other_Female' ===
#
# --- Model: pred_LogReg, Unprivileged: Other_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Female'(=0)
#    => #rows in subset: 6077 (unpriv_count=136, priv_count=5941)
#    => GroundTruth: label=1 => 700, label=0 => 5377
#    => Predictions: label=1 => 2093, label=0 => 3984
#    Compare Other_Female vs Caucasian_Female: SPD=0.0289, DI=1.0441
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Male'(=0)
#    => #rows in subset: 5527 (unpriv_count=136, priv_count=5391)
#    => GroundTruth: label=1 => 637, label=0 => 4890
#    => Predictions: label=1 => 1794, label=0 => 3733
#    Compare Other_Female vs Caucasian_Male: SPD=0.0086, DI=1.0128
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Female'(=0)
#    => #rows in subset: 1931 (unpriv_count=136, priv_count=1795)
#    => GroundTruth: label=1 => 223, label=0 => 1708
#    => Predictions: label=1 => 648, label=0 => 1283
#    Compare Other_Female vs AfricanAmerican_Female: SPD=0.0209, DI=1.0315
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Male'(=0)
#    => #rows in subset: 293 (unpriv_count=136, priv_count=157)
#    => GroundTruth: label=1 => 32, label=0 => 261
#    => Predictions: label=1 => 85, label=0 => 208
#    Compare Other_Female vs Hispanic_Male: SPD=-0.0487, DI=0.9336
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Male'(=0)
#    => #rows in subset: 1256 (unpriv_count=136, priv_count=1120)
#    => GroundTruth: label=1 => 161, label=0 => 1095
#    => Predictions: label=1 => 431, label=0 => 825
#    Compare Other_Female vs AfricanAmerican_Male: SPD=0.0303, DI=1.0463
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Female'(=0)
#    => #rows in subset: 302 (unpriv_count=136, priv_count=166)
#    => GroundTruth: label=1 => 35, label=0 => 267
#    => Predictions: label=1 => 94, label=0 => 208
#    Compare Other_Female vs Hispanic_Female: SPD=-0.0089, DI=0.9871
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Other_Male'(=0)
#    => #rows in subset: 250 (unpriv_count=136, priv_count=114)
#    => GroundTruth: label=1 => 26, label=0 => 224
#    => Predictions: label=1 => 82, label=0 => 168
#    Compare Other_Female vs Other_Male: SPD=0.0259, DI=1.0394
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 54, label=0 => 136
#    Compare Other_Female vs Asian_Female: SPD=-0.1125, DI=0.8588
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Male'(=0)
#    => #rows in subset: 186 (unpriv_count=136, priv_count=50)
#    => GroundTruth: label=1 => 23, label=0 => 163
#    => Predictions: label=1 => 53, label=0 => 133
#    Compare Other_Female vs Asian_Male: SPD=-0.1162, DI=0.8548
#
# --- Model: pred_XGB, Unprivileged: Other_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Female'(=0)
#    => #rows in subset: 6077 (unpriv_count=136, priv_count=5941)
#    => GroundTruth: label=1 => 700, label=0 => 5377
#    => Predictions: label=1 => 2236, label=0 => 3841
#    Compare Other_Female vs Caucasian_Female: SPD=0.0003, DI=1.0005
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Male'(=0)
#    => #rows in subset: 5527 (unpriv_count=136, priv_count=5391)
#    => GroundTruth: label=1 => 637, label=0 => 4890
#    => Predictions: label=1 => 1801, label=0 => 3726
#    Compare Other_Female vs Caucasian_Male: SPD=-0.0428, DI=0.9365
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Female'(=0)
#    => #rows in subset: 1931 (unpriv_count=136, priv_count=1795)
#    => GroundTruth: label=1 => 223, label=0 => 1708
#    => Predictions: label=1 => 664, label=0 => 1267
#    Compare Other_Female vs AfricanAmerican_Female: SPD=-0.0256, DI=0.9611
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Male'(=0)
#    => #rows in subset: 293 (unpriv_count=136, priv_count=157)
#    => GroundTruth: label=1 => 32, label=0 => 261
#    => Predictions: label=1 => 101, label=0 => 192
#    Compare Other_Female vs Hispanic_Male: SPD=-0.0428, DI=0.9366
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Male'(=0)
#    => #rows in subset: 1256 (unpriv_count=136, priv_count=1120)
#    => GroundTruth: label=1 => 161, label=0 => 1095
#    => Predictions: label=1 => 449, label=0 => 807
#    Compare Other_Female vs AfricanAmerican_Male: SPD=-0.0114, DI=0.9823
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Female'(=0)
#    => #rows in subset: 302 (unpriv_count=136, priv_count=166)
#    => GroundTruth: label=1 => 35, label=0 => 267
#    => Predictions: label=1 => 105, label=0 => 197
#    Compare Other_Female vs Hispanic_Female: SPD=-0.0363, DI=0.9457
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Other_Male'(=0)
#    => #rows in subset: 250 (unpriv_count=136, priv_count=114)
#    => GroundTruth: label=1 => 26, label=0 => 224
#    => Predictions: label=1 => 87, label=0 => 163
#    Compare Other_Female vs Other_Male: SPD=-0.0431, DI=0.9362
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 67, label=0 => 123
#    Compare Other_Female vs Asian_Female: SPD=-0.0528, DI=0.9229
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Male'(=0)
#    => #rows in subset: 186 (unpriv_count=136, priv_count=50)
#    => GroundTruth: label=1 => 23, label=0 => 163
#    => Predictions: label=1 => 57, label=0 => 129
#    Compare Other_Female vs Asian_Male: SPD=-0.2276, DI=0.7353
#
# --- Model: pred_MLP, Unprivileged: Other_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Female'(=0)
#    => #rows in subset: 6077 (unpriv_count=136, priv_count=5941)
#    => GroundTruth: label=1 => 700, label=0 => 5377
#    => Predictions: label=1 => 2456, label=0 => 3621
#    Compare Other_Female vs Caucasian_Female: SPD=-0.0304, DI=0.9491
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Male'(=0)
#    => #rows in subset: 5527 (unpriv_count=136, priv_count=5391)
#    => GroundTruth: label=1 => 637, label=0 => 4890
#    => Predictions: label=1 => 2069, label=0 => 3458
#    Compare Other_Female vs Caucasian_Male: SPD=-0.0610, DI=0.9028
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Female'(=0)
#    => #rows in subset: 1931 (unpriv_count=136, priv_count=1795)
#    => GroundTruth: label=1 => 223, label=0 => 1708
#    => Predictions: label=1 => 749, label=0 => 1182
#    Compare Other_Female vs AfricanAmerican_Female: SPD=-0.0494, DI=0.9197
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Male'(=0)
#    => #rows in subset: 293 (unpriv_count=136, priv_count=157)
#    => GroundTruth: label=1 => 32, label=0 => 261
#    => Predictions: label=1 => 109, label=0 => 184
#    Compare Other_Female vs Hispanic_Male: SPD=-0.1154, DI=0.8307
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Male'(=0)
#    => #rows in subset: 1256 (unpriv_count=136, priv_count=1120)
#    => GroundTruth: label=1 => 161, label=0 => 1095
#    => Predictions: label=1 => 484, label=0 => 772
#    Compare Other_Female vs AfricanAmerican_Male: SPD=-0.0544, DI=0.9124
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Female'(=0)
#    => #rows in subset: 302 (unpriv_count=136, priv_count=166)
#    => GroundTruth: label=1 => 35, label=0 => 267
#    => Predictions: label=1 => 121, label=0 => 181
#    Compare Other_Female vs Hispanic_Female: SPD=-0.0603, DI=0.9037
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Other_Male'(=0)
#    => #rows in subset: 250 (unpriv_count=136, priv_count=114)
#    => GroundTruth: label=1 => 26, label=0 => 224
#    => Predictions: label=1 => 99, label=0 => 151
#    Compare Other_Female vs Other_Male: SPD=-0.0829, DI=0.8722
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 75, label=0 => 115
#    Compare Other_Female vs Asian_Female: SPD=-0.1375, DI=0.8046
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Male'(=0)
#    => #rows in subset: 186 (unpriv_count=136, priv_count=50)
#    => GroundTruth: label=1 => 23, label=0 => 163
#    => Predictions: label=1 => 71, label=0 => 115
#    Compare Other_Female vs Asian_Male: SPD=-0.1938, DI=0.7450
#
# === Aggregated Bias Results (Individual Groups) ===
#            Model   UnprivGroup               PrivGroup       SPD        DI  \
# 0   pred_LogReg  Other_Female        Caucasian_Female  0.028883  1.044101
# 1   pred_LogReg  Other_Female          Caucasian_Male  0.008624  1.012773
# 2   pred_LogReg  Other_Female  AfricanAmerican_Female  0.020871  1.031482
# 3   pred_LogReg  Other_Female           Hispanic_Male -0.048661  0.933568
# 4   pred_LogReg  Other_Female    AfricanAmerican_Male  0.030252  1.046287
# 5   pred_LogReg  Other_Female         Hispanic_Female -0.008948  0.987084
# 6   pred_LogReg  Other_Female              Other_Male  0.025929  1.039412
# 7   pred_LogReg  Other_Female            Asian_Female -0.112473  0.858755
# 8   pred_LogReg  Other_Female              Asian_Male -0.116176  0.854779
# 9      pred_XGB  Other_Female        Caucasian_Female  0.000304  1.000482
# 10     pred_XGB  Other_Female          Caucasian_Male -0.042846  0.936543
# 11     pred_XGB  Other_Female  AfricanAmerican_Female -0.025586  0.961112
# 12     pred_XGB  Other_Female           Hispanic_Male -0.042806  0.936598
# 13     pred_XGB  Other_Female    AfricanAmerican_Male -0.011397  0.982296
# 14     pred_XGB  Other_Female         Hispanic_Female -0.036322  0.945681
# 15     pred_XGB  Other_Female              Other_Male -0.043086  0.936211
# 16     pred_XGB  Other_Female            Asian_Female -0.052832  0.922893
# 17     pred_XGB  Other_Female              Asian_Male -0.227647  0.735294
# 18     pred_MLP  Other_Female        Caucasian_Female -0.030356  0.949112
# 19     pred_MLP  Other_Female          Caucasian_Male -0.060980  0.902768
# 20     pred_MLP  Other_Female  AfricanAmerican_Female -0.049422  0.919717
# 21     pred_MLP  Other_Female           Hispanic_Male -0.115352  0.830745
# 22     pred_MLP  Other_Female    AfricanAmerican_Male -0.054359  0.912399
# 23     pred_MLP  Other_Female         Hispanic_Female -0.060330  0.903705
# 24     pred_MLP  Other_Female              Other_Male -0.082946  0.872218
# 25     pred_MLP  Other_Female            Asian_Female -0.137527  0.804567
# 26     pred_MLP  Other_Female              Asian_Male -0.193824  0.744969
#
#          EOD       AOD   T_Index
# 0   0.036831  0.018416  0.363946
# 1   0.015092  0.003103  0.337665
# 2   0.024443  0.025636  0.346155
# 3  -0.050373  0.010528  0.286177
# 4   0.036327  0.016415  0.355915
# 5  -0.012968  0.037634  0.308644
# 6   0.032619  0.078810  0.339353
# 7  -0.058969 -0.279484  0.301815
# 8  -0.110358 -0.105179  0.282529
# 9   0.029662 -0.066955  0.384781
# 10 -0.010123 -0.121423  0.338479
# 11  0.002793 -0.088983  0.351371
# 12 -0.012860 -0.081827  0.336604
# 13  0.012950 -0.074916  0.357840
# 14 -0.024969 -0.020654  0.323444
# 15 -0.011673 -0.054447  0.338393
# 16  0.019774 -0.267891  0.350897
# 17 -0.202448 -0.262335  0.274829
# 18  0.000846 -0.104742  0.436952
# 19 -0.026369 -0.146823  0.403808
# 20 -0.025381 -0.099140  0.401869
# 21 -0.073664 -0.211435  0.381911
# 22 -0.022093 -0.141194  0.405749
# 23 -0.032363 -0.110953  0.405747
# 24 -0.051167 -0.101973  0.400136
# 25 -0.048023 -0.412900  0.412284
# 26 -0.159134 -0.268456  0.368812
#
# === Plot SPD/DI for each Subgroup vs. Other_Female ===
# === (B) Lumps => 'Other_Female' unpriv, All Others => priv ===
# [pred_LogReg] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD=0.0184, DI=1.0276
# [pred_XGB] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD=-0.0216, DI=0.9669
# [pred_MLP] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD=-0.0482, DI=0.9215
#
# === Aggregated Bias Results (Lumped) ===
#           Model   UnprivGroup   PrivGroup       SPD        DI       EOD  \
# 0  pred_LogReg  Other_Female  ALL_OTHERS  0.018352  1.027577  0.024952
# 1     pred_XGB  Other_Female  ALL_OTHERS -0.021623  0.966936  0.008390
# 2     pred_MLP  Other_Female  ALL_OTHERS -0.048241  0.921486 -0.016317
#
#         AOD   T_Index
# 0  0.012329  0.349787
# 1 -0.091171  0.359664
# 2 -0.125123  0.415302
#
# === Plot SPD/DI => 'Other_Female'(unpriv) vs ALL_OTHERS ===

# %%
print("\n=== (A) Bias Analysis: Subgroup vs. 'Asian_Female' (Privileged) ===")

PRIV_GROUP_AF = "Asian_Female"
# all subgroups that are NOT 'Asian_Female' are tested as unprivileged, one by one
all_race_genders = test_data['race_gender'].unique()
unprivileged_groups = [g for g in all_race_genders if g != PRIV_GROUP_AF]

results_sep_AF = []
model_predictions = ['pred_LogReg','pred_XGB','pred_MLP']

for model_col in model_predictions:
    print(f"\n--- Model: {model_col}, Privileged: {PRIV_GROUP_AF} ---")
    for unpriv_grp in unprivileged_groups:
        ds_true, ds_pred = build_aif360_subset(
            df=test_data,
            label_col='readmitted',
            pred_col=model_col,
            unpriv_group_val=unpriv_grp,      # => 1
            priv_group_val=PRIV_GROUP_AF      # => 0
        )
        if ds_true is None or ds_pred is None:
            # If no rows match unpriv_grp or PRIV_GROUP_AF in test_data['race_gender']
            continue

        spd, di, eod, aod, t_index = compute_bias_metrics(ds_true, ds_pred)
        print(f"   Compare unpriv={unpriv_grp} vs priv={PRIV_GROUP_AF}: SPD={spd:.4f}, DI={di:.4f}")

        results_sep_AF.append({
            'Model': model_col,
            'UnprivGroup': unpriv_grp,
            'PrivGroup': PRIV_GROUP_AF,
            'SPD': spd,
            'DI': di,
            'EOD': eod,
            'AOD': aod,
            'T_Index': t_index
        })

df_results_sep_AF = pd.DataFrame(results_sep_AF)
print("\n=== Aggregated Bias Results (Individual Subgroups) ===\n", df_results_sep_AF)

# Plot SPD & DI
print("\n=== Plot SPD/DI for each Unpriv Subgroup vs. 'Asian_Female' ===")
plot_fairness_bar(
    df=df_results_sep_AF,
    x_col='UnprivGroup',
    y_col='SPD',
    hue_col='Model',
    title=f"Statistical Parity Difference vs. {PRIV_GROUP_AF}",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_sep_AF,
    x_col='UnprivGroup',
    y_col='DI',
    hue_col='Model',
    title=f"Disparate Impact vs. {PRIV_GROUP_AF}",
    ref_line=1
)


print("\n=== (B) Lumped Bias => 'Asian_Female' privileged vs. ALL_OTHERS unpriv ===")

results_lumped_AF = []

for model_col in model_predictions:
    ds_true_lumped, ds_pred_lumped = build_aif360_subset_lumped(
        df=test_data,
        label_col='readmitted',
        pred_col=model_col,
        privileged_grp=PRIV_GROUP_AF
    )
    # This lumps everything that is not 'Asian_Female' => 1, 
    # 'Asian_Female' => 0

    spd, di, eod, aod, t_index = compute_bias_metrics(ds_true_lumped, ds_pred_lumped)
    print(f"[{model_col}] Non-Asian_Female vs {PRIV_GROUP_AF}: SPD={spd:.4f}, DI={di:.4f}")

    results_lumped_AF.append({
        'Model': model_col,
        'UnprivGroup': "ALL_OTHERS",
        'PrivGroup': PRIV_GROUP_AF,
        'SPD': spd,
        'DI': di,
        'EOD': eod,
        'AOD': aod,
        'T_Index': t_index
    })

df_results_lumped_AF = pd.DataFrame(results_lumped_AF)
print("\n=== Aggregated Bias Results (Lumped) ===\n", df_results_lumped_AF)

print("\n=== Plot SPD/DI => Non-Asian_Female vs 'Asian_Female' ===")
plot_fairness_bar(
    df=df_results_lumped_AF,
    x_col='UnprivGroup',
    y_col='SPD',
    hue_col='Model',
    title=f"Statistical Parity Difference (All Non-Asian_Female vs. {PRIV_GROUP_AF})",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_lumped_AF,
    x_col='UnprivGroup',
    y_col='DI',
    hue_col='Model',
    title=f"Disparate Impact (All Non-Asian_Female vs. {PRIV_GROUP_AF})",
    ref_line=1
)
# Out:
# === (A) Bias Analysis: Subgroup vs. 'Asian_Female' (Privileged) ===
#
# --- Model: pred_LogReg, Privileged: Asian_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5995 (unpriv_count=5941, priv_count=54)
#    => GroundTruth: label=1 => 688, label=0 => 5307
#    => Predictions: label=1 => 2061, label=0 => 3934
#    Compare unpriv=Caucasian_Female vs priv=Asian_Female: SPD=-0.1414, DI=0.8225
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5445 (unpriv_count=5391, priv_count=54)
#    => GroundTruth: label=1 => 625, label=0 => 4820
#    => Predictions: label=1 => 1762, label=0 => 3683
#    Compare unpriv=Caucasian_Male vs priv=Asian_Female: SPD=-0.1211, DI=0.8479
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1849 (unpriv_count=1795, priv_count=54)
#    => GroundTruth: label=1 => 211, label=0 => 1638
#    => Predictions: label=1 => 616, label=0 => 1233
#    Compare unpriv=AfricanAmerican_Female vs priv=Asian_Female: SPD=-0.1333, DI=0.8325
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 211 (unpriv_count=157, priv_count=54)
#    => GroundTruth: label=1 => 20, label=0 => 191
#    => Predictions: label=1 => 53, label=0 => 158
#    Compare unpriv=Hispanic_Male vs priv=Asian_Female: SPD=-0.0638, DI=0.9199
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1174 (unpriv_count=1120, priv_count=54)
#    => GroundTruth: label=1 => 149, label=0 => 1025
#    => Predictions: label=1 => 399, label=0 => 775
#    Compare unpriv=AfricanAmerican_Male vs priv=Asian_Female: SPD=-0.1427, DI=0.8208
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 220 (unpriv_count=166, priv_count=54)
#    => GroundTruth: label=1 => 23, label=0 => 197
#    => Predictions: label=1 => 62, label=0 => 158
#    Compare unpriv=Hispanic_Female vs priv=Asian_Female: SPD=-0.1035, DI=0.8700
#
# [DEBUG] build_aif360_subset => unpriv='Other_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 168 (unpriv_count=114, priv_count=54)
#    => GroundTruth: label=1 => 14, label=0 => 154
#    => Predictions: label=1 => 50, label=0 => 118
#    Compare unpriv=Other_Male vs priv=Asian_Female: SPD=-0.1384, DI=0.8262
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 54, label=0 => 136
#    Compare unpriv=Other_Female vs priv=Asian_Female: SPD=-0.1125, DI=0.8588
#
# [DEBUG] build_aif360_subset => unpriv='Asian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 104 (unpriv_count=50, priv_count=54)
#    => GroundTruth: label=1 => 11, label=0 => 93
#    => Predictions: label=1 => 21, label=0 => 83
#    Compare unpriv=Asian_Male vs priv=Asian_Female: SPD=0.0037, DI=1.0047
#
# --- Model: pred_XGB, Privileged: Asian_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5995 (unpriv_count=5941, priv_count=54)
#    => GroundTruth: label=1 => 688, label=0 => 5307
#    => Predictions: label=1 => 2203, label=0 => 3792
#    Compare unpriv=Caucasian_Female vs priv=Asian_Female: SPD=-0.0531, DI=0.9224
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5445 (unpriv_count=5391, priv_count=54)
#    => GroundTruth: label=1 => 625, label=0 => 4820
#    => Predictions: label=1 => 1768, label=0 => 3677
#    Compare unpriv=Caucasian_Male vs priv=Asian_Female: SPD=-0.0100, DI=0.9854
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1849 (unpriv_count=1795, priv_count=54)
#    => GroundTruth: label=1 => 211, label=0 => 1638
#    => Predictions: label=1 => 631, label=0 => 1218
#    Compare unpriv=AfricanAmerican_Female vs priv=Asian_Female: SPD=-0.0272, DI=0.9602
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 211 (unpriv_count=157, priv_count=54)
#    => GroundTruth: label=1 => 20, label=0 => 191
#    => Predictions: label=1 => 68, label=0 => 143
#    Compare unpriv=Hispanic_Male vs priv=Asian_Female: SPD=-0.0100, DI=0.9854
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1174 (unpriv_count=1120, priv_count=54)
#    => GroundTruth: label=1 => 149, label=0 => 1025
#    => Predictions: label=1 => 416, label=0 => 758
#    Compare unpriv=AfricanAmerican_Male vs priv=Asian_Female: SPD=-0.0414, DI=0.9395
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 220 (unpriv_count=166, priv_count=54)
#    => GroundTruth: label=1 => 23, label=0 => 197
#    => Predictions: label=1 => 72, label=0 => 148
#    Compare unpriv=Hispanic_Female vs priv=Asian_Female: SPD=-0.0165, DI=0.9759
#
# [DEBUG] build_aif360_subset => unpriv='Other_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 168 (unpriv_count=114, priv_count=54)
#    => GroundTruth: label=1 => 14, label=0 => 154
#    => Predictions: label=1 => 54, label=0 => 114
#    Compare unpriv=Other_Male vs priv=Asian_Female: SPD=-0.0097, DI=0.9858
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 67, label=0 => 123
#    Compare unpriv=Other_Female vs priv=Asian_Female: SPD=-0.0528, DI=0.9229
#
# [DEBUG] build_aif360_subset => unpriv='Asian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 104 (unpriv_count=50, priv_count=54)
#    => GroundTruth: label=1 => 11, label=0 => 93
#    => Predictions: label=1 => 24, label=0 => 80
#    Compare unpriv=Asian_Male vs priv=Asian_Female: SPD=0.1748, DI=1.2551
#
# --- Model: pred_MLP, Privileged: Asian_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5995 (unpriv_count=5941, priv_count=54)
#    => GroundTruth: label=1 => 688, label=0 => 5307
#    => Predictions: label=1 => 2413, label=0 => 3582
#    Compare unpriv=Caucasian_Female vs priv=Asian_Female: SPD=-0.1072, DI=0.8477
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5445 (unpriv_count=5391, priv_count=54)
#    => GroundTruth: label=1 => 625, label=0 => 4820
#    => Predictions: label=1 => 2026, label=0 => 3419
#    Compare unpriv=Caucasian_Male vs priv=Asian_Female: SPD=-0.0765, DI=0.8912
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1849 (unpriv_count=1795, priv_count=54)
#    => GroundTruth: label=1 => 211, label=0 => 1638
#    => Predictions: label=1 => 706, label=0 => 1143
#    Compare unpriv=AfricanAmerican_Female vs priv=Asian_Female: SPD=-0.0881, DI=0.8748
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 211 (unpriv_count=157, priv_count=54)
#    => GroundTruth: label=1 => 20, label=0 => 191
#    => Predictions: label=1 => 66, label=0 => 145
#    Compare unpriv=Hispanic_Male vs priv=Asian_Female: SPD=-0.0222, DI=0.9685
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1174 (unpriv_count=1120, priv_count=54)
#    => GroundTruth: label=1 => 149, label=0 => 1025
#    => Predictions: label=1 => 441, label=0 => 733
#    Compare unpriv=AfricanAmerican_Male vs priv=Asian_Female: SPD=-0.0832, DI=0.8818
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 220 (unpriv_count=166, priv_count=54)
#    => GroundTruth: label=1 => 23, label=0 => 197
#    => Predictions: label=1 => 78, label=0 => 142
#    Compare unpriv=Hispanic_Female vs priv=Asian_Female: SPD=-0.0772, DI=0.8903
#
# [DEBUG] build_aif360_subset => unpriv='Other_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 168 (unpriv_count=114, priv_count=54)
#    => GroundTruth: label=1 => 14, label=0 => 154
#    => Predictions: label=1 => 56, label=0 => 112
#    Compare unpriv=Other_Male vs priv=Asian_Female: SPD=-0.0546, DI=0.9224
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 75, label=0 => 115
#    Compare unpriv=Other_Female vs priv=Asian_Female: SPD=-0.1375, DI=0.8046
#
# [DEBUG] build_aif360_subset => unpriv='Asian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 104 (unpriv_count=50, priv_count=54)
#    => GroundTruth: label=1 => 11, label=0 => 93
#    => Predictions: label=1 => 28, label=0 => 76
#    Compare unpriv=Asian_Male vs priv=Asian_Female: SPD=0.0563, DI=1.0800
#
# === Aggregated Bias Results (Individual Subgroups) ===
#            Model             UnprivGroup     PrivGroup       SPD        DI  \
# 0   pred_LogReg        Caucasian_Female  Asian_Female -0.141356  0.822483
# 1   pred_LogReg          Caucasian_Male  Asian_Female -0.121097  0.847925
# 2   pred_LogReg  AfricanAmerican_Female  Asian_Female -0.133344  0.832545
# 3   pred_LogReg           Hispanic_Male  Asian_Female -0.063812  0.919864
# 4   pred_LogReg    AfricanAmerican_Male  Asian_Female -0.142725  0.820764
# 5   pred_LogReg         Hispanic_Female  Asian_Female -0.103525  0.869992
# 6   pred_LogReg              Other_Male  Asian_Female -0.138402  0.826193
# 7   pred_LogReg            Other_Female  Asian_Female -0.112473  0.858755
# 8   pred_LogReg              Asian_Male  Asian_Female  0.003704  1.004651
# 9      pred_XGB        Caucasian_Female  Asian_Female -0.053137  0.922449
# 10     pred_XGB          Caucasian_Male  Asian_Female -0.009986  0.985426
# 11     pred_XGB  AfricanAmerican_Female  Asian_Female -0.027246  0.960235
# 12     pred_XGB           Hispanic_Male  Asian_Female -0.010026  0.985368
# 13     pred_XGB    AfricanAmerican_Male  Asian_Female -0.041435  0.939527
# 14     pred_XGB         Hispanic_Female  Asian_Female -0.016510  0.975904
# 15     pred_XGB              Other_Male  Asian_Female -0.009747  0.985775
# 16     pred_XGB            Other_Female  Asian_Female -0.052832  0.922893
# 17     pred_XGB              Asian_Male  Asian_Female  0.174815  1.255135
# 18     pred_MLP        Caucasian_Female  Asian_Female -0.107171  0.847704
# 19     pred_MLP          Caucasian_Male  Asian_Female -0.076547  0.891222
# 20     pred_MLP  AfricanAmerican_Female  Asian_Female -0.088105  0.874798
# 21     pred_MLP           Hispanic_Male  Asian_Female -0.022175  0.968488
# 22     pred_MLP    AfricanAmerican_Male  Asian_Female -0.083168  0.881814
# 23     pred_MLP         Hispanic_Female  Asian_Female -0.077198  0.890298
# 24     pred_MLP              Other_Male  Asian_Female -0.054581  0.922438
# 25     pred_MLP            Other_Female  Asian_Female -0.137527  0.804567
# 26     pred_MLP              Asian_Male  Asian_Female  0.056296  1.080000
#
#          EOD       AOD   T_Index
# 0  -0.095800 -0.297900  0.364175
# 1  -0.074060 -0.282588  0.337520
# 2  -0.083412 -0.305121  0.346112
# 3  -0.008596 -0.290012  0.263533
# 4  -0.095296 -0.295900  0.356485
# 5  -0.046001 -0.317118  0.294699
# 6  -0.091588 -0.358294  0.335682
# 7  -0.058969 -0.279484  0.301815
# 8   0.051389 -0.174306  0.233826
# 9  -0.009888 -0.200936  0.385992
# 10  0.029897 -0.146468  0.339058
# 11  0.016981 -0.178908  0.353711
# 12  0.032634 -0.186064  0.351662
# 13  0.006824 -0.192975  0.361963
# 14  0.044743 -0.247236  0.333034
# 15  0.031447 -0.213443  0.358577
# 16  0.019774 -0.267891  0.350897
# 17  0.222222 -0.005556  0.255403
# 18 -0.048869 -0.308159  0.437034
# 19 -0.021654 -0.266077  0.403390
# 20 -0.022642 -0.313760  0.400657
# 21  0.025641 -0.201465  0.363538
# 22 -0.025930 -0.271706  0.403862
# 23 -0.015660 -0.301948  0.396905
# 24  0.003145 -0.310928  0.386703
# 25 -0.048023 -0.412900  0.412284
# 26  0.111111 -0.144444  0.321893
#
# === Plot SPD/DI for each Unpriv Subgroup vs. 'Asian_Female' ===
# === (B) Lumped Bias => 'Asian_Female' privileged vs. ALL_OTHERS unpriv ===
# [pred_LogReg] Non-Asian_Female vs Asian_Female: SPD=-0.1311, DI=0.8353
# [pred_XGB] Non-Asian_Female vs Asian_Female: SPD=-0.0315, DI=0.9540
# [pred_MLP] Non-Asian_Female vs Asian_Female: SPD=-0.0901, DI=0.8720
#
# === Aggregated Bias Results (Lumped) ===
#           Model UnprivGroup     PrivGroup       SPD        DI       EOD  \
# 0  pred_LogReg  ALL_OTHERS  Asian_Female -0.131132  0.835323 -0.084003
# 1     pred_XGB  ALL_OTHERS  Asian_Female -0.031520  0.953998  0.011500
# 2     pred_MLP  ALL_OTHERS  Asian_Female -0.090052  0.872031 -0.031968
#
#         AOD   T_Index
# 0 -0.292732  0.349787
# 1 -0.178304  0.359664
# 2 -0.290093  0.415302
#
# === Plot SPD/DI => Non-Asian_Female vs 'Asian_Female' ===

# %%
results_dir = "dataset/train_test_extracted_oversample"

df_results_sep_OF.to_csv(os.path.join(results_dir, "bias_results_sep_OF_all_demographics.csv"), index=False)
df_results_lumped_OF.to_csv(os.path.join(results_dir, "bias_results_lumped_OF_all_demographics.csv"), index=False)

df_results_sep_AF.to_csv(os.path.join(results_dir, "bias_results_sep_AF_all_demographics.csv"), index=False)
df_results_lumped_AF.to_csv(os.path.join(results_dir, "bias_results_lumped_AF_all_demographics.csv"), index=False)
