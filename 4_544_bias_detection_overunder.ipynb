# %%
import os
import numpy as np
import pandas as pd

# Sklearn
from sklearn.metrics import accuracy_score, recall_score, f1_score
import joblib

# PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F

# AIF360
from aif360.datasets import BinaryLabelDataset
from aif360.metrics import ClassificationMetric

import seaborn as sns
import matplotlib.pyplot as plt

# %%
test_data = pd.read_csv('dataset/train_test_extracted_overunder/test.csv')

race_map = {0: "Other", 1: "AfricanAmerican", 2: "Asian", 3: "Caucasian", 4: "Hispanic"}
gender_map = {0: "Female", 1: "Male"}

test_data['race_str'] = test_data['race'].map(race_map)
test_data['gender_str'] = test_data['gender'].map(gender_map)
test_data['race_gender'] = test_data['race_str'] + "_" + test_data['gender_str']


drop_cols = ['readmitted','race','gender','race_str','gender_str','race_gender',
             'race_AfricanAmerican','race_Asian','race_Caucasian','race_Hispanic','race_Other']
X_test = test_data.drop(columns=drop_cols)
y_test = test_data['readmitted']

print("X_test shape:", X_test.shape, "y_test shape:", y_test.shape)


model_paths = {
    'LogReg': 'models/overunder/LogReg.joblib',
    'XGB':    'models/overunder/XGB.joblib',
    'MLP':    'models/overunder/MLP.pth'  # PyTorch model
}
# Out:
# X_test shape: (14924, 64) y_test shape: (14924,)

# %%
class SimpleNet(nn.Module):
    def __init__(self, input_dim, hidden_dim=128, num_classes=2):
        super(SimpleNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, num_classes)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        logits = self.fc2(x)
        return logits



for model_name, path in model_paths.items():
    print(f"\n=== Loading {model_name} ===")

    if model_name in ['LogReg','XGB']:
        # scikit-learn model
        model = joblib.load(path)

        if model_name == 'LogReg':
            scaler_path = "models/overunder/scaler_LogReg.joblib"
            scaler = joblib.load(scaler_path)
            X_test_scaled = scaler.transform(X_test)
            y_pred = model.predict(X_test_scaled)
        elif model_name == 'XGB':

            y_pred = model.predict(X_test)

    else:
        input_dim = X_test.shape[1]
        mlp_model = SimpleNet(input_dim=input_dim, hidden_dim=128, num_classes=2)
        mlp_model.load_state_dict(torch.load(path))  # Load weights


        mlp_model.eval()
        X_test_t = torch.tensor(X_test.values, dtype=torch.float32)
        with torch.no_grad():
            logits = mlp_model(X_test_t)
            probs = F.softmax(logits, dim=1)
            y_pred = torch.argmax(probs, dim=1).numpy()

    acc = accuracy_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred, zero_division=0)
    f1 = f1_score(y_test, y_pred, zero_division=0)

    print(f"[{model_name}] Accuracy: {acc:.4f}, Recall: {rec:.4f}, F1: {f1:.4f}")

    # Store predictions for bias analysis
    pred_col = f"pred_{model_name}"
    test_data[pred_col] = y_pred
# Out:
# === Loading LogReg ===
# [LogReg] Accuracy: 0.6385, Recall: 0.4980, F1: 0.2407
#
# === Loading XGB ===
# [XGB] Accuracy: 0.6687, Recall: 0.5108, F1: 0.2618
#
# === Loading MLP ===
# [MLP] Accuracy: 0.6455, Recall: 0.4747, F1: 0.2355

# %%
def build_aif360_subset(df, label_col, pred_col, unpriv_group_val, priv_group_val):
    """
    Filters 'df' so it only contains rows where race_gender is either unpriv_group_val or priv_group_val.
    Then encodes 'race_gender' as 1 => unpriv, 0 => priv.
    Returns two BinaryLabelDatasets (one ground truth, one predicted).
    Also prints debug info on how many times label=1 vs 0 in truth & predictions.
    """

    # Filter DataFrame
    df_filtered = df[df['race_gender'].isin([unpriv_group_val, priv_group_val])].copy()
    if df_filtered.empty:
        return None, None

    # Binarize race_gender => 1 if unpriv, else 0
    df_filtered['race_gender'] = df_filtered['race_gender'].apply(
        lambda x: 1 if x == unpriv_group_val else 0
    )

    unpriv_count = (df_filtered['race_gender'] == 1).sum()
    priv_count   = (df_filtered['race_gender'] == 0).sum()

    # Build dataset_true
    df_true = df_filtered[['race_gender', label_col]].copy()
    df_true.rename(columns={label_col: 'label'}, inplace=True)

    # Count how many label=1 vs. 0 in ground truth
    true_ones  = (df_true['label'] == 1).sum()
    true_zeros = (df_true['label'] == 0).sum()

    dataset_true = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_true,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    # Build dataset_pred
    df_pred = df_filtered[['race_gender', pred_col]].copy()
    df_pred.rename(columns={pred_col: 'label'}, inplace=True)

    # Count how many label=1 vs. 0 in predictions
    pred_ones  = (df_pred['label'] == 1).sum()
    pred_zeros = (df_pred['label'] == 0).sum()

    dataset_pred = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_pred,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    # Debug prints
    print(f"\n[DEBUG] build_aif360_subset => unpriv='{unpriv_group_val}'(=1), "
          f"priv='{priv_group_val}'(=0)")
    print(f"   => #rows in subset: {len(df_filtered)} (unpriv_count={unpriv_count}, priv_count={priv_count})")
    print(f"   => GroundTruth: label=1 => {true_ones}, label=0 => {true_zeros}")
    print(f"   => Predictions: label=1 => {pred_ones}, label=0 => {pred_zeros}")

    return dataset_true, dataset_pred


def compute_bias_metrics(dataset_true, dataset_pred):
    metric = ClassificationMetric(
        dataset_true,
        dataset_pred,
        unprivileged_groups=[{'race_gender': 1}],
        privileged_groups=[{'race_gender': 0}]
    )
    spd = metric.statistical_parity_difference()
    di = metric.disparate_impact()
    eod = metric.equal_opportunity_difference()  
    aod = metric.average_odds_difference()       
    t_index = metric.theil_index()               
    return spd, di, eod, aod, t_index



def plot_fairness_bar(df, x_col, y_col, hue_col, title,
                      width=8, height=6, ref_line=None,
                      label_fontsize=8):

    plt.figure(figsize=(width, height))
    ax = sns.barplot(data=df, x=x_col, y=y_col, hue=hue_col)

    if ref_line is not None:
        plt.axhline(ref_line, color='black', linewidth=1)

    for container in ax.containers:
        ax.bar_label(container, fmt="%.2f", label_type='edge', 
                     padding=3, fontsize=label_fontsize)

    plt.title(title)
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()


def build_aif360_subset_lumped(df, label_col, pred_col, privileged_grp="Asian_Female"):
    """
    Instead of splitting each unpriv group individually,
    we lump "everything that is not privileged_grp" into unpriv (1).
    """
    # Copy entire df (no filter for specific groups)
    df_temp = df.copy()

    # Binarize: 1 if not privileged_grp, else 0
    df_temp['race_gender'] = df_temp['race_gender'].apply(
        lambda x: 0 if x == privileged_grp else 1
    )

    # Build dataset_true
    df_true = df_temp[['race_gender', label_col]].copy()
    df_true.rename(columns={label_col: 'label'}, inplace=True)
    dataset_true = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_true,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    # Build dataset_pred
    df_pred = df_temp[['race_gender', pred_col]].copy()
    df_pred.rename(columns={pred_col: 'label'}, inplace=True)
    dataset_pred = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_pred,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    return dataset_true, dataset_pred

# %%
print("\n=== (A) Bias Analysis per Subgroup vs. 'Other_Female' ===")

UNPRIV_GROUP_OF = "Other_Female"
all_race_genders = test_data['race_gender'].unique()
privileged_groups = [g for g in all_race_genders if g != UNPRIV_GROUP_OF]

results_sep_OF = []
model_predictions = ['pred_LogReg','pred_XGB','pred_MLP']

for model_col in model_predictions:
    print(f"\n--- Model: {model_col}, Unprivileged: {UNPRIV_GROUP_OF} ---")
    for priv_grp in privileged_groups:
        ds_true, ds_pred = build_aif360_subset(
            df=test_data,
            label_col='readmitted',
            pred_col=model_col,
            unpriv_group_val=UNPRIV_GROUP_OF, 
            priv_group_val=priv_grp           
        )
        if ds_true is None or ds_pred is None:
            print(f"   WARNING: No data for group={priv_grp}; skipping.")
            continue

        spd, di, eod, aod, t_index = compute_bias_metrics(ds_true, ds_pred)
        print(f"   Compare {UNPRIV_GROUP_OF} vs {priv_grp}: SPD={spd:.4f}, DI={di:.4f}")

        results_sep_OF.append({
            'Model': model_col,
            'UnprivGroup': UNPRIV_GROUP_OF,
            'PrivGroup': priv_grp,
            'SPD': spd,
            'DI': di,
            'EOD': eod,
            'AOD': aod,
            'T_Index': t_index
        })

df_results_sep_OF = pd.DataFrame(results_sep_OF)
print("\n=== Aggregated Bias Results (Individual Groups) ===\n", df_results_sep_OF)

print("\n=== Plot SPD/DI for each Subgroup vs. Other_Female ===")
plot_fairness_bar(
    df=df_results_sep_OF,
    x_col='PrivGroup',
    y_col='SPD',
    hue_col='Model',
    title=f"Statistical Parity Difference vs. {UNPRIV_GROUP_OF} (Unpriv)",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_sep_OF,
    x_col='PrivGroup',
    y_col='DI',
    hue_col='Model',
    title=f"Disparate Impact vs. {UNPRIV_GROUP_OF} (Unpriv)",
    ref_line=1
)


def build_aif360_subset_lumped_OF(df, label_col, pred_col):
    """
    Lump: 'Other_Female' => 1 (unpriv), everything else => 0 (priv).
    """
    df_temp = df.copy()
    df_temp['race_gender'] = df_temp['race_gender'].apply(
        lambda x: 1 if x == "Other_Female" else 0
    )
    # Build dataset_true
    df_true = df_temp[[ 'race_gender', label_col]].copy()
    df_true.rename(columns={label_col: 'label'}, inplace=True)
    dataset_true = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_true,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )
    # Build dataset_pred
    df_pred = df_temp[['race_gender', pred_col]].copy()
    df_pred.rename(columns={pred_col: 'label'}, inplace=True)
    dataset_pred = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_pred,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )
    return dataset_true, dataset_pred


print("\n=== (B) Lumps => 'Other_Female' unpriv, All Others => priv ===")
results_lumped_OF = []

for model_col in model_predictions:
    ds_true_lumped, ds_pred_lumped = build_aif360_subset_lumped_OF(
        df=test_data,
        label_col='readmitted',
        pred_col=model_col
    )
    spd, di, eod, aod, t_index = compute_bias_metrics(ds_true_lumped, ds_pred_lumped)
    print(f"[{model_col}] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD={spd:.4f}, DI={di:.4f}")
    results_lumped_OF.append({
        'Model': model_col,
        'UnprivGroup': "Other_Female",
        'PrivGroup': "ALL_OTHERS",
        'SPD': spd,
        'DI': di,
        'EOD': eod,
        'AOD': aod,
        'T_Index': t_index
    })

df_results_lumped_OF = pd.DataFrame(results_lumped_OF)
print("\n=== Aggregated Bias Results (Lumped) ===\n", df_results_lumped_OF)

print("\n=== Plot SPD/DI => 'Other_Female'(unpriv) vs ALL_OTHERS ===")
plot_fairness_bar(
    df=df_results_lumped_OF,
    x_col='UnprivGroup',
    y_col='SPD',
    hue_col='Model',
    title="Statistical Parity Difference (Other_Female vs. ALL_OTHERS)",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_lumped_OF,
    x_col='UnprivGroup',
    y_col='DI',
    hue_col='Model',
    title="Disparate Impact (Other_Female vs. ALL_OTHERS)",
    ref_line=1
)
# Out:
# === (A) Bias Analysis per Subgroup vs. 'Other_Female' ===
#
# --- Model: pred_LogReg, Unprivileged: Other_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Female'(=0)
#    => #rows in subset: 6077 (unpriv_count=136, priv_count=5941)
#    => GroundTruth: label=1 => 700, label=0 => 5377
#    => Predictions: label=1 => 2254, label=0 => 3823
#    Compare Other_Female vs Caucasian_Female: SPD=0.0334, DI=1.0532
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Male'(=0)
#    => #rows in subset: 5527 (unpriv_count=136, priv_count=5391)
#    => GroundTruth: label=1 => 637, label=0 => 4890
#    => Predictions: label=1 => 1951, label=0 => 3576
#    Compare Other_Female vs Caucasian_Male: SPD=0.0151, DI=1.0234
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Female'(=0)
#    => #rows in subset: 1931 (unpriv_count=136, priv_count=1795)
#    => GroundTruth: label=1 => 223, label=0 => 1708
#    => Predictions: label=1 => 684, label=0 => 1247
#    Compare Other_Female vs AfricanAmerican_Female: SPD=0.0172, DI=1.0267
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Male'(=0)
#    => #rows in subset: 293 (unpriv_count=136, priv_count=157)
#    => GroundTruth: label=1 => 32, label=0 => 261
#    => Predictions: label=1 => 93, label=0 => 200
#    Compare Other_Female vs Hispanic_Male: SPD=-0.0389, DI=0.9445
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Male'(=0)
#    => #rows in subset: 1256 (unpriv_count=136, priv_count=1120)
#    => GroundTruth: label=1 => 161, label=0 => 1095
#    => Predictions: label=1 => 461, label=0 => 795
#    Compare Other_Female vs AfricanAmerican_Male: SPD=0.0323, DI=1.0513
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Female'(=0)
#    => #rows in subset: 302 (unpriv_count=136, priv_count=166)
#    => GroundTruth: label=1 => 35, label=0 => 267
#    => Predictions: label=1 => 104, label=0 => 198
#    Compare Other_Female vs Hispanic_Female: SPD=0.0112, DI=1.0172
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Other_Male'(=0)
#    => #rows in subset: 250 (unpriv_count=136, priv_count=114)
#    => GroundTruth: label=1 => 26, label=0 => 224
#    => Predictions: label=1 => 91, label=0 => 159
#    Compare Other_Female vs Other_Male: SPD=0.0565, DI=1.0934
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 60, label=0 => 130
#    Compare Other_Female vs Asian_Female: SPD=-0.0790, DI=0.8934
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Male'(=0)
#    => #rows in subset: 186 (unpriv_count=136, priv_count=50)
#    => GroundTruth: label=1 => 23, label=0 => 163
#    => Predictions: label=1 => 58, label=0 => 128
#    Compare Other_Female vs Asian_Male: SPD=-0.0982, DI=0.8707
#
# --- Model: pred_XGB, Unprivileged: Other_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Female'(=0)
#    => #rows in subset: 6077 (unpriv_count=136, priv_count=5941)
#    => GroundTruth: label=1 => 700, label=0 => 5377
#    => Predictions: label=1 => 2113, label=0 => 3964
#    Compare Other_Female vs Caucasian_Female: SPD=-0.0054, DI=0.9918
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Male'(=0)
#    => #rows in subset: 5527 (unpriv_count=136, priv_count=5391)
#    => GroundTruth: label=1 => 637, label=0 => 4890
#    => Predictions: label=1 => 1741, label=0 => 3786
#    Compare Other_Female vs Caucasian_Male: SPD=-0.0389, DI=0.9433
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Female'(=0)
#    => #rows in subset: 1931 (unpriv_count=136, priv_count=1795)
#    => GroundTruth: label=1 => 223, label=0 => 1708
#    => Predictions: label=1 => 666, label=0 => 1265
#    Compare Other_Female vs AfricanAmerican_Female: SPD=-0.0087, DI=0.9868
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Male'(=0)
#    => #rows in subset: 293 (unpriv_count=136, priv_count=157)
#    => GroundTruth: label=1 => 32, label=0 => 261
#    => Predictions: label=1 => 102, label=0 => 191
#    Compare Other_Female vs Hispanic_Male: SPD=-0.0090, DI=0.9863
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Male'(=0)
#    => #rows in subset: 1256 (unpriv_count=136, priv_count=1120)
#    => GroundTruth: label=1 => 161, label=0 => 1095
#    => Predictions: label=1 => 441, label=0 => 815
#    Compare Other_Female vs AfricanAmerican_Male: SPD=-0.0020, DI=0.9968
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Female'(=0)
#    => #rows in subset: 302 (unpriv_count=136, priv_count=166)
#    => GroundTruth: label=1 => 35, label=0 => 267
#    => Predictions: label=1 => 97, label=0 => 205
#    Compare Other_Female vs Hispanic_Female: SPD=-0.0578, DI=0.9180
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Other_Male'(=0)
#    => #rows in subset: 250 (unpriv_count=136, priv_count=114)
#    => GroundTruth: label=1 => 26, label=0 => 224
#    => Predictions: label=1 => 85, label=0 => 165
#    Compare Other_Female vs Other_Male: SPD=-0.0284, DI=0.9580
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 63, label=0 => 127
#    Compare Other_Female vs Asian_Female: SPD=-0.0752, DI=0.8959
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Male'(=0)
#    => #rows in subset: 186 (unpriv_count=136, priv_count=50)
#    => GroundTruth: label=1 => 23, label=0 => 163
#    => Predictions: label=1 => 58, label=0 => 128
#    Compare Other_Female vs Asian_Male: SPD=-0.1529, DI=0.8088
#
# --- Model: pred_MLP, Unprivileged: Other_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Female'(=0)
#    => #rows in subset: 6077 (unpriv_count=136, priv_count=5941)
#    => GroundTruth: label=1 => 700, label=0 => 5377
#    => Predictions: label=1 => 2135, label=0 => 3942
#    Compare Other_Female vs Caucasian_Female: SPD=0.0510, DI=1.0788
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Male'(=0)
#    => #rows in subset: 5527 (unpriv_count=136, priv_count=5391)
#    => GroundTruth: label=1 => 637, label=0 => 4890
#    => Predictions: label=1 => 1857, label=0 => 3670
#    Compare Other_Female vs Caucasian_Male: SPD=0.0354, DI=1.0534
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Female'(=0)
#    => #rows in subset: 1931 (unpriv_count=136, priv_count=1795)
#    => GroundTruth: label=1 => 223, label=0 => 1708
#    => Predictions: label=1 => 706, label=0 => 1225
#    Compare Other_Female vs AfricanAmerican_Female: SPD=0.0690, DI=1.1096
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Male'(=0)
#    => #rows in subset: 293 (unpriv_count=136, priv_count=157)
#    => GroundTruth: label=1 => 32, label=0 => 261
#    => Predictions: label=1 => 90, label=0 => 203
#    Compare Other_Female vs Hispanic_Male: SPD=0.0106, DI=1.0155
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Male'(=0)
#    => #rows in subset: 1256 (unpriv_count=136, priv_count=1120)
#    => GroundTruth: label=1 => 161, label=0 => 1095
#    => Predictions: label=1 => 455, label=0 => 801
#    Compare Other_Female vs AfricanAmerican_Male: SPD=0.0682, DI=1.1081
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Female'(=0)
#    => #rows in subset: 302 (unpriv_count=136, priv_count=166)
#    => GroundTruth: label=1 => 35, label=0 => 267
#    => Predictions: label=1 => 95, label=0 => 207
#    Compare Other_Female vs Hispanic_Female: SPD=0.0238, DI=1.0353
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Other_Male'(=0)
#    => #rows in subset: 250 (unpriv_count=136, priv_count=114)
#    => GroundTruth: label=1 => 26, label=0 => 224
#    => Predictions: label=1 => 84, label=0 => 166
#    Compare Other_Female vs Other_Male: SPD=0.0757, DI=1.1216
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 56, label=0 => 134
#    Compare Other_Female vs Asian_Female: SPD=-0.0237, DI=0.9672
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Male'(=0)
#    => #rows in subset: 186 (unpriv_count=136, priv_count=50)
#    => GroundTruth: label=1 => 23, label=0 => 163
#    => Predictions: label=1 => 54, label=0 => 132
#    Compare Other_Female vs Asian_Male: SPD=-0.0415, DI=0.9440
#
# === Aggregated Bias Results (Individual Groups) ===
#            Model   UnprivGroup               PrivGroup       SPD        DI  \
# 0   pred_LogReg  Other_Female        Caucasian_Female  0.033419  1.053186
# 1   pred_LogReg  Other_Female          Caucasian_Male  0.015131  1.023400
# 2   pred_LogReg  Other_Female  AfricanAmerican_Female  0.017196  1.026679
# 3   pred_LogReg  Other_Female           Hispanic_Male -0.038872  0.944519
# 4   pred_LogReg  Other_Female    AfricanAmerican_Male  0.032300  1.051314
# 5   pred_LogReg  Other_Female         Hispanic_Female  0.011162  1.017157
# 6   pred_LogReg  Other_Female              Other_Male  0.056502  1.093350
# 7   pred_LogReg  Other_Female            Asian_Female -0.078976  0.893382
# 8   pred_LogReg  Other_Female              Asian_Male -0.098235  0.870743
# 9      pred_XGB  Other_Female        Caucasian_Female -0.005357  0.991790
# 10     pred_XGB  Other_Female          Caucasian_Male -0.038899  0.943292
# 11     pred_XGB  Other_Female  AfricanAmerican_Female -0.008651  0.986806
# 12     pred_XGB  Other_Female           Hispanic_Male -0.008992  0.986294
# 13     pred_XGB  Other_Female    AfricanAmerican_Male -0.002048  0.996844
# 14     pred_XGB  Other_Female         Hispanic_Female -0.057760  0.918049
# 15     pred_XGB  Other_Female              Other_Male -0.028380  0.957983
# 16     pred_XGB  Other_Female            Asian_Female -0.075163  0.895928
# 17     pred_XGB  Other_Female              Asian_Male -0.152941  0.808824
# 18     pred_MLP  Other_Female        Caucasian_Female  0.050995  1.078753
# 19     pred_MLP  Other_Female          Caucasian_Male  0.035387  1.053363
# 20     pred_MLP  Other_Female  AfricanAmerican_Female  0.069003  1.109611
# 21     pred_MLP  Other_Female           Hispanic_Male  0.010631  1.015455
# 22     pred_MLP  Other_Female    AfricanAmerican_Male  0.068172  1.108149
# 23     pred_MLP  Other_Female         Hispanic_Female  0.023831  1.035320
# 24     pred_MLP  Other_Female              Other_Male  0.075722  1.121582
# 25     pred_MLP  Other_Female            Asian_Female -0.023693  0.967195
# 26     pred_MLP  Other_Female              Asian_Male -0.041471  0.943959
#
#          EOD       AOD   T_Index
# 0   0.051257 -0.007281  0.404449
# 1   0.030414 -0.017013  0.377754
# 2   0.027620  0.001886  0.370854
# 3  -0.025364 -0.040460  0.323066
# 4   0.043943  0.002935  0.384587
# 5   0.023774 -0.001185  0.354585
# 6   0.072274  0.070859  0.383533
# 7  -0.034251 -0.211570  0.327096
# 8  -0.082863 -0.119209  0.309455
# 9   0.021213 -0.066862  0.365400
# 10 -0.011497 -0.103218  0.327199
# 11  0.011896 -0.049336  0.350975
# 12 -0.004385  0.057331  0.328950
# 13  0.014260 -0.042986  0.348811
# 14 -0.043340 -0.060886  0.304879
# 15 -0.003198 -0.022432  0.334510
# 16 -0.013418 -0.256709  0.330733
# 17 -0.127307 -0.196987  0.291094
# 18  0.062717  0.029159  0.374786
# 19  0.053415 -0.007622  0.365599
# 20  0.077870  0.057228  0.387423
# 21  0.022520  0.011260  0.314973
# 22  0.079888  0.038196  0.383398
# 23  0.044250 -0.021993  0.330331
# 24  0.096738  0.048369  0.357829
# 25  0.041314 -0.229343  0.316039
# 26 -0.026742 -0.063371  0.289648
#
# === Plot SPD/DI for each Subgroup vs. Other_Female ===
# === (B) Lumps => 'Other_Female' unpriv, All Others => priv ===
# [pred_LogReg] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD=0.0230, DI=1.0360
# [pred_XGB] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD=-0.0193, DI=0.9710
# [pred_MLP] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD=0.0477, DI=1.0732
#
# === Aggregated Bias Results (Lumped) ===
#           Model   UnprivGroup   PrivGroup       SPD        DI       EOD  \
# 0  pred_LogReg  Other_Female  ALL_OTHERS  0.023004  1.036013  0.038486
# 1     pred_XGB  Other_Female  ALL_OTHERS -0.019292  0.971048  0.005787
# 2     pred_MLP  Other_Female  ALL_OTHERS  0.047664  1.073231  0.061688
#
#         AOD   T_Index
# 0 -0.009859  0.388529
# 1 -0.075878  0.346771
# 2  0.018043  0.375450
#
# === Plot SPD/DI => 'Other_Female'(unpriv) vs ALL_OTHERS ===

# %%
print("\n=== (A) Bias Analysis: Subgroup vs. 'Asian_Female' (Privileged) ===")

PRIV_GROUP_AF = "Asian_Female"
# all subgroups that are NOT 'Asian_Female' are tested as unprivileged, one by one
all_race_genders = test_data['race_gender'].unique()
unprivileged_groups = [g for g in all_race_genders if g != PRIV_GROUP_AF]

results_sep_AF = []
model_predictions = ['pred_LogReg','pred_XGB','pred_MLP']

for model_col in model_predictions:
    print(f"\n--- Model: {model_col}, Privileged: {PRIV_GROUP_AF} ---")
    for unpriv_grp in unprivileged_groups:
        ds_true, ds_pred = build_aif360_subset(
            df=test_data,
            label_col='readmitted',
            pred_col=model_col,
            unpriv_group_val=unpriv_grp,      # => 1
            priv_group_val=PRIV_GROUP_AF      # => 0
        )
        if ds_true is None or ds_pred is None:
            # If no rows match unpriv_grp or PRIV_GROUP_AF in test_data['race_gender']
            continue

        spd, di, eod, aod, t_index = compute_bias_metrics(ds_true, ds_pred)
        print(f"   Compare unpriv={unpriv_grp} vs priv={PRIV_GROUP_AF}: SPD={spd:.4f}, DI={di:.4f}")

        results_sep_AF.append({
            'Model': model_col,
            'UnprivGroup': unpriv_grp,
            'PrivGroup': PRIV_GROUP_AF,
            'SPD': spd,
            'DI': di,
            'EOD': eod,
            'AOD': aod,
            'T_Index': t_index
        })

df_results_sep_AF = pd.DataFrame(results_sep_AF)
print("\n=== Aggregated Bias Results (Individual Subgroups) ===\n", df_results_sep_AF)

# Plot SPD & DI
print("\n=== Plot SPD/DI for each Unpriv Subgroup vs. 'Asian_Female' ===")
plot_fairness_bar(
    df=df_results_sep_AF,
    x_col='UnprivGroup',
    y_col='SPD',
    hue_col='Model',
    title=f"Statistical Parity Difference vs. {PRIV_GROUP_AF}",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_sep_AF,
    x_col='UnprivGroup',
    y_col='DI',
    hue_col='Model',
    title=f"Disparate Impact vs. {PRIV_GROUP_AF}",
    ref_line=1
)


print("\n=== (B) Lumped Bias => 'Asian_Female' privileged vs. ALL_OTHERS unpriv ===")

results_lumped_AF = []

for model_col in model_predictions:
    ds_true_lumped, ds_pred_lumped = build_aif360_subset_lumped(
        df=test_data,
        label_col='readmitted',
        pred_col=model_col,
        privileged_grp=PRIV_GROUP_AF
    )
    # This lumps everything that is not 'Asian_Female' => 1, 
    # 'Asian_Female' => 0

    spd, di, eod, aod, t_index = compute_bias_metrics(ds_true_lumped, ds_pred_lumped)
    print(f"[{model_col}] Non-Asian_Female vs {PRIV_GROUP_AF}: SPD={spd:.4f}, DI={di:.4f}")

    results_lumped_AF.append({
        'Model': model_col,
        'UnprivGroup': "ALL_OTHERS",
        'PrivGroup': PRIV_GROUP_AF,
        'SPD': spd,
        'DI': di,
        'EOD': eod,
        'AOD': aod,
        'T_Index': t_index
    })

df_results_lumped_AF = pd.DataFrame(results_lumped_AF)
print("\n=== Aggregated Bias Results (Lumped) ===\n", df_results_lumped_AF)

print("\n=== Plot SPD/DI => Non-Asian_Female vs 'Asian_Female' ===")
plot_fairness_bar(
    df=df_results_lumped_AF,
    x_col='UnprivGroup',
    y_col='SPD',
    hue_col='Model',
    title=f"Statistical Parity Difference (All Non-Asian_Female vs. {PRIV_GROUP_AF})",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_lumped_AF,
    x_col='UnprivGroup',
    y_col='DI',
    hue_col='Model',
    title=f"Disparate Impact (All Non-Asian_Female vs. {PRIV_GROUP_AF})",
    ref_line=1
)
# Out:
# === (A) Bias Analysis: Subgroup vs. 'Asian_Female' (Privileged) ===
#
# --- Model: pred_LogReg, Privileged: Asian_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5995 (unpriv_count=5941, priv_count=54)
#    => GroundTruth: label=1 => 688, label=0 => 5307
#    => Predictions: label=1 => 2222, label=0 => 3773
#    Compare unpriv=Caucasian_Female vs priv=Asian_Female: SPD=-0.1124, DI=0.8483
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5445 (unpriv_count=5391, priv_count=54)
#    => GroundTruth: label=1 => 625, label=0 => 4820
#    => Predictions: label=1 => 1919, label=0 => 3526
#    Compare unpriv=Caucasian_Male vs priv=Asian_Female: SPD=-0.0941, DI=0.8730
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1849 (unpriv_count=1795, priv_count=54)
#    => GroundTruth: label=1 => 211, label=0 => 1638
#    => Predictions: label=1 => 652, label=0 => 1197
#    Compare unpriv=AfricanAmerican_Female vs priv=Asian_Female: SPD=-0.0962, DI=0.8702
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 211 (unpriv_count=157, priv_count=54)
#    => GroundTruth: label=1 => 20, label=0 => 191
#    => Predictions: label=1 => 61, label=0 => 150
#    Compare unpriv=Hispanic_Male vs priv=Asian_Female: SPD=-0.0401, DI=0.9459
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1174 (unpriv_count=1120, priv_count=54)
#    => GroundTruth: label=1 => 149, label=0 => 1025
#    => Predictions: label=1 => 429, label=0 => 745
#    Compare unpriv=AfricanAmerican_Male vs priv=Asian_Female: SPD=-0.1113, DI=0.8498
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 220 (unpriv_count=166, priv_count=54)
#    => GroundTruth: label=1 => 23, label=0 => 197
#    => Predictions: label=1 => 72, label=0 => 148
#    Compare unpriv=Hispanic_Female vs priv=Asian_Female: SPD=-0.0901, DI=0.8783
#
# [DEBUG] build_aif360_subset => unpriv='Other_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 168 (unpriv_count=114, priv_count=54)
#    => GroundTruth: label=1 => 14, label=0 => 154
#    => Predictions: label=1 => 59, label=0 => 109
#    Compare unpriv=Other_Male vs priv=Asian_Female: SPD=-0.1355, DI=0.8171
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 60, label=0 => 130
#    Compare unpriv=Other_Female vs priv=Asian_Female: SPD=-0.0790, DI=0.8934
#
# [DEBUG] build_aif360_subset => unpriv='Asian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 104 (unpriv_count=50, priv_count=54)
#    => GroundTruth: label=1 => 11, label=0 => 93
#    => Predictions: label=1 => 26, label=0 => 78
#    Compare unpriv=Asian_Male vs priv=Asian_Female: SPD=0.0193, DI=1.0260
#
# --- Model: pred_XGB, Privileged: Asian_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5995 (unpriv_count=5941, priv_count=54)
#    => GroundTruth: label=1 => 688, label=0 => 5307
#    => Predictions: label=1 => 2080, label=0 => 3915
#    Compare unpriv=Caucasian_Female vs priv=Asian_Female: SPD=-0.0698, DI=0.9033
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5445 (unpriv_count=5391, priv_count=54)
#    => GroundTruth: label=1 => 625, label=0 => 4820
#    => Predictions: label=1 => 1708, label=0 => 3737
#    Compare unpriv=Caucasian_Male vs priv=Asian_Female: SPD=-0.0363, DI=0.9498
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1849 (unpriv_count=1795, priv_count=54)
#    => GroundTruth: label=1 => 211, label=0 => 1638
#    => Predictions: label=1 => 633, label=0 => 1216
#    Compare unpriv=AfricanAmerican_Female vs priv=Asian_Female: SPD=-0.0665, DI=0.9079
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 211 (unpriv_count=157, priv_count=54)
#    => GroundTruth: label=1 => 20, label=0 => 191
#    => Predictions: label=1 => 69, label=0 => 142
#    Compare unpriv=Hispanic_Male vs priv=Asian_Female: SPD=-0.0662, DI=0.9084
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1174 (unpriv_count=1120, priv_count=54)
#    => GroundTruth: label=1 => 149, label=0 => 1025
#    => Predictions: label=1 => 408, label=0 => 766
#    Compare unpriv=AfricanAmerican_Male vs priv=Asian_Female: SPD=-0.0731, DI=0.8988
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 220 (unpriv_count=166, priv_count=54)
#    => GroundTruth: label=1 => 23, label=0 => 197
#    => Predictions: label=1 => 64, label=0 => 156
#    Compare unpriv=Hispanic_Female vs priv=Asian_Female: SPD=-0.0174, DI=0.9759
#
# [DEBUG] build_aif360_subset => unpriv='Other_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 168 (unpriv_count=114, priv_count=54)
#    => GroundTruth: label=1 => 14, label=0 => 154
#    => Predictions: label=1 => 52, label=0 => 116
#    Compare unpriv=Other_Male vs priv=Asian_Female: SPD=-0.0468, DI=0.9352
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 63, label=0 => 127
#    Compare unpriv=Other_Female vs priv=Asian_Female: SPD=-0.0752, DI=0.8959
#
# [DEBUG] build_aif360_subset => unpriv='Asian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 104 (unpriv_count=50, priv_count=54)
#    => GroundTruth: label=1 => 11, label=0 => 93
#    => Predictions: label=1 => 25, label=0 => 79
#    Compare unpriv=Asian_Male vs priv=Asian_Female: SPD=0.0778, DI=1.1077
#
# --- Model: pred_MLP, Privileged: Asian_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5995 (unpriv_count=5941, priv_count=54)
#    => GroundTruth: label=1 => 688, label=0 => 5307
#    => Predictions: label=1 => 2109, label=0 => 3886
#    Compare unpriv=Caucasian_Female vs priv=Asian_Female: SPD=-0.0747, DI=0.8966
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5445 (unpriv_count=5391, priv_count=54)
#    => GroundTruth: label=1 => 625, label=0 => 4820
#    => Predictions: label=1 => 1831, label=0 => 3614
#    Compare unpriv=Caucasian_Male vs priv=Asian_Female: SPD=-0.0591, DI=0.9182
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1849 (unpriv_count=1795, priv_count=54)
#    => GroundTruth: label=1 => 211, label=0 => 1638
#    => Predictions: label=1 => 680, label=0 => 1169
#    Compare unpriv=AfricanAmerican_Female vs priv=Asian_Female: SPD=-0.0927, DI=0.8717
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 211 (unpriv_count=157, priv_count=54)
#    => GroundTruth: label=1 => 20, label=0 => 191
#    => Predictions: label=1 => 64, label=0 => 147
#    Compare unpriv=Hispanic_Male vs priv=Asian_Female: SPD=-0.0343, DI=0.9525
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1174 (unpriv_count=1120, priv_count=54)
#    => GroundTruth: label=1 => 149, label=0 => 1025
#    => Predictions: label=1 => 429, label=0 => 745
#    Compare unpriv=AfricanAmerican_Male vs priv=Asian_Female: SPD=-0.0919, DI=0.8728
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 220 (unpriv_count=166, priv_count=54)
#    => GroundTruth: label=1 => 23, label=0 => 197
#    => Predictions: label=1 => 69, label=0 => 151
#    Compare unpriv=Hispanic_Female vs priv=Asian_Female: SPD=-0.0475, DI=0.9342
#
# [DEBUG] build_aif360_subset => unpriv='Other_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 168 (unpriv_count=114, priv_count=54)
#    => GroundTruth: label=1 => 14, label=0 => 154
#    => Predictions: label=1 => 58, label=0 => 110
#    Compare unpriv=Other_Male vs priv=Asian_Female: SPD=-0.0994, DI=0.8623
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 56, label=0 => 134
#    Compare unpriv=Other_Female vs priv=Asian_Female: SPD=-0.0237, DI=0.9672
#
# [DEBUG] build_aif360_subset => unpriv='Asian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 104 (unpriv_count=50, priv_count=54)
#    => GroundTruth: label=1 => 11, label=0 => 93
#    => Predictions: label=1 => 28, label=0 => 76
#    Compare unpriv=Asian_Male vs priv=Asian_Female: SPD=0.0178, DI=1.0246
#
# === Aggregated Bias Results (Individual Subgroups) ===
#            Model             UnprivGroup     PrivGroup       SPD        DI  \
# 0   pred_LogReg        Caucasian_Female  Asian_Female -0.112395  0.848266
# 1   pred_LogReg          Caucasian_Male  Asian_Female -0.094107  0.872955
# 2   pred_LogReg  AfricanAmerican_Female  Asian_Female -0.096172  0.870167
# 3   pred_LogReg           Hispanic_Male  Asian_Female -0.040104  0.945860
# 4   pred_LogReg    AfricanAmerican_Male  Asian_Female -0.111276  0.849777
# 5   pred_LogReg         Hispanic_Female  Asian_Female -0.090138  0.878313
# 6   pred_LogReg              Other_Male  Asian_Female -0.135478  0.817105
# 7   pred_LogReg            Other_Female  Asian_Female -0.078976  0.893382
# 8   pred_LogReg              Asian_Male  Asian_Female  0.019259  1.026000
# 9      pred_XGB        Caucasian_Female  Asian_Female -0.069807  0.903344
# 10     pred_XGB          Caucasian_Male  Asian_Female -0.036264  0.949788
# 11     pred_XGB  AfricanAmerican_Female  Asian_Female -0.066512  0.907907
# 12     pred_XGB           Hispanic_Male  Asian_Female -0.066171  0.908378
# 13     pred_XGB    AfricanAmerican_Male  Asian_Female -0.073115  0.898764
# 14     pred_XGB         Hispanic_Female  Asian_Female -0.017403  0.975904
# 15     pred_XGB              Other_Male  Asian_Female -0.046784  0.935223
# 16     pred_XGB            Other_Female  Asian_Female -0.075163  0.895928
# 17     pred_XGB              Asian_Male  Asian_Female  0.077778  1.107692
# 18     pred_MLP        Caucasian_Female  Asian_Female -0.074688  0.896586
# 19     pred_MLP          Caucasian_Male  Asian_Female -0.059080  0.918197
# 20     pred_MLP  AfricanAmerican_Female  Asian_Female -0.092696  0.871652
# 21     pred_MLP           Hispanic_Male  Asian_Female -0.034324  0.952474
# 22     pred_MLP    AfricanAmerican_Male  Asian_Female -0.091865  0.872802
# 23     pred_MLP         Hispanic_Female  Asian_Female -0.047523  0.934198
# 24     pred_MLP              Other_Male  Asian_Female -0.099415  0.862348
# 25     pred_MLP            Other_Female  Asian_Female -0.023693  0.967195
# 26     pred_MLP              Asian_Male  Asian_Female  0.017778  1.024615
#
#          EOD       AOD   T_Index
# 0  -0.085508 -0.204289  0.405251
# 1  -0.064665 -0.194557  0.378218
# 2  -0.061871 -0.213456  0.371918
# 3  -0.008887 -0.171110  0.313916
# 4  -0.078194 -0.214505  0.387215
# 5  -0.058026 -0.210385  0.357355
# 6  -0.106525 -0.282429  0.401945
# 7  -0.034251 -0.211570  0.327096
# 8   0.048611 -0.092361  0.280365
# 9  -0.034631 -0.189847  0.366014
# 10 -0.001921 -0.153491  0.327281
# 11 -0.025314 -0.207373  0.352332
# 12 -0.009033 -0.314040  0.332721
# 13 -0.027678 -0.213723  0.350758
# 14  0.029922 -0.195823  0.299178
# 15 -0.010220 -0.234277  0.341740
# 16 -0.013418 -0.256709  0.330733
# 17  0.113889 -0.059722  0.267807
# 18 -0.021404 -0.258502  0.376616
# 19 -0.012102 -0.221721  0.367448
# 20 -0.036557 -0.286571  0.394022
# 21  0.018794 -0.240603  0.341779
# 22 -0.038575 -0.267539  0.393418
# 23 -0.002936 -0.207350  0.362048
# 24 -0.055425 -0.277712  0.415480
# 25  0.041314 -0.229343  0.316039
# 26  0.068056 -0.165972  0.321893
#
# === Plot SPD/DI for each Unpriv Subgroup vs. 'Asian_Female' ===
# === (B) Lumped Bias => 'Asian_Female' privileged vs. ALL_OTHERS unpriv ===
# [pred_LogReg] Non-Asian_Female vs Asian_Female: SPD=-0.1021, DI=0.8621
# [pred_XGB] Non-Asian_Female vs Asian_Female: SPD=-0.0563, DI=0.9221
# [pred_MLP] Non-Asian_Female vs Asian_Female: SPD=-0.0712, DI=0.9014
#
# === Aggregated Bias Results (Lumped) ===
#           Model UnprivGroup     PrivGroup      SPD        DI       EOD  \
# 0  pred_LogReg  ALL_OTHERS  Asian_Female -0.10214  0.862112 -0.072658
# 1     pred_XGB  ALL_OTHERS  Asian_Female -0.05625  0.922115 -0.019223
# 2     pred_MLP  ALL_OTHERS  Asian_Female -0.07118  0.901443 -0.019896
#
#         AOD   T_Index
# 0 -0.202557  0.388529
# 1 -0.182269  0.346771
# 2 -0.248113  0.375450
#
# === Plot SPD/DI => Non-Asian_Female vs 'Asian_Female' ===

# %%
for model_name, path in model_paths.items():
    print(f"\n=== Loading {model_name} ===")

    if model_name in ['LogReg','XGB']:
        # scikit-learn model
        model = joblib.load(path)

        if model_name == 'LogReg':
            scaler_path = "models/overunder/scaler_LogReg.joblib"
            scaler = joblib.load(scaler_path)
            X_test_scaled = scaler.transform(X_test)
            y_pred = model.predict(X_test_scaled)
        elif model_name == 'XGB':

            y_pred = model.predict(X_test)

    else:
        input_dim = X_test.shape[1]
        mlp_model = SimpleNet(input_dim=input_dim, hidden_dim=128, num_classes=2)
        mlp_model.load_state_dict(torch.load(path))  # Load weights


        mlp_model.eval()
        X_test_t = torch.tensor(X_test.values, dtype=torch.float32)
        with torch.no_grad():
            logits = mlp_model(X_test_t)
            probs = F.softmax(logits, dim=1)
            y_pred = torch.argmax(probs, dim=1).numpy()

    acc = accuracy_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred, zero_division=0)
    f1 = f1_score(y_test, y_pred, zero_division=0)

    print(f"[{model_name}] Accuracy: {acc:.4f}, Recall: {rec:.4f}, F1: {f1:.4f}")

    # Store predictions for bias analysis
    pred_col = f"pred_{model_name}"
    test_data[pred_col] = y_pred
# Out:
# === Loading LogReg ===
# [LogReg] Accuracy: 0.6385, Recall: 0.4980, F1: 0.2407
#
# === Loading XGB ===
# [XGB] Accuracy: 0.6687, Recall: 0.5108, F1: 0.2618
#
# === Loading MLP ===
# [MLP] Accuracy: 0.6455, Recall: 0.4747, F1: 0.2355

# %%
results_dir = "dataset/train_test_extracted_overunder"

df_results_sep_OF.to_csv(os.path.join(results_dir, "bias_results_sep_OF.csv"), index=False)
df_results_lumped_OF.to_csv(os.path.join(results_dir, "bias_results_lumped_OF.csv"), index=False)

df_results_sep_AF.to_csv(os.path.join(results_dir, "bias_results_sep_AF.csv"), index=False)
df_results_lumped_AF.to_csv(os.path.join(results_dir, "bias_results_lumped_AF.csv"), index=False)
