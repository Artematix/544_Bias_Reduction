# %%
import os
import numpy as np
import pandas as pd

# Sklearn
from sklearn.metrics import accuracy_score, recall_score, f1_score
import joblib

# PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F

# AIF360
from aif360.datasets import BinaryLabelDataset
from aif360.metrics import ClassificationMetric

import seaborn as sns
import matplotlib.pyplot as plt

# %%
test_data = pd.read_csv('dataset/train_test_extracted_base/test_cherry_picked.csv')

race_map = {0: "Other", 1: "AfricanAmerican", 2: "Asian", 3: "Caucasian", 4: "Hispanic"}
gender_map = {0: "Female", 1: "Male"}

test_data['race_str'] = test_data['race'].map(race_map)
test_data['gender_str'] = test_data['gender'].map(gender_map)
test_data['race_gender'] = test_data['race_str'] + "_" + test_data['gender_str']



drop_cols = ['readmitted','race','gender','race_str','gender_str','race_gender',
             'race_AfricanAmerican','race_Asian','race_Caucasian','race_Hispanic','race_Other']
X_test = test_data.drop(columns=drop_cols)
y_test = test_data['readmitted']

print("X_test shape:", X_test.shape, "y_test shape:", y_test.shape)

model_paths = {
    'LogReg': 'models/base_cherry_picked/LogReg.joblib',
    'XGB':    'models/base_cherry_picked/XGB.joblib',
    'MLP':    'models/base_cherry_picked/MLP.pth' 
}
# Out:
# X_test shape: (14924, 23) y_test shape: (14924,)

# %%
class SimpleNet(nn.Module):
    def __init__(self, input_dim, hidden_dim=64, num_classes=2):
        super(SimpleNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, num_classes)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        logits = self.fc2(x)
        return logits


for model_name, path in model_paths.items():
    print(f"\n=== Loading {model_name} ===")

    if model_name in ['LogReg','XGB']:
        # scikit-learn model
        model = joblib.load(path)


        if model_name == 'LogReg':
            scaler_path = "models/base_cherry_picked/scaler_LogReg.joblib"
            scaler = joblib.load(scaler_path)
            X_test_scaled = scaler.transform(X_test)
            y_pred = model.predict(X_test_scaled)
        elif model_name == 'XGB':
            y_pred = model.predict(X_test)

    else:

        input_dim = X_test.shape[1]
        mlp_model = SimpleNet(input_dim=input_dim, hidden_dim=128, num_classes=2)
        mlp_model.load_state_dict(torch.load(path))  # Load weights


        mlp_model.eval()
        X_test_t = torch.tensor(X_test.values, dtype=torch.float32)
        with torch.no_grad():
            logits = mlp_model(X_test_t)
            probs = F.softmax(logits, dim=1)
            y_pred = torch.argmax(probs, dim=1).numpy()

    acc = accuracy_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred, zero_division=0)
    f1 = f1_score(y_test, y_pred, zero_division=0)

    print(f"[{model_name}] Accuracy: {acc:.4f}, Recall: {rec:.4f}, F1: {f1:.4f}")

    # Store predictions for bias analysis
    pred_col = f"pred_{model_name}"
    test_data[pred_col] = y_pred
# Out:
# === Loading LogReg ===
# [LogReg] Accuracy: 0.6644, Recall: 0.4991, F1: 0.2549
#
# === Loading XGB ===
# [XGB] Accuracy: 0.5945, Recall: 0.6226, F1: 0.2611
#
# === Loading MLP ===
# [MLP] Accuracy: 0.6497, Recall: 0.5207, F1: 0.2548

# %%
def build_aif360_subset(df, label_col, pred_col, unpriv_group_val, priv_group_val):
    """
    Filters 'df' so it only contains rows where race_gender is either unpriv_group_val or priv_group_val.
    Then encodes 'race_gender' as 1 => unpriv, 0 => priv.
    Returns two BinaryLabelDatasets (one ground truth, one predicted).
    Also prints debug info on how many times label=1 vs 0 in truth & predictions.
    """

    # Filter DataFrame
    df_filtered = df[df['race_gender'].isin([unpriv_group_val, priv_group_val])].copy()
    if df_filtered.empty:
        return None, None

    # Binarize race_gender => 1 if unpriv, else 0
    df_filtered['race_gender'] = df_filtered['race_gender'].apply(
        lambda x: 1 if x == unpriv_group_val else 0
    )

    unpriv_count = (df_filtered['race_gender'] == 1).sum()
    priv_count   = (df_filtered['race_gender'] == 0).sum()

    # Build dataset_true
    df_true = df_filtered[['race_gender', label_col]].copy()
    df_true.rename(columns={label_col: 'label'}, inplace=True)

    # Count how many label=1 vs. 0 in ground truth
    true_ones  = (df_true['label'] == 1).sum()
    true_zeros = (df_true['label'] == 0).sum()

    dataset_true = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_true,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    # Build dataset_pred
    df_pred = df_filtered[['race_gender', pred_col]].copy()
    df_pred.rename(columns={pred_col: 'label'}, inplace=True)

    # Count how many label=1 vs. 0 in predictions
    pred_ones  = (df_pred['label'] == 1).sum()
    pred_zeros = (df_pred['label'] == 0).sum()

    dataset_pred = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_pred,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    # Debug prints
    print(f"\n[DEBUG] build_aif360_subset => unpriv='{unpriv_group_val}'(=1), "
          f"priv='{priv_group_val}'(=0)")
    print(f"   => #rows in subset: {len(df_filtered)} (unpriv_count={unpriv_count}, priv_count={priv_count})")
    print(f"   => GroundTruth: label=1 => {true_ones}, label=0 => {true_zeros}")
    print(f"   => Predictions: label=1 => {pred_ones}, label=0 => {pred_zeros}")

    return dataset_true, dataset_pred


def compute_bias_metrics(dataset_true, dataset_pred):
    metric = ClassificationMetric(
        dataset_true,
        dataset_pred,
        unprivileged_groups=[{'race_gender': 1}],
        privileged_groups=[{'race_gender': 0}]
    )
    spd = metric.statistical_parity_difference()
    di = metric.disparate_impact()
    eod = metric.equal_opportunity_difference()   
    aod = metric.average_odds_difference()        
    t_index = metric.theil_index()                
    return spd, di, eod, aod, t_index


def plot_fairness_bar(df, x_col, y_col, hue_col, title,
                      width=8, height=6, ref_line=None,
                      label_fontsize=8):

    plt.figure(figsize=(width, height))
    ax = sns.barplot(data=df, x=x_col, y=y_col, hue=hue_col)

    if ref_line is not None:
        plt.axhline(ref_line, color='black', linewidth=1)

    for container in ax.containers:
        ax.bar_label(container, fmt="%.2f", label_type='edge', 
                     padding=3, fontsize=label_fontsize)

    plt.title(title)
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()


def build_aif360_subset_lumped(df, label_col, pred_col, privileged_grp="Asian_Female"):
    """
    Instead of splitting each unpriv group individually,
    we lump "everything that is not privileged_grp" into unpriv (1).
    """
    # Copy entire df (no filter for specific groups)
    df_temp = df.copy()

    # Binarize: 1 if not privileged_grp, else 0
    df_temp['race_gender'] = df_temp['race_gender'].apply(
        lambda x: 0 if x == privileged_grp else 1
    )

    # Build dataset_true
    df_true = df_temp[['race_gender', label_col]].copy()
    df_true.rename(columns={label_col: 'label'}, inplace=True)
    dataset_true = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_true,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    # Build dataset_pred
    df_pred = df_temp[['race_gender', pred_col]].copy()
    df_pred.rename(columns={pred_col: 'label'}, inplace=True)
    dataset_pred = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_pred,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )

    return dataset_true, dataset_pred

# %%
print("\n=== (A) Bias Analysis per Subgroup vs. 'Other_Female' ===")

UNPRIV_GROUP_OF = "Other_Female"
all_race_genders = test_data['race_gender'].unique()
privileged_groups = [g for g in all_race_genders if g != UNPRIV_GROUP_OF]

results_sep_OF = []
model_predictions = ['pred_LogReg','pred_XGB','pred_MLP']

for model_col in model_predictions:
    print(f"\n--- Model: {model_col}, Unprivileged: {UNPRIV_GROUP_OF} ---")
    for priv_grp in privileged_groups:
        ds_true, ds_pred = build_aif360_subset(
            df=test_data,
            label_col='readmitted',
            pred_col=model_col,
            unpriv_group_val=UNPRIV_GROUP_OF, 
            priv_group_val=priv_grp           
        )
        if ds_true is None or ds_pred is None:
            print(f"   WARNING: No data for group={priv_grp}; skipping.")
            continue

        spd, di, eod, aod, t_index = compute_bias_metrics(ds_true, ds_pred)
        print(f"   Compare {UNPRIV_GROUP_OF} vs {priv_grp}: SPD={spd:.4f}, DI={di:.4f}")

        results_sep_OF.append({
            'Model': model_col,
            'UnprivGroup': UNPRIV_GROUP_OF,
            'PrivGroup': priv_grp,
            'SPD': spd,
            'DI': di,
            'EOD': eod,
            'AOD': aod,
            'T_Index': t_index
        })

df_results_sep_OF = pd.DataFrame(results_sep_OF)
print("\n=== Aggregated Bias Results (Individual Groups) ===\n", df_results_sep_OF)

print("\n=== Plot SPD/DI for each Subgroup vs. Other_Female ===")
plot_fairness_bar(
    df=df_results_sep_OF,
    x_col='PrivGroup',
    y_col='SPD',
    hue_col='Model',
    title=f"Statistical Parity Difference vs. {UNPRIV_GROUP_OF} (Unpriv)",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_sep_OF,
    x_col='PrivGroup',
    y_col='DI',
    hue_col='Model',
    title=f"Disparate Impact vs. {UNPRIV_GROUP_OF} (Unpriv)",
    ref_line=1
)


def build_aif360_subset_lumped_OF(df, label_col, pred_col):
    """
    Lump: 'Other_Female' => 1 (unpriv), everything else => 0 (priv).
    """
    df_temp = df.copy()
    df_temp['race_gender'] = df_temp['race_gender'].apply(
        lambda x: 1 if x == "Other_Female" else 0
    )
    # Build dataset_true
    df_true = df_temp[[ 'race_gender', label_col]].copy()
    df_true.rename(columns={label_col: 'label'}, inplace=True)
    dataset_true = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_true,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )
    # Build dataset_pred
    df_pred = df_temp[['race_gender', pred_col]].copy()
    df_pred.rename(columns={pred_col: 'label'}, inplace=True)
    dataset_pred = BinaryLabelDataset(
        favorable_label=0,
        unfavorable_label=1,
        df=df_pred,
        label_names=['label'],
        protected_attribute_names=['race_gender']
    )
    return dataset_true, dataset_pred


print("\n=== (B) Lumps => 'Other_Female' unpriv, All Others => priv ===")
results_lumped_OF = []

for model_col in model_predictions:
    ds_true_lumped, ds_pred_lumped = build_aif360_subset_lumped_OF(
        df=test_data,
        label_col='readmitted',
        pred_col=model_col
    )
    spd, di, eod, aod, t_index = compute_bias_metrics(ds_true_lumped, ds_pred_lumped)
    print(f"[{model_col}] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD={spd:.4f}, DI={di:.4f}")
    results_lumped_OF.append({
        'Model': model_col,
        'UnprivGroup': "Other_Female",
        'PrivGroup': "ALL_OTHERS",
        'SPD': spd,
        'DI': di,
        'EOD': eod,
        'AOD': aod,
        'T_Index': t_index
    })

df_results_lumped_OF = pd.DataFrame(results_lumped_OF)
print("\n=== Aggregated Bias Results (Lumped) ===\n", df_results_lumped_OF)

print("\n=== Plot SPD/DI => 'Other_Female'(unpriv) vs ALL_OTHERS ===")
plot_fairness_bar(
    df=df_results_lumped_OF,
    x_col='UnprivGroup',
    y_col='SPD',
    hue_col='Model',
    title="Statistical Parity Difference (Other_Female vs. ALL_OTHERS)",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_lumped_OF,
    x_col='UnprivGroup',
    y_col='DI',
    hue_col='Model',
    title="Disparate Impact (Other_Female vs. ALL_OTHERS)",
    ref_line=1
)
# Out:
# === (A) Bias Analysis per Subgroup vs. 'Other_Female' ===
#
# --- Model: pred_LogReg, Unprivileged: Other_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Female'(=0)
#    => #rows in subset: 6077 (unpriv_count=136, priv_count=5941)
#    => GroundTruth: label=1 => 700, label=0 => 5377
#    => Predictions: label=1 => 2114, label=0 => 3963
#    Compare Other_Female vs Caucasian_Female: SPD=0.0475, DI=1.0729
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Male'(=0)
#    => #rows in subset: 5527 (unpriv_count=136, priv_count=5391)
#    => GroundTruth: label=1 => 637, label=0 => 4890
#    => Predictions: label=1 => 1783, label=0 => 3744
#    Compare Other_Female vs Caucasian_Male: SPD=0.0217, DI=1.0320
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Female'(=0)
#    => #rows in subset: 1931 (unpriv_count=136, priv_count=1795)
#    => GroundTruth: label=1 => 223, label=0 => 1708
#    => Predictions: label=1 => 654, label=0 => 1277
#    Compare Other_Female vs AfricanAmerican_Female: SPD=0.0400, DI=1.0608
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Male'(=0)
#    => #rows in subset: 293 (unpriv_count=136, priv_count=157)
#    => GroundTruth: label=1 => 32, label=0 => 261
#    => Predictions: label=1 => 84, label=0 => 209
#    Compare Other_Female vs Hispanic_Male: SPD=-0.0276, DI=0.9620
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Male'(=0)
#    => #rows in subset: 1256 (unpriv_count=136, priv_count=1120)
#    => GroundTruth: label=1 => 161, label=0 => 1095
#    => Predictions: label=1 => 429, label=0 => 827
#    Compare Other_Female vs AfricanAmerican_Male: SPD=0.0450, DI=1.0688
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Female'(=0)
#    => #rows in subset: 302 (unpriv_count=136, priv_count=166)
#    => GroundTruth: label=1 => 35, label=0 => 267
#    => Predictions: label=1 => 90, label=0 => 212
#    Compare Other_Female vs Hispanic_Female: SPD=-0.0063, DI=0.9911
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Other_Male'(=0)
#    => #rows in subset: 250 (unpriv_count=136, priv_count=114)
#    => GroundTruth: label=1 => 26, label=0 => 224
#    => Predictions: label=1 => 78, label=0 => 172
#    Compare Other_Female vs Other_Male: SPD=0.0231, DI=1.0342
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 51, label=0 => 139
#    Compare Other_Female vs Asian_Female: SPD=-0.1163, DI=0.8573
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Male'(=0)
#    => #rows in subset: 186 (unpriv_count=136, priv_count=50)
#    => GroundTruth: label=1 => 23, label=0 => 163
#    => Predictions: label=1 => 51, label=0 => 135
#    Compare Other_Female vs Asian_Male: SPD=-0.1015, DI=0.8732
#
# --- Model: pred_XGB, Unprivileged: Other_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Female'(=0)
#    => #rows in subset: 6077 (unpriv_count=136, priv_count=5941)
#    => GroundTruth: label=1 => 700, label=0 => 5377
#    => Predictions: label=1 => 2880, label=0 => 3197
#    Compare Other_Female vs Caucasian_Female: SPD=0.0335, DI=1.0638
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Male'(=0)
#    => #rows in subset: 5527 (unpriv_count=136, priv_count=5391)
#    => GroundTruth: label=1 => 637, label=0 => 4890
#    => Predictions: label=1 => 2262, label=0 => 3265
#    Compare Other_Female vs Caucasian_Male: SPD=-0.0327, DI=0.9447
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Female'(=0)
#    => #rows in subset: 1931 (unpriv_count=136, priv_count=1795)
#    => GroundTruth: label=1 => 223, label=0 => 1708
#    => Predictions: label=1 => 796, label=0 => 1135
#    Compare Other_Female vs AfricanAmerican_Female: SPD=-0.0311, DI=0.9472
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Male'(=0)
#    => #rows in subset: 293 (unpriv_count=136, priv_count=157)
#    => GroundTruth: label=1 => 32, label=0 => 261
#    => Predictions: label=1 => 119, label=0 => 174
#    Compare Other_Female vs Hispanic_Male: SPD=-0.0654, DI=0.8953
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Male'(=0)
#    => #rows in subset: 1256 (unpriv_count=136, priv_count=1120)
#    => GroundTruth: label=1 => 161, label=0 => 1095
#    => Predictions: label=1 => 529, label=0 => 727
#    Compare Other_Female vs AfricanAmerican_Male: SPD=-0.0224, DI=0.9614
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Female'(=0)
#    => #rows in subset: 302 (unpriv_count=136, priv_count=166)
#    => GroundTruth: label=1 => 35, label=0 => 267
#    => Predictions: label=1 => 120, label=0 => 182
#    Compare Other_Female vs Hispanic_Female: SPD=-0.0797, DI=0.8751
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Other_Male'(=0)
#    => #rows in subset: 250 (unpriv_count=136, priv_count=114)
#    => GroundTruth: label=1 => 26, label=0 => 224
#    => Predictions: label=1 => 99, label=0 => 151
#    Compare Other_Female vs Other_Male: SPD=-0.0991, DI=0.8494
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 78, label=0 => 112
#    Compare Other_Female vs Asian_Female: SPD=-0.1078, DI=0.8382
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Male'(=0)
#    => #rows in subset: 186 (unpriv_count=136, priv_count=50)
#    => GroundTruth: label=1 => 23, label=0 => 163
#    => Predictions: label=1 => 70, label=0 => 116
#    Compare Other_Female vs Asian_Male: SPD=-0.2412, DI=0.6985
#
# --- Model: pred_MLP, Unprivileged: Other_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Female'(=0)
#    => #rows in subset: 6077 (unpriv_count=136, priv_count=5941)
#    => GroundTruth: label=1 => 700, label=0 => 5377
#    => Predictions: label=1 => 2220, label=0 => 3857
#    Compare Other_Female vs Caucasian_Female: SPD=0.0578, DI=1.0912
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Caucasian_Male'(=0)
#    => #rows in subset: 5527 (unpriv_count=136, priv_count=5391)
#    => GroundTruth: label=1 => 637, label=0 => 4890
#    => Predictions: label=1 => 1883, label=0 => 3644
#    Compare Other_Female vs Caucasian_Male: SPD=0.0327, DI=1.0496
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Female'(=0)
#    => #rows in subset: 1931 (unpriv_count=136, priv_count=1795)
#    => GroundTruth: label=1 => 223, label=0 => 1708
#    => Predictions: label=1 => 711, label=0 => 1220
#    Compare Other_Female vs AfricanAmerican_Female: SPD=0.0639, DI=1.1018
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Male'(=0)
#    => #rows in subset: 293 (unpriv_count=136, priv_count=157)
#    => GroundTruth: label=1 => 32, label=0 => 261
#    => Predictions: label=1 => 86, label=0 => 207
#    Compare Other_Female vs Hispanic_Male: SPD=-0.0286, DI=0.9603
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='AfricanAmerican_Male'(=0)
#    => #rows in subset: 1256 (unpriv_count=136, priv_count=1120)
#    => GroundTruth: label=1 => 161, label=0 => 1095
#    => Predictions: label=1 => 461, label=0 => 795
#    Compare Other_Female vs AfricanAmerican_Male: SPD=0.0653, DI=1.1043
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Hispanic_Female'(=0)
#    => #rows in subset: 302 (unpriv_count=136, priv_count=166)
#    => GroundTruth: label=1 => 35, label=0 => 267
#    => Predictions: label=1 => 89, label=0 => 213
#    Compare Other_Female vs Hispanic_Female: SPD=-0.0257, DI=0.9642
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Other_Male'(=0)
#    => #rows in subset: 250 (unpriv_count=136, priv_count=114)
#    => GroundTruth: label=1 => 26, label=0 => 224
#    => Predictions: label=1 => 79, label=0 => 171
#    Compare Other_Female vs Other_Male: SPD=0.0157, DI=1.0233
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 55, label=0 => 135
#    Compare Other_Female vs Asian_Female: SPD=-0.0681, DI=0.9103
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Male'(=0)
#    => #rows in subset: 186 (unpriv_count=136, priv_count=50)
#    => GroundTruth: label=1 => 23, label=0 => 163
#    => Predictions: label=1 => 51, label=0 => 135
#    Compare Other_Female vs Asian_Male: SPD=-0.1288, DI=0.8429
#
# === Aggregated Bias Results (Individual Groups) ===
#            Model   UnprivGroup               PrivGroup       SPD        DI  \
# 0   pred_LogReg  Other_Female        Caucasian_Female  0.047461  1.072896
# 1   pred_LogReg  Other_Female          Caucasian_Male  0.021661  1.032001
# 2   pred_LogReg  Other_Female  AfricanAmerican_Female  0.040034  1.060796
# 3   pred_LogReg  Other_Female           Hispanic_Male -0.027585  0.962010
# 4   pred_LogReg  Other_Female    AfricanAmerican_Male  0.044958  1.068788
# 5   pred_LogReg  Other_Female         Hispanic_Female -0.006290  0.991076
# 6   pred_LogReg  Other_Female              Other_Male  0.023091  1.034186
# 7   pred_LogReg  Other_Female            Asian_Female -0.116285  0.857286
# 8   pred_LogReg  Other_Female              Asian_Male -0.101471  0.873162
# 9      pred_XGB  Other_Female        Caucasian_Female  0.033491  1.063752
# 10     pred_XGB  Other_Female          Caucasian_Male -0.032718  0.944690
# 11     pred_XGB  Other_Female  AfricanAmerican_Female -0.031149  0.947203
# 12     pred_XGB  Other_Female           Hispanic_Male -0.065380  0.895258
# 13     pred_XGB  Other_Female    AfricanAmerican_Male -0.022426  0.961417
# 14     pred_XGB  Other_Female         Hispanic_Female -0.079731  0.875139
# 15     pred_XGB  Other_Female              Other_Male -0.099071  0.849412
# 16     pred_XGB  Other_Female            Asian_Female -0.107843  0.838235
# 17     pred_XGB  Other_Female              Asian_Male -0.241176  0.698529
# 18     pred_MLP  Other_Female        Caucasian_Female  0.057781  1.091225
# 19     pred_MLP  Other_Female          Caucasian_Male  0.032672  1.049615
# 20     pred_MLP  Other_Female  AfricanAmerican_Female  0.063878  1.101831
# 21     pred_MLP  Other_Female           Hispanic_Male -0.028569  0.960307
# 22     pred_MLP  Other_Female    AfricanAmerican_Male  0.065284  1.104305
# 23     pred_MLP  Other_Female         Hispanic_Female -0.025691  0.964162
# 24     pred_MLP  Other_Female              Other_Male  0.015738  1.023300
# 25     pred_MLP  Other_Female            Asian_Female -0.068083  0.910330
# 26     pred_MLP  Other_Female              Asian_Male -0.128824  0.842898
#
#          EOD       AOD   T_Index
# 0   0.065678  0.008727  0.367122
# 1   0.040306 -0.018530  0.337108
# 2   0.058043  0.002463  0.354234
# 3  -0.017957 -0.001042  0.275907
# 4   0.055610  0.019258  0.343836
# 5   0.005745 -0.010200  0.290839
# 6   0.029741  0.112093  0.303209
# 7  -0.054379 -0.304967  0.272342
# 8  -0.084934 -0.120245  0.259666
# 9   0.061586 -0.031116  0.529680
# 10 -0.005924 -0.092982  0.438041
# 11 -0.004296 -0.091037  0.439817
# 12 -0.047173 -0.055333  0.406133
# 13  0.003209 -0.090081  0.443506
# 14 -0.067683 -0.069789  0.388026
# 15 -0.069076 -0.110927  0.400136
# 16 -0.035664 -0.323387  0.426109
# 17 -0.234275 -0.206026  0.351113
# 18  0.082791  0.000503  0.387628
# 19  0.058328 -0.026796  0.358111
# 20  0.089489  0.005043  0.390266
# 21 -0.003971 -0.057541  0.284915
# 22  0.084269  0.016299  0.374436
# 23 -0.007678 -0.044689  0.280847
# 24  0.029741  0.084315  0.301590
# 25  0.008121 -0.301495  0.291465
# 26 -0.107156 -0.159134  0.250892
#
# === Plot SPD/DI for each Subgroup vs. Other_Female ===
# === (B) Lumps => 'Other_Female' unpriv, All Others => priv ===
# [pred_LogReg] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD=0.0343, DI=1.0516
# [pred_XGB] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD=-0.0075, DI=0.9867
# [pred_MLP] 'Other_Female'(unpriv) vs ALL_OTHERS: SPD=0.0467, DI=1.0724
#
# === Aggregated Bias Results (Lumped) ===
#           Model   UnprivGroup   PrivGroup       SPD        DI       EOD  \
# 0  pred_LogReg  Other_Female  ALL_OTHERS  0.034275  1.051599  0.051903
# 1     pred_XGB  Other_Female  ALL_OTHERS -0.007514  0.986732  0.019521
# 2     pred_MLP  Other_Female  ALL_OTHERS  0.046667  1.072408  0.071462
#
#         AOD   T_Index
# 0 -0.002562  0.351421
# 1 -0.068652  0.472073
# 2 -0.009966  0.375051
#
# === Plot SPD/DI => 'Other_Female'(unpriv) vs ALL_OTHERS ===

# %%
print("\n=== (A) Bias Analysis: Subgroup vs. 'Asian_Female' (Privileged) ===")

PRIV_GROUP_AF = "Asian_Female"
# all subgroups that are NOT 'Asian_Female' are tested as unprivileged, one by one
all_race_genders = test_data['race_gender'].unique()
unprivileged_groups = [g for g in all_race_genders if g != PRIV_GROUP_AF]

results_sep_AF = []
model_predictions = ['pred_LogReg','pred_XGB','pred_MLP']

for model_col in model_predictions:
    print(f"\n--- Model: {model_col}, Privileged: {PRIV_GROUP_AF} ---")
    for unpriv_grp in unprivileged_groups:
        ds_true, ds_pred = build_aif360_subset(
            df=test_data,
            label_col='readmitted',
            pred_col=model_col,
            unpriv_group_val=unpriv_grp,      # => 1
            priv_group_val=PRIV_GROUP_AF      # => 0
        )
        if ds_true is None or ds_pred is None:
            # If no rows match unpriv_grp or PRIV_GROUP_AF in test_data['race_gender']
            continue

        spd, di, eod, aod, t_index = compute_bias_metrics(ds_true, ds_pred)
        print(f"   Compare unpriv={unpriv_grp} vs priv={PRIV_GROUP_AF}: SPD={spd:.4f}, DI={di:.4f}")

        results_sep_AF.append({
            'Model': model_col,
            'UnprivGroup': unpriv_grp,
            'PrivGroup': PRIV_GROUP_AF,
            'SPD': spd,
            'DI': di,
            'EOD': eod,
            'AOD': aod,
            'T_Index': t_index
        })

df_results_sep_AF = pd.DataFrame(results_sep_AF)
print("\n=== Aggregated Bias Results (Individual Subgroups) ===\n", df_results_sep_AF)

# Plot SPD & DI
print("\n=== Plot SPD/DI for each Unpriv Subgroup vs. 'Asian_Female' ===")
plot_fairness_bar(
    df=df_results_sep_AF,
    x_col='UnprivGroup',
    y_col='SPD',
    hue_col='Model',
    title=f"Statistical Parity Difference vs. {PRIV_GROUP_AF}",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_sep_AF,
    x_col='UnprivGroup',
    y_col='DI',
    hue_col='Model',
    title=f"Disparate Impact vs. {PRIV_GROUP_AF}",
    ref_line=1
)


print("\n=== (B) Lumped Bias => 'Asian_Female' privileged vs. ALL_OTHERS unpriv ===")

results_lumped_AF = []

for model_col in model_predictions:
    ds_true_lumped, ds_pred_lumped = build_aif360_subset_lumped(
        df=test_data,
        label_col='readmitted',
        pred_col=model_col,
        privileged_grp=PRIV_GROUP_AF
    )
    # This lumps everything that is not 'Asian_Female' => 1, 
    # 'Asian_Female' => 0

    spd, di, eod, aod, t_index = compute_bias_metrics(ds_true_lumped, ds_pred_lumped)
    print(f"[{model_col}] Non-Asian_Female vs {PRIV_GROUP_AF}: SPD={spd:.4f}, DI={di:.4f}")

    results_lumped_AF.append({
        'Model': model_col,
        'UnprivGroup': "ALL_OTHERS",
        'PrivGroup': PRIV_GROUP_AF,
        'SPD': spd,
        'DI': di,
        'EOD': eod,
        'AOD': aod,
        'T_Index': t_index
    })

df_results_lumped_AF = pd.DataFrame(results_lumped_AF)
print("\n=== Aggregated Bias Results (Lumped) ===\n", df_results_lumped_AF)

print("\n=== Plot SPD/DI => Non-Asian_Female vs 'Asian_Female' ===")
plot_fairness_bar(
    df=df_results_lumped_AF,
    x_col='UnprivGroup',
    y_col='SPD',
    hue_col='Model',
    title=f"Statistical Parity Difference (All Non-Asian_Female vs. {PRIV_GROUP_AF})",
    ref_line=0
)
plot_fairness_bar(
    df=df_results_lumped_AF,
    x_col='UnprivGroup',
    y_col='DI',
    hue_col='Model',
    title=f"Disparate Impact (All Non-Asian_Female vs. {PRIV_GROUP_AF})",
    ref_line=1
)
# Out:
# === (A) Bias Analysis: Subgroup vs. 'Asian_Female' (Privileged) ===
#
# --- Model: pred_LogReg, Privileged: Asian_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5995 (unpriv_count=5941, priv_count=54)
#    => GroundTruth: label=1 => 688, label=0 => 5307
#    => Predictions: label=1 => 2083, label=0 => 3912
#    Compare unpriv=Caucasian_Female vs priv=Asian_Female: SPD=-0.1637, DI=0.7990
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5445 (unpriv_count=5391, priv_count=54)
#    => GroundTruth: label=1 => 625, label=0 => 4820
#    => Predictions: label=1 => 1752, label=0 => 3693
#    Compare unpriv=Caucasian_Male vs priv=Asian_Female: SPD=-0.1379, DI=0.8307
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1849 (unpriv_count=1795, priv_count=54)
#    => GroundTruth: label=1 => 211, label=0 => 1638
#    => Predictions: label=1 => 623, label=0 => 1226
#    Compare unpriv=AfricanAmerican_Female vs priv=Asian_Female: SPD=-0.1563, DI=0.8082
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 211 (unpriv_count=157, priv_count=54)
#    => GroundTruth: label=1 => 20, label=0 => 191
#    => Predictions: label=1 => 53, label=0 => 158
#    Compare unpriv=Hispanic_Male vs priv=Asian_Female: SPD=-0.0887, DI=0.8911
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1174 (unpriv_count=1120, priv_count=54)
#    => GroundTruth: label=1 => 149, label=0 => 1025
#    => Predictions: label=1 => 398, label=0 => 776
#    Compare unpriv=AfricanAmerican_Male vs priv=Asian_Female: SPD=-0.1612, DI=0.8021
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 220 (unpriv_count=166, priv_count=54)
#    => GroundTruth: label=1 => 23, label=0 => 197
#    => Predictions: label=1 => 59, label=0 => 161
#    Compare unpriv=Hispanic_Female vs priv=Asian_Female: SPD=-0.1100, DI=0.8650
#
# [DEBUG] build_aif360_subset => unpriv='Other_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 168 (unpriv_count=114, priv_count=54)
#    => GroundTruth: label=1 => 14, label=0 => 154
#    => Predictions: label=1 => 47, label=0 => 121
#    Compare unpriv=Other_Male vs priv=Asian_Female: SPD=-0.1394, DI=0.8289
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 51, label=0 => 139
#    Compare unpriv=Other_Female vs priv=Asian_Female: SPD=-0.1163, DI=0.8573
#
# [DEBUG] build_aif360_subset => unpriv='Asian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 104 (unpriv_count=50, priv_count=54)
#    => GroundTruth: label=1 => 11, label=0 => 93
#    => Predictions: label=1 => 20, label=0 => 84
#    Compare unpriv=Asian_Male vs priv=Asian_Female: SPD=-0.0148, DI=0.9818
#
# --- Model: pred_XGB, Privileged: Asian_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5995 (unpriv_count=5941, priv_count=54)
#    => GroundTruth: label=1 => 688, label=0 => 5307
#    => Predictions: label=1 => 2838, label=0 => 3157
#    Compare unpriv=Caucasian_Female vs priv=Asian_Female: SPD=-0.1413, DI=0.7880
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5445 (unpriv_count=5391, priv_count=54)
#    => GroundTruth: label=1 => 625, label=0 => 4820
#    => Predictions: label=1 => 2220, label=0 => 3225
#    Compare unpriv=Caucasian_Male vs priv=Asian_Female: SPD=-0.0751, DI=0.8873
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1849 (unpriv_count=1795, priv_count=54)
#    => GroundTruth: label=1 => 211, label=0 => 1638
#    => Predictions: label=1 => 754, label=0 => 1095
#    Compare unpriv=AfricanAmerican_Female vs priv=Asian_Female: SPD=-0.0767, DI=0.8850
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 211 (unpriv_count=157, priv_count=54)
#    => GroundTruth: label=1 => 20, label=0 => 191
#    => Predictions: label=1 => 77, label=0 => 134
#    Compare unpriv=Hispanic_Male vs priv=Asian_Female: SPD=-0.0425, DI=0.9363
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1174 (unpriv_count=1120, priv_count=54)
#    => GroundTruth: label=1 => 149, label=0 => 1025
#    => Predictions: label=1 => 487, label=0 => 687
#    Compare unpriv=AfricanAmerican_Male vs priv=Asian_Female: SPD=-0.0854, DI=0.8719
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 220 (unpriv_count=166, priv_count=54)
#    => GroundTruth: label=1 => 23, label=0 => 197
#    => Predictions: label=1 => 78, label=0 => 142
#    Compare unpriv=Hispanic_Female vs priv=Asian_Female: SPD=-0.0281, DI=0.9578
#
# [DEBUG] build_aif360_subset => unpriv='Other_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 168 (unpriv_count=114, priv_count=54)
#    => GroundTruth: label=1 => 14, label=0 => 154
#    => Predictions: label=1 => 57, label=0 => 111
#    Compare unpriv=Other_Male vs priv=Asian_Female: SPD=-0.0088, DI=0.9868
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 78, label=0 => 112
#    Compare unpriv=Other_Female vs priv=Asian_Female: SPD=-0.1078, DI=0.8382
#
# [DEBUG] build_aif360_subset => unpriv='Asian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 104 (unpriv_count=50, priv_count=54)
#    => GroundTruth: label=1 => 11, label=0 => 93
#    => Predictions: label=1 => 28, label=0 => 76
#    Compare unpriv=Asian_Male vs priv=Asian_Female: SPD=0.1333, DI=1.2000
#
# --- Model: pred_MLP, Privileged: Asian_Female ---
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5995 (unpriv_count=5941, priv_count=54)
#    => GroundTruth: label=1 => 688, label=0 => 5307
#    => Predictions: label=1 => 2191, label=0 => 3804
#    Compare unpriv=Caucasian_Female vs priv=Asian_Female: SPD=-0.1259, DI=0.8342
#
# [DEBUG] build_aif360_subset => unpriv='Caucasian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 5445 (unpriv_count=5391, priv_count=54)
#    => GroundTruth: label=1 => 625, label=0 => 4820
#    => Predictions: label=1 => 1854, label=0 => 3591
#    Compare unpriv=Caucasian_Male vs priv=Asian_Female: SPD=-0.1008, DI=0.8673
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1849 (unpriv_count=1795, priv_count=54)
#    => GroundTruth: label=1 => 211, label=0 => 1638
#    => Predictions: label=1 => 682, label=0 => 1167
#    Compare unpriv=AfricanAmerican_Female vs priv=Asian_Female: SPD=-0.1320, DI=0.8262
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 211 (unpriv_count=157, priv_count=54)
#    => GroundTruth: label=1 => 20, label=0 => 191
#    => Predictions: label=1 => 57, label=0 => 154
#    Compare unpriv=Hispanic_Male vs priv=Asian_Female: SPD=-0.0395, DI=0.9480
#
# [DEBUG] build_aif360_subset => unpriv='AfricanAmerican_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 1174 (unpriv_count=1120, priv_count=54)
#    => GroundTruth: label=1 => 149, label=0 => 1025
#    => Predictions: label=1 => 432, label=0 => 742
#    Compare unpriv=AfricanAmerican_Male vs priv=Asian_Female: SPD=-0.1334, DI=0.8243
#
# [DEBUG] build_aif360_subset => unpriv='Hispanic_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 220 (unpriv_count=166, priv_count=54)
#    => GroundTruth: label=1 => 23, label=0 => 197
#    => Predictions: label=1 => 60, label=0 => 160
#    Compare unpriv=Hispanic_Female vs priv=Asian_Female: SPD=-0.0424, DI=0.9442
#
# [DEBUG] build_aif360_subset => unpriv='Other_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 168 (unpriv_count=114, priv_count=54)
#    => GroundTruth: label=1 => 14, label=0 => 154
#    => Predictions: label=1 => 50, label=0 => 118
#    Compare unpriv=Other_Male vs priv=Asian_Female: SPD=-0.0838, DI=0.8896
#
# [DEBUG] build_aif360_subset => unpriv='Other_Female'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 190 (unpriv_count=136, priv_count=54)
#    => GroundTruth: label=1 => 24, label=0 => 166
#    => Predictions: label=1 => 55, label=0 => 135
#    Compare unpriv=Other_Female vs priv=Asian_Female: SPD=-0.0681, DI=0.9103
#
# [DEBUG] build_aif360_subset => unpriv='Asian_Male'(=1), priv='Asian_Female'(=0)
#    => #rows in subset: 104 (unpriv_count=50, priv_count=54)
#    => GroundTruth: label=1 => 11, label=0 => 93
#    => Predictions: label=1 => 22, label=0 => 82
#    Compare unpriv=Asian_Male vs priv=Asian_Female: SPD=0.0607, DI=1.0800
#
# === Aggregated Bias Results (Individual Subgroups) ===
#            Model             UnprivGroup     PrivGroup       SPD        DI  \
# 0   pred_LogReg        Caucasian_Female  Asian_Female -0.163746  0.799039
# 1   pred_LogReg          Caucasian_Male  Asian_Female -0.137946  0.830703
# 2   pred_LogReg  AfricanAmerican_Female  Asian_Female -0.156319  0.808154
# 3   pred_LogReg           Hispanic_Male  Asian_Female -0.088700  0.891141
# 4   pred_LogReg    AfricanAmerican_Male  Asian_Female -0.161243  0.802110
# 5   pred_LogReg         Hispanic_Female  Asian_Female -0.109996  0.865005
# 6   pred_LogReg              Other_Male  Asian_Female -0.139376  0.828947
# 7   pred_LogReg            Other_Female  Asian_Female -0.116285  0.857286
# 8   pred_LogReg              Asian_Male  Asian_Female -0.014815  0.981818
# 9      pred_XGB        Caucasian_Female  Asian_Female -0.141334  0.787999
# 10     pred_XGB          Caucasian_Male  Asian_Female -0.075125  0.887312
# 11     pred_XGB  AfricanAmerican_Female  Asian_Female -0.076695  0.884958
# 12     pred_XGB           Hispanic_Male  Asian_Female -0.042463  0.936306
# 13     pred_XGB    AfricanAmerican_Male  Asian_Female -0.085417  0.871875
# 14     pred_XGB         Hispanic_Female  Asian_Female -0.028112  0.957831
# 15     pred_XGB              Other_Male  Asian_Female -0.008772  0.986842
# 16     pred_XGB            Other_Female  Asian_Female -0.107843  0.838235
# 17     pred_XGB              Asian_Male  Asian_Female  0.133333  1.200000
# 18     pred_MLP        Caucasian_Female  Asian_Female -0.125864  0.834228
# 19     pred_MLP          Caucasian_Male  Asian_Female -0.100754  0.867299
# 20     pred_MLP  AfricanAmerican_Female  Asian_Female -0.131961  0.826197
# 21     pred_MLP           Hispanic_Male  Asian_Female -0.039514  0.947957
# 22     pred_MLP    AfricanAmerican_Male  Asian_Female -0.133366  0.824347
# 23     pred_MLP         Hispanic_Female  Asian_Female -0.042392  0.944167
# 24     pred_MLP              Other_Male  Asian_Female -0.083821  0.889602
# 25     pred_MLP            Other_Female  Asian_Female -0.068083  0.910330
# 26     pred_MLP              Asian_Male  Asian_Female  0.060741  1.080000
#
#          EOD       AOD   T_Index
# 0  -0.120056 -0.313694  0.367937
# 1  -0.094684 -0.286437  0.337531
# 2  -0.112421 -0.307430  0.356276
# 3  -0.036422 -0.303925  0.263533
# 4  -0.109988 -0.324225  0.346284
# 5  -0.060123 -0.294767  0.284171
# 6  -0.084119 -0.417060  0.300840
# 7  -0.054379 -0.304967  0.272342
# 8   0.030556 -0.184722  0.221847
# 9  -0.097250 -0.292271  0.531043
# 10 -0.029739 -0.230406  0.438084
# 11 -0.031368 -0.232351  0.440025
# 12  0.011509 -0.268055  0.395923
# 13 -0.038873 -0.233306  0.444013
# 14  0.032019 -0.253598  0.371700
# 15  0.033412 -0.212461  0.384373
# 16 -0.035664 -0.323387  0.426109
# 17  0.198611 -0.117361  0.290024
# 18 -0.074670 -0.301998  0.389545
# 19 -0.050206 -0.274699  0.359717
# 20 -0.081368 -0.306538  0.396626
# 21  0.012092 -0.243954  0.296377
# 22 -0.076147 -0.317794  0.383184
# 23  0.015800 -0.256806  0.290197
# 24 -0.021619 -0.385810  0.325180
# 25  0.008121 -0.301495  0.291465
# 26  0.115278 -0.142361  0.245949
#
# === Plot SPD/DI for each Unpriv Subgroup vs. 'Asian_Female' ===
# === (B) Lumped Bias => 'Asian_Female' privileged vs. ALL_OTHERS unpriv ===
# [pred_LogReg] Non-Asian_Female vs Asian_Female: SPD=-0.1508, DI=0.8149
# [pred_XGB] Non-Asian_Female vs Asian_Female: SPD=-0.1008, DI=0.8489
# [pred_MLP] Non-Asian_Female vs Asian_Female: SPD=-0.1147, DI=0.8489
#
# === Aggregated Bias Results (Lumped) ===
#           Model UnprivGroup     PrivGroup       SPD        DI       EOD  \
# 0  pred_LogReg  ALL_OTHERS  Asian_Female -0.150793  0.814936 -0.106204
# 1     pred_XGB  ALL_OTHERS  Asian_Female -0.100762  0.848857 -0.055211
# 2     pred_MLP  ALL_OTHERS  Asian_Female -0.114740  0.848879 -0.062931
#
#         AOD   T_Index
# 0 -0.303540  0.351421
# 1 -0.256370  0.472073
# 2 -0.292716  0.375051
#
# === Plot SPD/DI => Non-Asian_Female vs 'Asian_Female' ===

# %%
results_dir = "dataset/train_test_extracted_base"

df_results_sep_OF.to_csv(os.path.join(results_dir, "bias_results_sep_OF_cherry_picked.csv"), index=False)
df_results_lumped_OF.to_csv(os.path.join(results_dir, "bias_results_lumped_OF_cherry_picked.csv"), index=False)

df_results_sep_AF.to_csv(os.path.join(results_dir, "bias_results_sep_AF_cherry_picked.csv"), index=False)
df_results_lumped_AF.to_csv(os.path.join(results_dir, "bias_results_lumped_AF_cherry_picked.csv"), index=False)
